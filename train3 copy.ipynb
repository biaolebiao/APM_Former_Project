# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 74.39%
# seed 3407 74.39%
# seed 1234 74.39%
# seed 98 73.17%
# seed 20 71.95%
# seed 1024 73.17%

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
UNFREEZE_EPOCH = 5  # 设定前 5 个 epoch 为阶段一
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 50
GRADIENT_ACCUMULATION_STEPS = 1
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SAVE_PATH = "checkpoints/best_model.pth"
PRETRAINED_SWIN_PATH = "checkpoints/model_swinvit.pt"
SEED = 42

set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-05-12 02:16:20,179 - Train - INFO - ==================================================
# 2026-05-12 02:16:20,180 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-05-12 02:16:20,182 - Train - INFO - ==================================================
# 2026-05-12 02:16:20,183 - Train - INFO - ▶ 随机种子 (SEED): 42
# 2026-05-12 02:16:20,184 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-05-12 02:16:20,185 - Train - INFO - ▶ 预热轮数 (Warmup Epochs): 5
# 2026-05-12 02:16:20,186 - Train - INFO - ▶ 批次大小 (Batch Size): 1
# 2026-05-12 02:16:20,187 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-05-12 02:16:20,189 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-05-12 02:16:20,190 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-05-12 02:16:20,192 - Train - INFO - ==================================================
# 2026-05-12 02:16:20,194 - Train - INFO - 训练设备: cuda
# 2026-05-12 02:16:20,195 - Train - INFO - 批次大小: 1
# 2026-05-12 02:16:20,196 - Train - INFO - 总轮数: 50

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS
)
# Out:
# 2026-05-12 02:16:20,243 - Train - INFO - 正在加载数据集...
# 2026-05-12 02:16:20,287 - utils.dataset - INFO - ✅ 成功加载 659 个样本
# 2026-05-12 02:16:20,294 - utils.dataset - INFO - ✅ 成功加载 82 个样本
# 2026-05-12 02:16:20,296 - utils.dataset - INFO - ✅ DataLoader 构建完成！
# 2026-05-12 02:16:20,297 - utils.dataset - INFO - 训练集批次: 659，验证集批次: 82

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model = APM_Former_ImageOnly(
    img_size=TRAIN_IMG_SIZE,
    in_channels=1,
    num_classes=NUM_CLASSES,
    feature_size=FEATURE_SIZE,
    guide_channels=GUIDE_CHANNELS,
    pretrained_swin_path=PRETRAINED_SWIN_PATH # 传入刚刚下载的权重
).to(DEVICE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-05-12 02:16:20,342 - Train - INFO - 初始化 APM-Former 模型...
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-05-12 02:16:22,376 - Train - INFO - 模型总参数量: 16.32 M

# %%
# 5. 损失函数 + 两阶段优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR

# ==========================================
# 损失函数 (保持你原来的完美配置不变)
# ==========================================
weights = torch.tensor([1.0, 1.768]).to(DEVICE) 
criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)

# ==========================================
# 两阶段训练：阶段一 (冻结主干)
# ==========================================

# 1. 冻结 Swin 主干网络
logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
for name, param in model.named_parameters():
    if "swin_backbone" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

# 2. 定义优化器：极其重要！这里加了 filter，只把没冻结的参数交给优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# 3. 阶段一的调度器：不需要预热，直接用 5 个 epoch 的余弦退火
scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
# Out:
# 2026-05-12 02:16:22,428 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1))
        # loss = criterion(logits, labels)
        loss = loss / accum_steps

        loss.backward()
        # 👇 就在 optimizer.step() 之前，加入这行“梯度裁剪”代码！
        # max_norm=1.0 或 2.0 是最常用的安全值
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc

from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    # correct = 0
    # total = 0
    all_preds = []
    all_labels = []
    all_probs = []  # 🌟 新增：专门用于收集预测为 pMCI 的概率，计算 AUC 必须用

    for images, labels in loader: 
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1)) # 如果用的是交叉熵，这里不用 unsqueeze

        total_loss += loss.item()
        
        # 获取预测类别 (0 或 1)
        preds = torch.argmax(logits, dim=1)
        
        # 🌟 获取预测为类别 1 (pMCI) 的概率
        probs = F.softmax(logits, dim=1)[:, 1] 
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    # ==========================
    # 🌟 计算所有医学黄金指标
    # ==========================
    acc = accuracy_score(all_labels, all_preds) * 100
    sen = recall_score(all_labels, all_preds, pos_label=1) * 100  # Sensitivity / Recall
    spe = recall_score(all_labels, all_preds, pos_label=0) * 100  # Specificity (反向召回)
    f1 = f1_score(all_labels, all_preds, pos_label=1) * 100
    
    # 计算 AUC (注意：有些 batch 如果只有一个类别会报错，这里做了容错)
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    
    # 打印超级豪华版日志
    logger.info(f"👉 混淆矩阵: [sMCI正确: {cm[0][0]}, 误判为pMCI: {cm[0][1]}] | [pMCI漏判: {cm[1][0]}, pMCI正确: {cm[1][1]}]")
    logger.info(f"🏆 评估指标: ACC: {acc:.2f}% | SEN: {sen:.2f}% | SPE: {spe:.2f}% | F1: {f1:.2f}% | AUC: {auc:.2f}%")
    
    return avg_loss, acc, auc

# %%
# # %% 训练1个batch，打印梯度！！！
# model.train()
# images, labels = next(iter(train_loader))
# images = images.to(DEVICE)
# labels = labels.to(DEVICE)

# optimizer.zero_grad()
# logits, _, _ = model(images)
# loss = criterion(logits, labels)
# loss.backward()

# # 打印Swin主干的梯度（如果是None/0，就是主干冻结！）
# print("Loss:", loss.item())
# print("Swin主干参数梯度：")
# for name, param in model.swin_backbone.named_parameters():
#     if param.grad is not None:
#         print(f"{name}: 梯度均值 = {param.grad.mean().item()}")
#         break
#     else:
#         print(f"{name}: 梯度为 None ❌（冻结了！）")
#         break

# %%
# 7. 主训练循环
best_val_acc = 0.0
logger.info("=" * 50)
logger.info("开始训练！")
logger.info("=" * 50)

for epoch in range(NUM_EPOCHS):
    # 👇 ================= 新增：解冻机关 ================= 👇
    if epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 重新定义优化器（包含主干网络），并大幅降低学习率来保护老专家！
        # 这里用 1e-4 或 5e-5 进行微调最合适
        optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    val_loss, val_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    scheduler.step()

    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {val_acc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), SAVE_PATH)
        logger.info(f"✅ 最佳模型已保存！最佳验证准确率: {best_val_acc:.2f}%")

logger.info("\n🎉 训练完成！")
logger.info(f"最终最佳验证准确率: {best_val_acc:.2f}%")
# Out:
# 2026-05-12 02:16:22,644 - Train - INFO - ==================================================
# 2026-05-12 02:16:22,646 - Train - INFO - 开始训练！
# 2026-05-12 02:16:22,647 - Train - INFO - ==================================================
# 2026-05-12 02:16:22,649 - Train - INFO -
# Epoch [1/50]
# 训练中: 100%|██████████| 659/659 [01:16<00:00,  8.66it/s]
# 2026-05-12 02:17:49,002 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:17:49,004 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.50%
# 2026-05-12 02:17:49,006 - Train - INFO - 训练损失: 0.2524 | 训练准确率: 62.67%
# 2026-05-12 02:17:49,007 - Train - INFO - 验证损失: 0.2993 | 验证准确率: 63.41%
# 2026-05-12 02:17:49,008 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-12 02:17:50,797 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 63.41%
# 2026-05-12 02:17:50,799 - Train - INFO -
# Epoch [2/50]
# 训练中: 100%|██████████| 659/659 [01:16<00:00,  8.57it/s]
# 2026-05-12 02:19:17,833 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:19:17,835 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 66.28%
# 2026-05-12 02:19:17,836 - Train - INFO - 训练损失: 0.2765 | 训练准确率: 63.88%
# 2026-05-12 02:19:17,837 - Train - INFO - 验证损失: 0.2500 | 验证准确率: 63.41%
# 2026-05-12 02:19:17,838 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-12 02:19:17,839 - Train - INFO -
# Epoch [3/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.31it/s]
# 2026-05-12 02:20:46,845 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:20:46,847 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 72.18%
# 2026-05-12 02:20:46,848 - Train - INFO - 训练损失: 0.2599 | 训练准确率: 63.88%
# 2026-05-12 02:20:46,849 - Train - INFO - 验证损失: 0.2607 | 验证准确率: 63.41%
# 2026-05-12 02:20:46,850 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-12 02:20:46,851 - Train - INFO -
# Epoch [4/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.69it/s]
# 2026-05-12 02:22:12,313 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:22:12,315 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 70.83%
# 2026-05-12 02:22:12,317 - Train - INFO - 训练损失: 0.2574 | 训练准确率: 63.88%
# 2026-05-12 02:22:12,319 - Train - INFO - 验证损失: 0.2604 | 验证准确率: 63.41%
# 2026-05-12 02:22:12,320 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-12 02:22:12,321 - Train - INFO -
# Epoch [5/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.24it/s]
# 2026-05-12 02:23:43,655 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:23:43,658 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.09%
# 2026-05-12 02:23:43,660 - Train - INFO - 训练损失: 0.2669 | 训练准确率: 63.88%
# 2026-05-12 02:23:43,661 - Train - INFO - 验证损失: 0.2585 | 验证准确率: 63.41%
# 2026-05-12 02:23:43,662 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-12 02:23:43,663 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-12 02:23:43,664 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！
# 2026-05-12 02:23:43,665 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-12 02:23:43,668 - Train - INFO -
# Epoch [6/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.69it/s]
# 2026-05-12 02:25:10,010 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:25:10,013 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 59.36%
# 2026-05-12 02:25:10,015 - Train - INFO - 训练损失: 0.3012 | 训练准确率: 63.88%
# 2026-05-12 02:25:10,016 - Train - INFO - 验证损失: 0.2471 | 验证准确率: 63.41%
# 2026-05-12 02:25:10,017 - Train - INFO - 当前学习率: 0.00029963
# 2026-05-12 02:25:10,018 - Train - INFO -
# Epoch [7/50]
# 训练中: 100%|██████████| 659/659 [01:16<00:00,  8.60it/s]
# 2026-05-12 02:26:37,252 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:26:37,255 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.79%
# 2026-05-12 02:26:37,258 - Train - INFO - 训练损失: 0.2452 | 训练准确率: 63.88%
# 2026-05-12 02:26:37,259 - Train - INFO - 验证损失: 0.2816 | 验证准确率: 63.41%
# 2026-05-12 02:26:37,260 - Train - INFO - 当前学习率: 0.00029854
# 2026-05-12 02:26:37,261 - Train - INFO -
# Epoch [8/50]
# 训练中: 100%|██████████| 659/659 [01:18<00:00,  8.43it/s]
# 2026-05-12 02:28:05,593 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:28:05,594 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 70.83%
# 2026-05-12 02:28:05,596 - Train - INFO - 训练损失: 0.2472 | 训练准确率: 63.88%
# 2026-05-12 02:28:05,597 - Train - INFO - 验证损失: 0.2280 | 验证准确率: 63.41%
# 2026-05-12 02:28:05,598 - Train - INFO - 当前学习率: 0.00029672
# 2026-05-12 02:28:05,598 - Train - INFO -
# Epoch [9/50]
# 训练中: 100%|██████████| 659/659 [01:18<00:00,  8.36it/s]
# 2026-05-12 02:29:35,242 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:29:35,244 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 72.82%
# 2026-05-12 02:29:35,246 - Train - INFO - 训练损失: 0.2323 | 训练准确率: 63.88%
# 2026-05-12 02:29:35,247 - Train - INFO - 验证损失: 0.2325 | 验证准确率: 63.41%
# 2026-05-12 02:29:35,248 - Train - INFO - 当前学习率: 0.00029419
# 2026-05-12 02:29:35,248 - Train - INFO -
# Epoch [10/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.79it/s]
# 2026-05-12 02:31:00,230 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:31:00,232 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 78.33%
# 2026-05-12 02:31:00,234 - Train - INFO - 训练损失: 0.2305 | 训练准确率: 63.28%
# 2026-05-12 02:31:00,235 - Train - INFO - 验证损失: 0.2270 | 验证准确率: 63.41%
# 2026-05-12 02:31:00,235 - Train - INFO - 当前学习率: 0.00029095
# 2026-05-12 02:31:00,236 - Train - INFO -
# Epoch [11/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.67it/s]
# 2026-05-12 02:32:26,103 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:32:26,106 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 74.42%
# 2026-05-12 02:32:26,108 - Train - INFO - 训练损失: 0.2415 | 训练准确率: 63.88%
# 2026-05-12 02:32:26,109 - Train - INFO - 验证损失: 0.2278 | 验证准确率: 63.41%
# 2026-05-12 02:32:26,110 - Train - INFO - 当前学习率: 0.00028703
# 2026-05-12 02:32:26,111 - Train - INFO -
# Epoch [12/50]
# 训练中: 100%|██████████| 659/659 [01:16<00:00,  8.64it/s]
# 2026-05-12 02:33:52,976 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:33:52,978 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 66.92%
# 2026-05-12 02:33:52,980 - Train - INFO - 训练损失: 0.2656 | 训练准确率: 63.88%
# 2026-05-12 02:33:52,981 - Train - INFO - 验证损失: 0.2834 | 验证准确率: 63.41%
# 2026-05-12 02:33:52,983 - Train - INFO - 当前学习率: 0.00028244
# 2026-05-12 02:33:52,984 - Train - INFO -
# Epoch [13/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.73it/s]
# 2026-05-12 02:35:18,558 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:35:18,561 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 54.36%
# 2026-05-12 02:35:18,563 - Train - INFO - 训练损失: 0.2776 | 训练准确率: 63.88%
# 2026-05-12 02:35:18,564 - Train - INFO - 验证损失: 0.2302 | 验证准确率: 63.41%
# 2026-05-12 02:35:18,565 - Train - INFO - 当前学习率: 0.00027721
# 2026-05-12 02:35:18,565 - Train - INFO -
# Epoch [14/50]
# 训练中: 100%|██████████| 659/659 [01:20<00:00,  8.19it/s]
# 2026-05-12 02:36:49,112 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:36:49,114 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 61.73%
# 2026-05-12 02:36:49,116 - Train - INFO - 训练损失: 0.2308 | 训练准确率: 63.88%
# 2026-05-12 02:36:49,117 - Train - INFO - 验证损失: 0.2289 | 验证准确率: 63.41%
# 2026-05-12 02:36:49,118 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-12 02:36:49,118 - Train - INFO -
# Epoch [15/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.34it/s]
# 2026-05-12 02:38:19,752 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:38:19,755 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 73.14%
# 2026-05-12 02:38:19,756 - Train - INFO - 训练损失: 0.2285 | 训练准确率: 63.88%
# 2026-05-12 02:38:19,757 - Train - INFO - 验证损失: 0.2266 | 验证准确率: 63.41%
# 2026-05-12 02:38:19,759 - Train - INFO - 当前学习率: 0.00026491
# 2026-05-12 02:38:19,760 - Train - INFO -
# Epoch [16/50]
# 训练中: 100%|██████████| 659/659 [01:17<00:00,  8.46it/s]
# 2026-05-12 02:39:48,169 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:39:48,171 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 70.71%
# 2026-05-12 02:39:48,172 - Train - INFO - 训练损失: 0.2276 | 训练准确率: 63.88%
# 2026-05-12 02:39:48,174 - Train - INFO - 验证损失: 0.2275 | 验证准确率: 63.41%
# 2026-05-12 02:39:48,174 - Train - INFO - 当前学习率: 0.00025790
# 2026-05-12 02:39:48,175 - Train - INFO -
# Epoch [17/50]
# 训练中: 100%|██████████| 659/659 [01:18<00:00,  8.39it/s]
# 2026-05-12 02:41:16,163 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:41:16,165 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 74.10%
# 2026-05-12 02:41:16,167 - Train - INFO - 训练损失: 0.2265 | 训练准确率: 63.88%
# 2026-05-12 02:41:16,168 - Train - INFO - 验证损失: 0.2451 | 验证准确率: 63.41%
# 2026-05-12 02:41:16,170 - Train - INFO - 当前学习率: 0.00025037
# 2026-05-12 02:41:16,171 - Train - INFO -
# Epoch [18/50]
# 训练中: 100%|██████████| 659/659 [01:18<00:00,  8.38it/s]
# 2026-05-12 02:42:44,479 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:42:44,482 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 74.94%
# 2026-05-12 02:42:44,483 - Train - INFO - 训练损失: 0.2346 | 训练准确率: 63.88%
# 2026-05-12 02:42:44,484 - Train - INFO - 验证损失: 0.2264 | 验证准确率: 63.41%
# 2026-05-12 02:42:44,485 - Train - INFO - 当前学习率: 0.00024235
# 2026-05-12 02:42:44,487 - Train - INFO -
# Epoch [19/50]
# 训练中: 100%|██████████| 659/659 [01:21<00:00,  8.11it/s]
# 2026-05-12 02:44:16,810 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:44:16,812 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.32%
# 2026-05-12 02:44:16,814 - Train - INFO - 训练损失: 0.2309 | 训练准确率: 63.88%
# 2026-05-12 02:44:16,815 - Train - INFO - 验证损失: 0.2251 | 验证准确率: 63.41%
# 2026-05-12 02:44:16,816 - Train - INFO - 当前学习率: 0.00023388
# 2026-05-12 02:44:16,816 - Train - INFO -
# Epoch [20/50]
# 训练中: 100%|██████████| 659/659 [01:33<00:00,  7.08it/s]
# 2026-05-12 02:46:01,041 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:46:01,043 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 76.54%
# 2026-05-12 02:46:01,045 - Train - INFO - 训练损失: 0.2625 | 训练准确率: 63.88%
# 2026-05-12 02:46:01,046 - Train - INFO - 验证损失: 0.2915 | 验证准确率: 63.41%
# 2026-05-12 02:46:01,047 - Train - INFO - 当前学习率: 0.00022500
# 2026-05-12 02:46:01,048 - Train - INFO -
# Epoch [21/50]
# 训练中: 100%|██████████| 659/659 [01:28<00:00,  7.44it/s]
# 2026-05-12 02:47:40,124 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:47:40,127 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.96%
# 2026-05-12 02:47:40,128 - Train - INFO - 训练损失: 0.3182 | 训练准确率: 63.88%
# 2026-05-12 02:47:40,129 - Train - INFO - 验证损失: 0.2614 | 验证准确率: 63.41%
# 2026-05-12 02:47:40,130 - Train - INFO - 当前学习率: 0.00021576
# 2026-05-12 02:47:40,131 - Train - INFO -
# Epoch [22/50]
# 训练中: 100%|██████████| 659/659 [01:21<00:00,  8.04it/s]
# 2026-05-12 02:49:12,602 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-12 02:49:12,604 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 76.28%
# 2026-05-12 02:49:12,606 - Train - INFO - 训练损失: 0.3260 | 训练准确率: 63.88%
# 2026-05-12 02:49:12,606 - Train - INFO - 验证损失: 0.2971 | 验证准确率: 63.41%
# 2026-05-12 02:49:12,607 - Train - INFO - 当前学习率: 0.00020619
# 2026-05-12 02:49:12,608 - Train - INFO -
# Epoch [23/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.33it/s]
# 2026-05-12 02:50:41,090 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 26, pMCI正确: 4]
# 2026-05-12 02:50:41,092 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 13.33% | SPE: 100.00% | F1: 23.53% | AUC: 76.03%
# 2026-05-12 02:50:41,094 - Train - INFO - 训练损失: 0.3404 | 训练准确率: 64.19%
# 2026-05-12 02:50:41,095 - Train - INFO - 验证损失: 0.2413 | 验证准确率: 68.29%
# 2026-05-12 02:50:41,095 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-12 02:50:42,302 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 68.29%
# 2026-05-12 02:50:42,303 - Train - INFO -
# Epoch [24/50]
# 训练中: 100%|██████████| 659/659 [01:20<00:00,  8.20it/s]
# 2026-05-12 02:52:13,225 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 50, 误判为pMCI: 2] | [pMCI漏判: 25, pMCI正确: 5]
# 2026-05-12 02:52:13,227 - Train - INFO - 🏆 评估指标: ACC: 67.07% | SEN: 16.67% | SPE: 96.15% | F1: 27.03% | AUC: 77.12%
# 2026-05-12 02:52:13,229 - Train - INFO - 训练损失: 0.3284 | 训练准确率: 64.34%
# 2026-05-12 02:52:13,230 - Train - INFO - 验证损失: 0.2202 | 验证准确率: 67.07%
# 2026-05-12 02:52:13,231 - Train - INFO - 当前学习率: 0.00018629
# 2026-05-12 02:52:13,232 - Train - INFO -
# Epoch [25/50]
# 训练中: 100%|██████████| 659/659 [01:18<00:00,  8.41it/s]
# 2026-05-12 02:53:42,216 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 51, 误判为pMCI: 1] | [pMCI漏判: 25, pMCI正确: 5]
# 2026-05-12 02:53:42,217 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 16.67% | SPE: 98.08% | F1: 27.78% | AUC: 76.22%
# 2026-05-12 02:53:42,219 - Train - INFO - 训练损失: 0.3280 | 训练准确率: 63.58%
# 2026-05-12 02:53:42,220 - Train - INFO - 验证损失: 0.2363 | 验证准确率: 68.29%
# 2026-05-12 02:53:42,220 - Train - INFO - 当前学习率: 0.00017605
# 2026-05-12 02:53:42,221 - Train - INFO -
# Epoch [26/50]
# 训练中: 100%|██████████| 659/659 [01:21<00:00,  8.08it/s]
# 2026-05-12 02:55:13,977 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 50, 误判为pMCI: 2] | [pMCI漏判: 25, pMCI正确: 5]
# 2026-05-12 02:55:13,979 - Train - INFO - 🏆 评估指标: ACC: 67.07% | SEN: 16.67% | SPE: 96.15% | F1: 27.03% | AUC: 76.28%
# 2026-05-12 02:55:13,981 - Train - INFO - 训练损失: 0.3241 | 训练准确率: 65.55%
# 2026-05-12 02:55:13,982 - Train - INFO - 验证损失: 0.2552 | 验证准确率: 67.07%
# 2026-05-12 02:55:13,983 - Train - INFO - 当前学习率: 0.00016568
# 2026-05-12 02:55:13,984 - Train - INFO -
# Epoch [27/50]
# 训练中: 100%|██████████| 659/659 [01:16<00:00,  8.61it/s]
# 2026-05-12 02:56:41,448 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 40, 误判为pMCI: 12] | [pMCI漏判: 10, pMCI正确: 20]
# 2026-05-12 02:56:41,451 - Train - INFO - 🏆 评估指标: ACC: 73.17% | SEN: 66.67% | SPE: 76.92% | F1: 64.52% | AUC: 76.60%
# 2026-05-12 02:56:41,453 - Train - INFO - 训练损失: 0.3323 | 训练准确率: 66.92%
# 2026-05-12 02:56:41,454 - Train - INFO - 验证损失: 0.2229 | 验证准确率: 73.17%
# 2026-05-12 02:56:41,455 - Train - INFO - 当前学习率: 0.00015523
# 2026-05-12 02:56:43,295 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 73.17%
# 2026-05-12 02:56:43,297 - Train - INFO -
# Epoch [28/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.24it/s]
# 2026-05-12 02:58:13,024 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 50, 误判为pMCI: 2] | [pMCI漏判: 25, pMCI正确: 5]
# 2026-05-12 02:58:13,026 - Train - INFO - 🏆 评估指标: ACC: 67.07% | SEN: 16.67% | SPE: 96.15% | F1: 27.03% | AUC: 76.41%
# 2026-05-12 02:58:13,027 - Train - INFO - 训练损失: 0.3067 | 训练准确率: 68.13%
# 2026-05-12 02:58:13,028 - Train - INFO - 验证损失: 0.3716 | 验证准确率: 67.07%
# 2026-05-12 02:58:13,029 - Train - INFO - 当前学习率: 0.00014477
# 2026-05-12 02:58:13,029 - Train - INFO -
# Epoch [29/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.68it/s]
# 2026-05-12 02:59:39,501 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 24, 误判为pMCI: 28] | [pMCI漏判: 5, pMCI正确: 25]
# 2026-05-12 02:59:39,505 - Train - INFO - 🏆 评估指标: ACC: 59.76% | SEN: 83.33% | SPE: 46.15% | F1: 60.24% | AUC: 74.94%
# 2026-05-12 02:59:39,509 - Train - INFO - 训练损失: 0.3579 | 训练准确率: 67.07%
# 2026-05-12 02:59:39,510 - Train - INFO - 验证损失: 0.4055 | 验证准确率: 59.76%
# 2026-05-12 02:59:39,511 - Train - INFO - 当前学习率: 0.00013432
# 2026-05-12 02:59:39,512 - Train - INFO -
# Epoch [30/50]
# 训练中: 100%|██████████| 659/659 [01:20<00:00,  8.18it/s]
# 2026-05-12 03:01:10,532 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 48, 误判为pMCI: 4] | [pMCI漏判: 23, pMCI正确: 7]
# 2026-05-12 03:01:10,535 - Train - INFO - 🏆 评估指标: ACC: 67.07% | SEN: 23.33% | SPE: 92.31% | F1: 34.15% | AUC: 76.73%
# 2026-05-12 03:01:10,536 - Train - INFO - 训练损失: 0.3345 | 训练准确率: 66.31%
# 2026-05-12 03:01:10,537 - Train - INFO - 验证损失: 0.2888 | 验证准确率: 67.07%
# 2026-05-12 03:01:10,538 - Train - INFO - 当前学习率: 0.00012395
# 2026-05-12 03:01:10,539 - Train - INFO -
# Epoch [31/50]
# 训练中: 100%|██████████| 659/659 [01:16<00:00,  8.59it/s]
# 2026-05-12 03:02:37,479 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 14, pMCI正确: 16]
# 2026-05-12 03:02:37,482 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 53.33% | SPE: 80.77% | F1: 57.14% | AUC: 75.58%
# 2026-05-12 03:02:37,483 - Train - INFO - 训练损失: 0.3379 | 训练准确率: 68.44%
# 2026-05-12 03:02:37,484 - Train - INFO - 验证损失: 0.2397 | 验证准确率: 70.73%
# 2026-05-12 03:02:37,485 - Train - INFO - 当前学习率: 0.00011371
# 2026-05-12 03:02:37,485 - Train - INFO -
# Epoch [32/50]
# 训练中: 100%|██████████| 659/659 [01:17<00:00,  8.50it/s]
# 2026-05-12 03:04:05,461 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 40, 误判为pMCI: 12] | [pMCI漏判: 9, pMCI正确: 21]
# 2026-05-12 03:04:05,463 - Train - INFO - 🏆 评估指标: ACC: 74.39% | SEN: 70.00% | SPE: 76.92% | F1: 66.67% | AUC: 75.19%
# 2026-05-12 03:04:05,465 - Train - INFO - 训练损失: 0.3452 | 训练准确率: 68.29%
# 2026-05-12 03:04:05,466 - Train - INFO - 验证损失: 0.2702 | 验证准确率: 74.39%
# 2026-05-12 03:04:05,467 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-12 03:04:07,232 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 74.39%
# 2026-05-12 03:04:07,233 - Train - INFO -
# Epoch [33/50]
# 训练中: 100%|██████████| 659/659 [01:18<00:00,  8.40it/s]
# 2026-05-12 03:05:35,200 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 50, 误判为pMCI: 2] | [pMCI漏判: 23, pMCI正确: 7]
# 2026-05-12 03:05:35,202 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 23.33% | SPE: 96.15% | F1: 35.90% | AUC: 76.86%
# 2026-05-12 03:05:35,204 - Train - INFO - 训练损失: 0.3428 | 训练准确率: 68.89%
# 2026-05-12 03:05:35,205 - Train - INFO - 验证损失: 0.3258 | 验证准确率: 69.51%
# 2026-05-12 03:05:35,206 - Train - INFO - 当前学习率: 0.00009381
# 2026-05-12 03:05:35,207 - Train - INFO -
# Epoch [34/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.25it/s]
# 2026-05-12 03:07:05,924 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 26, pMCI正确: 4]
# 2026-05-12 03:07:05,927 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 13.33% | SPE: 100.00% | F1: 23.53% | AUC: 77.24%
# 2026-05-12 03:07:05,929 - Train - INFO - 训练损失: 0.3457 | 训练准确率: 68.13%
# 2026-05-12 03:07:05,930 - Train - INFO - 验证损失: 0.3956 | 验证准确率: 68.29%
# 2026-05-12 03:07:05,931 - Train - INFO - 当前学习率: 0.00008424
# 2026-05-12 03:07:05,932 - Train - INFO -
# Epoch [35/50]
# 训练中: 100%|██████████| 659/659 [01:17<00:00,  8.48it/s]
# 2026-05-12 03:08:33,386 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:08:33,390 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 50.00% | SPE: 84.62% | F1: 56.60% | AUC: 75.45%
# 2026-05-12 03:08:33,392 - Train - INFO - 训练损失: 0.3671 | 训练准确率: 69.50%
# 2026-05-12 03:08:33,393 - Train - INFO - 验证损失: 0.2530 | 验证准确率: 71.95%
# 2026-05-12 03:08:33,394 - Train - INFO - 当前学习率: 0.00007500
# 2026-05-12 03:08:33,395 - Train - INFO -
# Epoch [36/50]
# 训练中: 100%|██████████| 659/659 [01:26<00:00,  7.65it/s]
# 2026-05-12 03:10:09,801 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 51, 误判为pMCI: 1] | [pMCI漏判: 25, pMCI正确: 5]
# 2026-05-12 03:10:09,804 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 16.67% | SPE: 98.08% | F1: 27.78% | AUC: 76.09%
# 2026-05-12 03:10:09,806 - Train - INFO - 训练损失: 0.3428 | 训练准确率: 68.13%
# 2026-05-12 03:10:09,807 - Train - INFO - 验证损失: 0.3602 | 验证准确率: 68.29%
# 2026-05-12 03:10:09,808 - Train - INFO - 当前学习率: 0.00006612
# 2026-05-12 03:10:09,809 - Train - INFO -
# Epoch [37/50]
# 训练中: 100%|██████████| 659/659 [01:31<00:00,  7.20it/s]
# 2026-05-12 03:11:53,211 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 36, 误判为pMCI: 16] | [pMCI漏判: 8, pMCI正确: 22]
# 2026-05-12 03:11:53,214 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 73.33% | SPE: 69.23% | F1: 64.71% | AUC: 75.00%
# 2026-05-12 03:11:53,216 - Train - INFO - 训练损失: 0.3374 | 训练准确率: 66.77%
# 2026-05-12 03:11:53,218 - Train - INFO - 验证损失: 0.3508 | 验证准确率: 70.73%
# 2026-05-12 03:11:53,219 - Train - INFO - 当前学习率: 0.00005765
# 2026-05-12 03:11:53,220 - Train - INFO -
# Epoch [38/50]
# 训练中: 100%|██████████| 659/659 [01:37<00:00,  6.76it/s]
# 2026-05-12 03:13:41,240 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:13:41,244 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 50.00% | SPE: 82.69% | F1: 55.56% | AUC: 75.26%
# 2026-05-12 03:13:41,246 - Train - INFO - 训练损失: 0.3443 | 训练准确率: 69.80%
# 2026-05-12 03:13:41,247 - Train - INFO - 验证损失: 0.2909 | 验证准确率: 70.73%
# 2026-05-12 03:13:41,248 - Train - INFO - 当前学习率: 0.00004963
# 2026-05-12 03:13:41,249 - Train - INFO -
# Epoch [39/50]
# 训练中: 100%|██████████| 659/659 [01:29<00:00,  7.33it/s]
# 2026-05-12 03:15:21,927 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 14, pMCI正确: 16]
# 2026-05-12 03:15:21,930 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 53.33% | SPE: 80.77% | F1: 57.14% | AUC: 75.26%
# 2026-05-12 03:15:21,931 - Train - INFO - 训练损失: 0.3445 | 训练准确率: 70.11%
# 2026-05-12 03:15:21,933 - Train - INFO - 验证损失: 0.2967 | 验证准确率: 70.73%
# 2026-05-12 03:15:21,934 - Train - INFO - 当前学习率: 0.00004210
# 2026-05-12 03:15:21,935 - Train - INFO -
# Epoch [40/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.30it/s]
# 2026-05-12 03:16:52,372 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 39, 误判为pMCI: 13] | [pMCI漏判: 9, pMCI正确: 21]
# 2026-05-12 03:16:52,374 - Train - INFO - 🏆 评估指标: ACC: 73.17% | SEN: 70.00% | SPE: 75.00% | F1: 65.62% | AUC: 74.87%
# 2026-05-12 03:16:52,376 - Train - INFO - 训练损失: 0.3639 | 训练准确率: 68.29%
# 2026-05-12 03:16:52,377 - Train - INFO - 验证损失: 0.3412 | 验证准确率: 73.17%
# 2026-05-12 03:16:52,378 - Train - INFO - 当前学习率: 0.00003509
# 2026-05-12 03:16:52,379 - Train - INFO -
# Epoch [41/50]
# 训练中: 100%|██████████| 659/659 [01:17<00:00,  8.45it/s]
# 2026-05-12 03:18:20,876 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 40, 误判为pMCI: 12] | [pMCI漏判: 10, pMCI正确: 20]
# 2026-05-12 03:18:20,879 - Train - INFO - 🏆 评估指标: ACC: 73.17% | SEN: 66.67% | SPE: 76.92% | F1: 64.52% | AUC: 75.13%
# 2026-05-12 03:18:20,881 - Train - INFO - 训练损失: 0.3609 | 训练准确率: 69.50%
# 2026-05-12 03:18:20,882 - Train - INFO - 验证损失: 0.3039 | 验证准确率: 73.17%
# 2026-05-12 03:18:20,884 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-12 03:18:20,885 - Train - INFO -
# Epoch [42/50]
# 训练中: 100%|██████████| 659/659 [01:19<00:00,  8.32it/s]
# 2026-05-12 03:19:51,161 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 47, 误判为pMCI: 5] | [pMCI漏判: 19, pMCI正确: 11]
# 2026-05-12 03:19:51,164 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 36.67% | SPE: 90.38% | F1: 47.83% | AUC: 75.64%
# 2026-05-12 03:19:51,167 - Train - INFO - 训练损失: 0.3418 | 训练准确率: 68.44%
# 2026-05-12 03:19:51,168 - Train - INFO - 验证损失: 0.2886 | 验证准确率: 70.73%
# 2026-05-12 03:19:51,170 - Train - INFO - 当前学习率: 0.00002279
# 2026-05-12 03:19:51,171 - Train - INFO -
# Epoch [43/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.68it/s]
# 2026-05-12 03:21:17,325 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:21:17,327 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 74.94%
# 2026-05-12 03:21:17,329 - Train - INFO - 训练损失: 0.3383 | 训练准确率: 69.35%
# 2026-05-12 03:21:17,330 - Train - INFO - 验证损失: 0.2841 | 验证准确率: 69.51%
# 2026-05-12 03:21:17,331 - Train - INFO - 当前学习率: 0.00001756
# 2026-05-12 03:21:17,332 - Train - INFO -
# Epoch [44/50]
# 训练中: 100%|██████████| 659/659 [01:18<00:00,  8.40it/s]
# 2026-05-12 03:22:47,354 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-12 03:22:47,356 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 56.67% | SPE: 80.77% | F1: 59.65% | AUC: 74.62%
# 2026-05-12 03:22:47,358 - Train - INFO - 训练损失: 0.3524 | 训练准确率: 70.86%
# 2026-05-12 03:22:47,359 - Train - INFO - 验证损失: 0.2983 | 验证准确率: 71.95%
# 2026-05-12 03:22:47,360 - Train - INFO - 当前学习率: 0.00001297
# 2026-05-12 03:22:47,361 - Train - INFO -
# Epoch [45/50]
# 训练中: 100%|██████████| 659/659 [01:30<00:00,  7.30it/s]
# 2026-05-12 03:24:28,182 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 16, pMCI正确: 14]
# 2026-05-12 03:24:28,184 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 46.67% | SPE: 80.77% | F1: 51.85% | AUC: 75.38%
# 2026-05-12 03:24:28,186 - Train - INFO - 训练损失: 0.3506 | 训练准确率: 69.65%
# 2026-05-12 03:24:28,187 - Train - INFO - 验证损失: 0.2894 | 验证准确率: 68.29%
# 2026-05-12 03:24:28,188 - Train - INFO - 当前学习率: 0.00000905
# 2026-05-12 03:24:28,189 - Train - INFO -
# Epoch [46/50]
# 训练中: 100%|██████████| 659/659 [01:15<00:00,  8.72it/s]
# 2026-05-12 03:25:54,200 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:25:54,202 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.19%
# 2026-05-12 03:25:54,205 - Train - INFO - 训练损失: 0.3494 | 训练准确率: 68.44%
# 2026-05-12 03:25:54,207 - Train - INFO - 验证损失: 0.2917 | 验证准确率: 69.51%
# 2026-05-12 03:25:54,208 - Train - INFO - 当前学习率: 0.00000581
# 2026-05-12 03:25:54,209 - Train - INFO -
# Epoch [47/50]
# 训练中: 100%|██████████| 659/659 [01:14<00:00,  8.81it/s]
# 2026-05-12 03:27:18,801 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:27:18,804 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.38%
# 2026-05-12 03:27:18,807 - Train - INFO - 训练损失: 0.3418 | 训练准确率: 70.26%
# 2026-05-12 03:27:18,808 - Train - INFO - 验证损失: 0.2928 | 验证准确率: 69.51%
# 2026-05-12 03:27:18,809 - Train - INFO - 当前学习率: 0.00000328
# 2026-05-12 03:27:18,810 - Train - INFO -
# Epoch [48/50]
# 训练中: 100%|██████████| 659/659 [01:16<00:00,  8.66it/s]
# 2026-05-12 03:28:44,904 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:28:44,906 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.32%
# 2026-05-12 03:28:44,907 - Train - INFO - 训练损失: 0.3449 | 训练准确率: 71.17%
# 2026-05-12 03:28:44,908 - Train - INFO - 验证损失: 0.2940 | 验证准确率: 69.51%
# 2026-05-12 03:28:44,909 - Train - INFO - 当前学习率: 0.00000146
# 2026-05-12 03:28:44,910 - Train - INFO -
# Epoch [49/50]
# 训练中: 100%|██████████| 659/659 [01:17<00:00,  8.55it/s]
# 2026-05-12 03:30:12,718 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:30:12,720 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.32%
# 2026-05-12 03:30:12,722 - Train - INFO - 训练损失: 0.3584 | 训练准确率: 69.20%
# 2026-05-12 03:30:12,723 - Train - INFO - 验证损失: 0.2938 | 验证准确率: 69.51%
# 2026-05-12 03:30:12,724 - Train - INFO - 当前学习率: 0.00000037
# 2026-05-12 03:30:12,725 - Train - INFO -
# Epoch [50/50]
# 训练中: 100%|██████████| 659/659 [01:17<00:00,  8.52it/s]
# 2026-05-12 03:31:40,159 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-12 03:31:40,162 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.32%
# 2026-05-12 03:31:40,163 - Train - INFO - 训练损失: 0.3651 | 训练准确率: 69.20%
# 2026-05-12 03:31:40,164 - Train - INFO - 验证损失: 0.2940 | 验证准确率: 69.51%
# 2026-05-12 03:31:40,165 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-12 03:31:40,166 - Train - INFO -
# 🎉 训练完成！
# 2026-05-12 03:31:40,167 - Train - INFO - 最终最佳验证准确率: 74.39%

# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# ==========================================
# 第一步：加载你跑出 74.39% 的最佳模型权重
# ==========================================
print("🔄 正在加载最佳模型权重...")

# 实例化模型 (确保这里的参数和你跑出最好成绩的那次完全一致)
# 之前确认过 FEATURE_SIZE 是 24
vis_model = APM_Former_ImageOnly(
    feature_size=24,  
    num_classes=2
).to(DEVICE)

# ⚠️ 注意：把这里的 'best_model.pth' 换成你实际保存的权重文件名！
# 比如可能是 'checkpoint_epoch_xx.pth'
checkpoint_path = 'checkpoints/best_model.pth'  
state_dict = torch.load(checkpoint_path, map_location=DEVICE)
vis_model.load_state_dict(state_dict)

vis_model.eval() # 切换到评估模式
print(f"✅ 成功加载权重: {checkpoint_path}")
print("-" * 50)


# ==========================================
# 第二步：定义并运行可视化探针
# ==========================================
@torch.no_grad()
def visualize_pMCI_attention(model, val_loader, device, num_cases_to_show=3):
    model.eval()
    found_cases = 0
    
    # 解决 matplotlib 中文显示问题
    # plt.rcParams['font.sans-serif'] = ['SimHei'] 
    # plt.rcParams['axes.unicode_minus'] = False
    
    print("🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...\n")
    
    for images, labels in val_loader:
        images = images.to(device)
        labels = labels.to(device)
        
        logits, _, spatial_attention = model(images)
        preds = torch.argmax(logits, dim=1)
        
        # 寻找 True Positives (真实为pMCI，预测也为pMCI)
        for i in range(len(labels)):
            if labels[i].item() == 1 and preds[i].item() == 1:
                found_cases += 1
                
                # 1. 提取原始 3D MRI 图像
                img_3d = images[i, 0].cpu().numpy()  
                
                # 2. 提取注意力掩码，并插值放大到原始图像大小 (96, 96, 96)
                attn_tensor = spatial_attention[i:i+1] 
                attn_resized = F.interpolate(attn_tensor, size=img_3d.shape, mode='trilinear', align_corners=False)
                attn_3d = attn_resized[0, 0].cpu().numpy()
                
                # 3. 智能寻找网络最关注的切片位置
                slice_x = np.argmax(np.sum(attn_3d, axis=(1, 2))) 
                slice_y = np.argmax(np.sum(attn_3d, axis=(0, 2))) 
                slice_z = np.argmax(np.sum(attn_3d, axis=(0, 1))) 
                
                # 4. 绘图
                fig, axes = plt.subplots(1, 3, figsize=(18, 6))
                # 成功识别的pMCI阳性病例  高亮区域为网络空间对齐中点关注区域
                fig.suptitle(f"True Positive pMCI Case #{found_cases}\n(Spatial Attention Guided Alignment)", fontsize=18, fontweight='bold', y=1.05)
                
                # 矢状面 矢状面切片
                axes[0].imshow(img_3d[slice_x, :, :], cmap='gray') 
                im = axes[0].imshow(attn_3d[slice_x, :, :], cmap='jet', alpha=0.45) 
                axes[0].set_title(f"Sagittal View (Slice {slice_x})", fontsize=14)
                axes[0].axis('off')
                
                # 冠状面 冠状面切片
                axes[1].imshow(img_3d[:, slice_y, :], cmap='gray')
                axes[1].imshow(attn_3d[:, slice_y, :], cmap='jet', alpha=0.45)
                axes[1].set_title(f"Coronal View (Slice {slice_y})", fontsize=14)
                axes[1].axis('off')
                
                # 轴状面 轴状面切片
                axes[2].imshow(img_3d[:, :, slice_z], cmap='gray')
                axes[2].imshow(attn_3d[:, :, slice_z], cmap='jet', alpha=0.45)
                axes[2].set_title(f"Axial View (Slice {slice_z})", fontsize=14)
                axes[2].axis('off')
                
                # 颜色条的标签 解剖引导强度
                cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
                cbar.set_label('Attention Weight', fontsize=12)
                
                plt.show()
                
                if found_cases >= num_cases_to_show:
                    print(f"\n✅ 成功提取 {num_cases_to_show} 组 pMCI 空间注意力图！")
                    return

    print(f"\n搜索结束，共找到 {found_cases} 个符合条件的病例。")

# 执行探针！展示前 5 个最典型的病例
visualize_pMCI_attention(vis_model, val_loader, DEVICE, num_cases_to_show=5)
# Out:
# 🔄 正在加载最佳模型权重...
# ✅ 成功加载权重: checkpoints/best_model.pth
# --------------------------------------------------
# 🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# ✅ 成功提取 5 组 pMCI 空间注意力图！
