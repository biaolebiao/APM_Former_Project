# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 71.95% 74.39%
# seed 3407 71.95% 75.61%
# seed 1234 73.17% 69.51%
# seed 98 71.95% 73.17%
# seed 20  69.51%
# seed 1024

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
UNFREEZE_EPOCH = 5  # 设定前 5 个 epoch 为阶段一
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 50
GRADIENT_ACCUMULATION_STEPS = 1
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SAVE_PATH = "checkpoints/best_mci_C.pth"
PRETRAINED_SWIN_PATH = "checkpoints/model_swinvit.pt"
SEED = 3407

set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-05-26 08:33:30,556 - Train - INFO - ==================================================
# 2026-05-26 08:33:30,557 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-05-26 08:33:30,558 - Train - INFO - ==================================================
# 2026-05-26 08:33:30,559 - Train - INFO - ▶ 随机种子 (SEED): 3407
# 2026-05-26 08:33:30,560 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-05-26 08:33:30,560 - Train - INFO - ▶ 预热轮数 (Warmup Epochs): 5
# 2026-05-26 08:33:30,561 - Train - INFO - ▶ 批次大小 (Batch Size): 2
# 2026-05-26 08:33:30,562 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-05-26 08:33:30,563 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-05-26 08:33:30,563 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-05-26 08:33:30,564 - Train - INFO - ==================================================
# 2026-05-26 08:33:30,566 - Train - INFO - 训练设备: cuda
# 2026-05-26 08:33:30,567 - Train - INFO - 批次大小: 2
# 2026-05-26 08:33:30,568 - Train - INFO - 总轮数: 50

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS,
    use_sampler=False
)
# Out:
# 2026-05-26 08:33:30,615 - Train - INFO - 正在加载数据集...
# 2026-05-26 08:33:30,623 - utils.dataset - INFO - ✅ 成功加载 82 个样本
# 2026-05-26 08:33:30,624 - utils.dataset - INFO - 🧪 启用【原生数据分布 (Shuffle) + 基础增强】策略
# 2026-05-26 08:33:30,653 - utils.dataset - INFO - ✅ 成功加载 656 个样本
# 2026-05-26 08:33:30,654 - utils.dataset - INFO - 训练集批次: 328，验证集批次: 41

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model = APM_Former_ImageOnly(
    img_size=TRAIN_IMG_SIZE,
    in_channels=1,
    num_classes=NUM_CLASSES,
    feature_size=FEATURE_SIZE,
    guide_channels=GUIDE_CHANNELS,
    pretrained_swin_path=PRETRAINED_SWIN_PATH,
    use_anatomy_prior=True,
    use_dcn_alignment=True
).to(DEVICE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-05-26 08:33:30,696 - Train - INFO - 初始化 APM-Former 模型...
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-05-26 08:33:31,937 - Train - INFO - 模型总参数量: 16.32 M

# %%
# 5. 损失函数 + 两阶段优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR

# ==========================================
# 损失函数 (保持你原来的完美配置不变)
# ==========================================
# weights = torch.tensor([1.0, 1.755]).to(DEVICE) 
weights = torch.tensor([1.0, 2.5]).to(DEVICE)
criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)

# ==========================================
# 两阶段训练：阶段一 (冻结主干)
# ==========================================

# 1. 冻结 Swin 主干网络
logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
for name, param in model.named_parameters():
    if "swin_backbone" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

# 2. 定义优化器：极其重要！这里加了 filter，只把没冻结的参数交给优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# 3. 阶段一的调度器：不需要预热，直接用 5 个 epoch 的余弦退火
scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
# Out:
# 2026-05-26 08:33:31,992 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 对比实验：增加TV Loss
def total_variation_loss_3d(displacement_field):
    """
    计算 3D 形变场的 TV Loss，促使相邻像素的偏移方向和幅度保持平滑
    displacement_field shape: (Batch_size, 3, Depth, Height, Width)
    """
    # 计算三个空间维度的梯度（相邻体素的差值绝对值）
    d_diff = torch.abs(displacement_field[:, :, 1:, :, :] - displacement_field[:, :, :-1, :, :])
    h_diff = torch.abs(displacement_field[:, :, :, 1:, :] - displacement_field[:, :, :, :-1, :])
    w_diff = torch.abs(displacement_field[:, :, :, :, 1:] - displacement_field[:, :, :, :, :-1])
    
    # 将三个方向的平滑度误差求平均并相加
    tv_loss = torch.mean(d_diff) + torch.mean(h_diff) + torch.mean(w_diff)
    return tv_loss

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0
    tv_weight = 0

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _, displacement_field = model(images)
        cls_loss = criterion(logits, labels.unsqueeze(1))
        # 增加tv_loss
        tv_loss = total_variation_loss_3d(displacement_field)

        loss = cls_loss + tv_loss *tv_weight

        loss = loss / accum_steps

        loss.backward()
        # 👇 就在 optimizer.step() 之前，加入这行“梯度裁剪”代码！
        # max_norm=1.0 或 2.0 是最常用的安全值
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc

from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    # correct = 0
    # total = 0
    all_preds = []
    all_labels = []
    all_probs = []  # 🌟 新增：专门用于收集预测为 pMCI 的概率，计算 AUC 必须用

    for images, labels in loader: 
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1)) # 如果用的是交叉熵，这里不用 unsqueeze

        total_loss += loss.item()
        
        # 获取预测类别 (0 或 1)
        preds = torch.argmax(logits, dim=1)
        
        # 🌟 获取预测为类别 1 (pMCI) 的概率
        probs = F.softmax(logits, dim=1)[:, 1] 
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    # ==========================
    # 🌟 计算所有医学黄金指标
    # ==========================
    acc = accuracy_score(all_labels, all_preds) * 100
    precision = precision_score(all_labels, all_preds, pos_label=1, zero_division=0) * 100
    sen = recall_score(all_labels, all_preds, pos_label=1) * 100  # Sensitivity / Recall
    spe = recall_score(all_labels, all_preds, pos_label=0) * 100  # Specificity (反向召回)
    f1 = f1_score(all_labels, all_preds, pos_label=1,zero_division=0) * 100
    
    # 计算 AUC (注意：有些 batch 如果只有一个类别会报错，这里做了容错)
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    
    # 打印超级豪华版日志
    logger.info(f"👉 混淆矩阵: [类0正确: {cm[0][0]}, 误判为类1: {cm[0][1]}] | [类1漏判: {cm[1][0]}, 类1正确: {cm[1][1]}]")
    logger.info(f"🏆 评估指标: ACC: {acc:.2f}% | Precision: {precision:.2f}% | SEN/Recall: {sen:.2f}% | SPE: {spe:.2f}% | F1: {f1:.2f}% | AUC: {auc:.2f}%")
    return avg_loss, acc, auc

# %%
# 7. 主训练循环
best_val_acc = 0.0
logger.info("=" * 50)
logger.info("开始训练！")
logger.info("=" * 50)

for epoch in range(NUM_EPOCHS):
    # 👇 ================= 新增：解冻机关 ================= 👇
    if epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 重新定义优化器（包含主干网络），并大幅降低学习率来保护老专家！
        # 这里用 1e-4 或 5e-5 进行微调最合适
        optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    val_loss, val_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    scheduler.step()

    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {val_acc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), SAVE_PATH)
        logger.info(f"✅ 最佳模型已保存！最佳验证准确率: {best_val_acc:.2f}%")

logger.info("\n🎉 训练完成！")
logger.info(f"最终最佳验证准确率: {best_val_acc:.2f}%")
# Out:
# 2026-05-26 08:33:32,126 - Train - INFO - ==================================================
# 2026-05-26 08:33:32,127 - Train - INFO - 开始训练！
# 2026-05-26 08:33:32,129 - Train - INFO - ==================================================
# 2026-05-26 08:33:32,130 - Train - INFO -
# Epoch [1/50]
# 训练中: 100%|██████████| 328/328 [01:26<00:00,  3.80it/s]
# 2026-05-26 08:35:10,065 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:35:10,067 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 59.23%
# 2026-05-26 08:35:10,068 - Train - INFO - 训练损失: 0.2985 | 训练准确率: 61.43%
# 2026-05-26 08:35:10,069 - Train - INFO - 验证损失: 0.2896 | 验证准确率: 63.41%
# 2026-05-26 08:35:10,070 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-26 08:35:11,210 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 63.41%
# 2026-05-26 08:35:11,212 - Train - INFO -
# Epoch [2/50]
# 训练中: 100%|██████████| 328/328 [01:23<00:00,  3.94it/s]
# 2026-05-26 08:36:45,145 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:36:45,147 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 63.46%
# 2026-05-26 08:36:45,148 - Train - INFO - 训练损失: 0.2940 | 训练准确率: 63.72%
# 2026-05-26 08:36:45,149 - Train - INFO - 验证损失: 0.2903 | 验证准确率: 63.41%
# 2026-05-26 08:36:45,150 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-26 08:36:45,150 - Train - INFO -
# Epoch [3/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.97it/s]
# 2026-05-26 08:38:17,915 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:38:17,917 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 60.51%
# 2026-05-26 08:38:17,919 - Train - INFO - 训练损失: 0.2906 | 训练准确率: 63.72%
# 2026-05-26 08:38:17,919 - Train - INFO - 验证损失: 0.2891 | 验证准确率: 63.41%
# 2026-05-26 08:38:17,921 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-26 08:38:17,921 - Train - INFO -
# Epoch [4/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.08it/s]
# 2026-05-26 08:39:49,175 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:39:49,177 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.56%
# 2026-05-26 08:39:49,179 - Train - INFO - 训练损失: 0.2929 | 训练准确率: 63.72%
# 2026-05-26 08:39:49,180 - Train - INFO - 验证损失: 0.2893 | 验证准确率: 63.41%
# 2026-05-26 08:39:49,181 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-26 08:39:49,182 - Train - INFO -
# Epoch [5/50]
# 训练中: 100%|██████████| 328/328 [01:25<00:00,  3.85it/s]
# 2026-05-26 08:41:24,663 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:41:24,665 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 65.00%
# 2026-05-26 08:41:24,667 - Train - INFO - 训练损失: 0.2907 | 训练准确率: 63.72%
# 2026-05-26 08:41:24,668 - Train - INFO - 验证损失: 0.2891 | 验证准确率: 63.41%
# 2026-05-26 08:41:24,669 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-26 08:41:24,670 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-26 08:41:24,671 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！
# 2026-05-26 08:41:24,672 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-26 08:41:24,677 - Train - INFO -
# Epoch [6/50]
# 训练中: 100%|██████████| 328/328 [01:28<00:00,  3.72it/s]
# 2026-05-26 08:43:03,538 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:43:03,540 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 64.55%
# 2026-05-26 08:43:03,541 - Train - INFO - 训练损失: 0.3013 | 训练准确率: 62.65%
# 2026-05-26 08:43:03,542 - Train - INFO - 验证损失: 0.2900 | 验证准确率: 63.41%
# 2026-05-26 08:43:03,543 - Train - INFO - 当前学习率: 0.00029963
# 2026-05-26 08:43:03,544 - Train - INFO -
# Epoch [7/50]
# 训练中: 100%|██████████| 328/328 [01:23<00:00,  3.92it/s]
# 2026-05-26 08:44:37,193 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:44:37,195 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.24%
# 2026-05-26 08:44:37,196 - Train - INFO - 训练损失: 0.2933 | 训练准确率: 63.72%
# 2026-05-26 08:44:37,197 - Train - INFO - 验证损失: 0.2899 | 验证准确率: 63.41%
# 2026-05-26 08:44:37,198 - Train - INFO - 当前学习率: 0.00029854
# 2026-05-26 08:44:37,198 - Train - INFO -
# Epoch [8/50]
# 训练中: 100%|██████████| 328/328 [01:24<00:00,  3.87it/s]
# 2026-05-26 08:46:12,638 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:46:12,640 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 58.91%
# 2026-05-26 08:46:12,641 - Train - INFO - 训练损失: 0.2929 | 训练准确率: 63.72%
# 2026-05-26 08:46:12,642 - Train - INFO - 验证损失: 0.2891 | 验证准确率: 63.41%
# 2026-05-26 08:46:12,643 - Train - INFO - 当前学习率: 0.00029672
# 2026-05-26 08:46:12,643 - Train - INFO -
# Epoch [9/50]
# 训练中: 100%|██████████| 328/328 [01:25<00:00,  3.85it/s]
# 2026-05-26 08:47:48,479 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:47:48,481 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 61.09%
# 2026-05-26 08:47:48,483 - Train - INFO - 训练损失: 0.2910 | 训练准确率: 63.72%
# 2026-05-26 08:47:48,483 - Train - INFO - 验证损失: 0.2900 | 验证准确率: 63.41%
# 2026-05-26 08:47:48,484 - Train - INFO - 当前学习率: 0.00029419
# 2026-05-26 08:47:48,485 - Train - INFO -
# Epoch [10/50]
# 训练中: 100%|██████████| 328/328 [01:26<00:00,  3.79it/s]
# 2026-05-26 08:49:26,719 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:49:26,721 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 59.29%
# 2026-05-26 08:49:26,722 - Train - INFO - 训练损失: 0.2911 | 训练准确率: 63.72%
# 2026-05-26 08:49:26,723 - Train - INFO - 验证损失: 0.2902 | 验证准确率: 63.41%
# 2026-05-26 08:49:26,724 - Train - INFO - 当前学习率: 0.00029095
# 2026-05-26 08:49:26,725 - Train - INFO -
# Epoch [11/50]
# 训练中: 100%|██████████| 328/328 [01:28<00:00,  3.69it/s]
# 2026-05-26 08:51:06,139 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:51:06,142 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 59.81%
# 2026-05-26 08:51:06,143 - Train - INFO - 训练损失: 0.2900 | 训练准确率: 63.72%
# 2026-05-26 08:51:06,144 - Train - INFO - 验证损失: 0.2897 | 验证准确率: 63.41%
# 2026-05-26 08:51:06,145 - Train - INFO - 当前学习率: 0.00028703
# 2026-05-26 08:51:06,146 - Train - INFO -
# Epoch [12/50]
# 训练中: 100%|██████████| 328/328 [01:28<00:00,  3.71it/s]
# 2026-05-26 08:52:45,516 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:52:45,518 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 65.90%
# 2026-05-26 08:52:45,520 - Train - INFO - 训练损失: 0.2887 | 训练准确率: 63.72%
# 2026-05-26 08:52:45,521 - Train - INFO - 验证损失: 0.2867 | 验证准确率: 63.41%
# 2026-05-26 08:52:45,521 - Train - INFO - 当前学习率: 0.00028244
# 2026-05-26 08:52:45,523 - Train - INFO -
# Epoch [13/50]
# 训练中: 100%|██████████| 328/328 [01:26<00:00,  3.81it/s]
# 2026-05-26 08:54:22,628 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:54:22,630 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 65.13%
# 2026-05-26 08:54:22,632 - Train - INFO - 训练损失: 0.2871 | 训练准确率: 63.72%
# 2026-05-26 08:54:22,632 - Train - INFO - 验证损失: 0.2948 | 验证准确率: 63.41%
# 2026-05-26 08:54:22,633 - Train - INFO - 当前学习率: 0.00027721
# 2026-05-26 08:54:22,634 - Train - INFO -
# Epoch [14/50]
# 训练中: 100%|██████████| 328/328 [01:25<00:00,  3.84it/s]
# 2026-05-26 08:55:58,898 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:55:58,901 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 65.64%
# 2026-05-26 08:55:58,903 - Train - INFO - 训练损失: 0.2909 | 训练准确率: 63.72%
# 2026-05-26 08:55:58,903 - Train - INFO - 验证损失: 0.2871 | 验证准确率: 63.41%
# 2026-05-26 08:55:58,904 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-26 08:55:58,905 - Train - INFO -
# Epoch [15/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.01it/s]
# 2026-05-26 08:57:32,381 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:57:32,383 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 52.31%
# 2026-05-26 08:57:32,385 - Train - INFO - 训练损失: 0.2831 | 训练准确率: 63.72%
# 2026-05-26 08:57:32,386 - Train - INFO - 验证损失: 0.2928 | 验证准确率: 63.41%
# 2026-05-26 08:57:32,387 - Train - INFO - 当前学习率: 0.00026491
# 2026-05-26 08:57:32,388 - Train - INFO -
# Epoch [16/50]
# 训练中: 100%|██████████| 328/328 [01:25<00:00,  3.83it/s]
# 2026-05-26 08:59:08,531 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:59:08,533 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 66.15%
# 2026-05-26 08:59:08,535 - Train - INFO - 训练损失: 0.2899 | 训练准确率: 63.72%
# 2026-05-26 08:59:08,536 - Train - INFO - 验证损失: 0.2864 | 验证准确率: 63.41%
# 2026-05-26 08:59:08,537 - Train - INFO - 当前学习率: 0.00025790
# 2026-05-26 08:59:08,538 - Train - INFO -
# Epoch [17/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.05it/s]
# 2026-05-26 09:00:40,801 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 09:00:40,803 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.22%
# 2026-05-26 09:00:40,805 - Train - INFO - 训练损失: 0.2878 | 训练准确率: 63.72%
# 2026-05-26 09:00:40,806 - Train - INFO - 验证损失: 0.2813 | 验证准确率: 63.41%
# 2026-05-26 09:00:40,807 - Train - INFO - 当前学习率: 0.00025037
# 2026-05-26 09:00:40,808 - Train - INFO -
# Epoch [18/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.01it/s]
# 2026-05-26 09:02:12,921 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 09:02:12,923 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.73%
# 2026-05-26 09:02:12,925 - Train - INFO - 训练损失: 0.2851 | 训练准确率: 63.72%
# 2026-05-26 09:02:12,925 - Train - INFO - 验证损失: 0.2903 | 验证准确率: 63.41%
# 2026-05-26 09:02:12,926 - Train - INFO - 当前学习率: 0.00024235
# 2026-05-26 09:02:12,927 - Train - INFO -
# Epoch [19/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.01it/s]
# 2026-05-26 09:03:45,224 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 09:03:45,227 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 70.38%
# 2026-05-26 09:03:45,228 - Train - INFO - 训练损失: 0.3068 | 训练准确率: 63.72%
# 2026-05-26 09:03:45,229 - Train - INFO - 验证损失: 0.4669 | 验证准确率: 63.41%
# 2026-05-26 09:03:45,230 - Train - INFO - 当前学习率: 0.00023388
# 2026-05-26 09:03:45,230 - Train - INFO -
# Epoch [20/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.03it/s]
# 2026-05-26 09:05:16,902 - Train - INFO - 👉 混淆矩阵: [类0正确: 46, 误判为类1: 6] | [类1漏判: 19, 类1正确: 11]
# 2026-05-26 09:05:16,903 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 64.71% | SEN/Recall: 36.67% | SPE: 88.46% | F1: 46.81% | AUC: 73.97%
# 2026-05-26 09:05:16,905 - Train - INFO - 训练损失: 0.3044 | 训练准确率: 63.87%
# 2026-05-26 09:05:16,906 - Train - INFO - 验证损失: 0.2597 | 验证准确率: 69.51%
# 2026-05-26 09:05:16,907 - Train - INFO - 当前学习率: 0.00022500
# 2026-05-26 09:05:18,125 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 69.51%
# 2026-05-26 09:05:18,126 - Train - INFO -
# Epoch [21/50]
# 训练中: 100%|██████████| 328/328 [01:23<00:00,  3.92it/s]
# 2026-05-26 09:06:51,913 - Train - INFO - 👉 混淆矩阵: [类0正确: 50, 误判为类1: 2] | [类1漏判: 28, 类1正确: 2]
# 2026-05-26 09:06:51,915 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 50.00% | SEN/Recall: 6.67% | SPE: 96.15% | F1: 11.76% | AUC: 73.33%
# 2026-05-26 09:06:51,917 - Train - INFO - 训练损失: 0.2843 | 训练准确率: 66.77%
# 2026-05-26 09:06:51,918 - Train - INFO - 验证损失: 0.3507 | 验证准确率: 63.41%
# 2026-05-26 09:06:51,918 - Train - INFO - 当前学习率: 0.00021576
# 2026-05-26 09:06:51,919 - Train - INFO -
# Epoch [22/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.06it/s]
# 2026-05-26 09:08:22,594 - Train - INFO - 👉 混淆矩阵: [类0正确: 23, 误判为类1: 29] | [类1漏判: 6, 类1正确: 24]
# 2026-05-26 09:08:22,597 - Train - INFO - 🏆 评估指标: ACC: 57.32% | Precision: 45.28% | SEN/Recall: 80.00% | SPE: 44.23% | F1: 57.83% | AUC: 73.85%
# 2026-05-26 09:08:22,599 - Train - INFO - 训练损失: 0.3043 | 训练准确率: 67.38%
# 2026-05-26 09:08:22,599 - Train - INFO - 验证损失: 0.2825 | 验证准确率: 57.32%
# 2026-05-26 09:08:22,600 - Train - INFO - 当前学习率: 0.00020619
# 2026-05-26 09:08:22,601 - Train - INFO -
# Epoch [23/50]
# 训练中: 100%|██████████| 328/328 [01:23<00:00,  3.93it/s]
# 2026-05-26 09:09:56,712 - Train - INFO - 👉 混淆矩阵: [类0正确: 49, 误判为类1: 3] | [类1漏判: 25, 类1正确: 5]
# 2026-05-26 09:09:56,714 - Train - INFO - 🏆 评估指标: ACC: 65.85% | Precision: 62.50% | SEN/Recall: 16.67% | SPE: 94.23% | F1: 26.32% | AUC: 73.91%
# 2026-05-26 09:09:56,715 - Train - INFO - 训练损失: 0.3127 | 训练准确率: 67.68%
# 2026-05-26 09:09:56,716 - Train - INFO - 验证损失: 0.3129 | 验证准确率: 65.85%
# 2026-05-26 09:09:56,717 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-26 09:09:56,718 - Train - INFO -
# Epoch [24/50]
# 训练中: 100%|██████████| 328/328 [01:26<00:00,  3.78it/s]
# 2026-05-26 09:11:34,234 - Train - INFO - 👉 混淆矩阵: [类0正确: 37, 误判为类1: 15] | [类1漏判: 8, 类1正确: 22]
# 2026-05-26 09:11:34,236 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 59.46% | SEN/Recall: 73.33% | SPE: 71.15% | F1: 65.67% | AUC: 74.68%
# 2026-05-26 09:11:34,238 - Train - INFO - 训练损失: 0.3008 | 训练准确率: 69.66%
# 2026-05-26 09:11:34,238 - Train - INFO - 验证损失: 0.2791 | 验证准确率: 71.95%
# 2026-05-26 09:11:34,239 - Train - INFO - 当前学习率: 0.00018629
# 2026-05-26 09:11:35,314 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 71.95%
# 2026-05-26 09:11:35,316 - Train - INFO -
# Epoch [25/50]
# 训练中: 100%|██████████| 328/328 [01:24<00:00,  3.87it/s]
# 2026-05-26 09:13:10,710 - Train - INFO - 👉 混淆矩阵: [类0正确: 23, 误判为类1: 29] | [类1漏判: 6, 类1正确: 24]
# 2026-05-26 09:13:10,712 - Train - INFO - 🏆 评估指标: ACC: 57.32% | Precision: 45.28% | SEN/Recall: 80.00% | SPE: 44.23% | F1: 57.83% | AUC: 74.17%
# 2026-05-26 09:13:10,715 - Train - INFO - 训练损失: 0.2823 | 训练准确率: 68.75%
# 2026-05-26 09:13:10,716 - Train - INFO - 验证损失: 0.3397 | 验证准确率: 57.32%
# 2026-05-26 09:13:10,717 - Train - INFO - 当前学习率: 0.00017605
# 2026-05-26 09:13:10,718 - Train - INFO -
# Epoch [26/50]
# 训练中: 100%|██████████| 328/328 [01:25<00:00,  3.86it/s]
# 2026-05-26 09:14:46,035 - Train - INFO - 👉 混淆矩阵: [类0正确: 41, 误判为类1: 11] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 09:14:46,037 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.71% | SEN/Recall: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 74.04%
# 2026-05-26 09:14:46,038 - Train - INFO - 训练损失: 0.3119 | 训练准确率: 68.75%
# 2026-05-26 09:14:46,039 - Train - INFO - 验证损失: 0.2640 | 验证准确率: 70.73%
# 2026-05-26 09:14:46,040 - Train - INFO - 当前学习率: 0.00016568
# 2026-05-26 09:14:46,041 - Train - INFO -
# Epoch [27/50]
# 训练中: 100%|██████████| 328/328 [01:29<00:00,  3.67it/s]
# 2026-05-26 09:16:26,610 - Train - INFO - 👉 混淆矩阵: [类0正确: 44, 误判为类1: 8] | [类1漏判: 15, 类1正确: 15]
# 2026-05-26 09:16:26,613 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 65.22% | SEN/Recall: 50.00% | SPE: 84.62% | F1: 56.60% | AUC: 74.36%
# 2026-05-26 09:16:26,614 - Train - INFO - 训练损失: 0.3189 | 训练准确率: 66.92%
# 2026-05-26 09:16:26,615 - Train - INFO - 验证损失: 0.2698 | 验证准确率: 71.95%
# 2026-05-26 09:16:26,616 - Train - INFO - 当前学习率: 0.00015523
# 2026-05-26 09:16:26,617 - Train - INFO -
# Epoch [28/50]
# 训练中: 100%|██████████| 328/328 [01:27<00:00,  3.76it/s]
# 2026-05-26 09:18:04,156 - Train - INFO - 👉 混淆矩阵: [类0正确: 50, 误判为类1: 2] | [类1漏判: 26, 类1正确: 4]
# 2026-05-26 09:18:04,158 - Train - INFO - 🏆 评估指标: ACC: 65.85% | Precision: 66.67% | SEN/Recall: 13.33% | SPE: 96.15% | F1: 22.22% | AUC: 74.17%
# 2026-05-26 09:18:04,160 - Train - INFO - 训练损失: 0.3082 | 训练准确率: 68.45%
# 2026-05-26 09:18:04,161 - Train - INFO - 验证损失: 0.3567 | 验证准确率: 65.85%
# 2026-05-26 09:18:04,162 - Train - INFO - 当前学习率: 0.00014477
# 2026-05-26 09:18:04,163 - Train - INFO -
# Epoch [29/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.96it/s]
# 2026-05-26 09:19:37,855 - Train - INFO - 👉 混淆矩阵: [类0正确: 42, 误判为类1: 10] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 09:19:37,856 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 62.96% | SEN/Recall: 56.67% | SPE: 80.77% | F1: 59.65% | AUC: 73.78%
# 2026-05-26 09:19:37,856 - Train - INFO - 训练损失: 0.3193 | 训练准确率: 70.43%
# 2026-05-26 09:19:37,856 - Train - INFO - 验证损失: 0.2951 | 验证准确率: 71.95%
# 2026-05-26 09:19:37,857 - Train - INFO - 当前学习率: 0.00013432
# 2026-05-26 09:19:37,857 - Train - INFO -
# Epoch [30/50]
# 训练中: 100%|██████████| 328/328 [01:28<00:00,  3.73it/s]
# 2026-05-26 09:21:17,936 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 09:21:17,939 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.62% | SEN/Recall: 56.67% | SPE: 76.92% | F1: 57.63% | AUC: 73.72%
# 2026-05-26 09:21:17,940 - Train - INFO - 训练损失: 0.3237 | 训练准确率: 69.36%
# 2026-05-26 09:21:17,941 - Train - INFO - 验证损失: 0.2948 | 验证准确率: 69.51%
# 2026-05-26 09:21:17,942 - Train - INFO - 当前学习率: 0.00012395
# 2026-05-26 09:21:17,943 - Train - INFO -
# Epoch [31/50]
# 训练中: 100%|██████████| 328/328 [01:29<00:00,  3.67it/s]
# 2026-05-26 09:22:58,078 - Train - INFO - 👉 混淆矩阵: [类0正确: 43, 误判为类1: 9] | [类1漏判: 16, 类1正确: 14]
# 2026-05-26 09:22:58,079 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 60.87% | SEN/Recall: 46.67% | SPE: 82.69% | F1: 52.83% | AUC: 73.59%
# 2026-05-26 09:22:58,081 - Train - INFO - 训练损失: 0.3299 | 训练准确率: 69.82%
# 2026-05-26 09:22:58,082 - Train - INFO - 验证损失: 0.2992 | 验证准确率: 69.51%
# 2026-05-26 09:22:58,083 - Train - INFO - 当前学习率: 0.00011371
# 2026-05-26 09:22:58,084 - Train - INFO -
# Epoch [32/50]
# 训练中: 100%|██████████| 328/328 [01:25<00:00,  3.83it/s]
# 2026-05-26 09:24:34,033 - Train - INFO - 👉 混淆矩阵: [类0正确: 34, 误判为类1: 18] | [类1漏判: 8, 类1正确: 22]
# 2026-05-26 09:24:34,035 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 55.00% | SEN/Recall: 73.33% | SPE: 65.38% | F1: 62.86% | AUC: 74.10%
# 2026-05-26 09:24:34,036 - Train - INFO - 训练损失: 0.3154 | 训练准确率: 72.26%
# 2026-05-26 09:24:34,037 - Train - INFO - 验证损失: 0.3088 | 验证准确率: 68.29%
# 2026-05-26 09:24:34,038 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-26 09:24:34,039 - Train - INFO -
# Epoch [33/50]
# 训练中: 100%|██████████| 328/328 [01:24<00:00,  3.89it/s]
# 2026-05-26 09:26:09,749 - Train - INFO - 👉 混淆矩阵: [类0正确: 41, 误判为类1: 11] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 09:26:09,750 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 59.26% | SEN/Recall: 53.33% | SPE: 78.85% | F1: 56.14% | AUC: 73.78%
# 2026-05-26 09:26:09,751 - Train - INFO - 训练损失: 0.3065 | 训练准确率: 70.43%
# 2026-05-26 09:26:09,752 - Train - INFO - 验证损失: 0.3110 | 验证准确率: 69.51%
# 2026-05-26 09:26:09,753 - Train - INFO - 当前学习率: 0.00009381
# 2026-05-26 09:26:09,754 - Train - INFO -
# Epoch [34/50]
# 训练中: 100%|██████████| 328/328 [01:28<00:00,  3.71it/s]
# 2026-05-26 09:27:48,942 - Train - INFO - 👉 混淆矩阵: [类0正确: 41, 误判为类1: 11] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 09:27:48,944 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 59.26% | SEN/Recall: 53.33% | SPE: 78.85% | F1: 56.14% | AUC: 74.29%
# 2026-05-26 09:27:48,946 - Train - INFO - 训练损失: 0.3379 | 训练准确率: 70.43%
# 2026-05-26 09:27:48,946 - Train - INFO - 验证损失: 0.3111 | 验证准确率: 69.51%
# 2026-05-26 09:27:48,947 - Train - INFO - 当前学习率: 0.00008424
# 2026-05-26 09:27:48,948 - Train - INFO -
# Epoch [35/50]
# 训练中: 100%|██████████| 328/328 [01:23<00:00,  3.91it/s]
# 2026-05-26 09:29:23,951 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 10, 类1正确: 20]
# 2026-05-26 09:29:23,954 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 58.82% | SEN/Recall: 66.67% | SPE: 73.08% | F1: 62.50% | AUC: 74.17%
# 2026-05-26 09:29:23,955 - Train - INFO - 训练损失: 0.3136 | 训练准确率: 69.51%
# 2026-05-26 09:29:23,956 - Train - INFO - 验证损失: 0.3017 | 验证准确率: 70.73%
# 2026-05-26 09:29:23,956 - Train - INFO - 当前学习率: 0.00007500
# 2026-05-26 09:29:23,957 - Train - INFO -
# Epoch [36/50]
# 训练中: 100%|██████████| 328/328 [01:26<00:00,  3.80it/s]
# 2026-05-26 09:31:02,087 - Train - INFO - 👉 混淆矩阵: [类0正确: 45, 误判为类1: 7] | [类1漏判: 16, 类1正确: 14]
# 2026-05-26 09:31:02,089 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 66.67% | SEN/Recall: 46.67% | SPE: 86.54% | F1: 54.90% | AUC: 74.04%
# 2026-05-26 09:31:02,091 - Train - INFO - 训练损失: 0.3000 | 训练准确率: 71.65%
# 2026-05-26 09:31:02,091 - Train - INFO - 验证损失: 0.3240 | 验证准确率: 71.95%
# 2026-05-26 09:31:02,092 - Train - INFO - 当前学习率: 0.00006612
# 2026-05-26 09:31:02,093 - Train - INFO -
# Epoch [37/50]
# 训练中: 100%|██████████| 328/328 [01:24<00:00,  3.88it/s]
# 2026-05-26 09:32:37,151 - Train - INFO - 👉 混淆矩阵: [类0正确: 42, 误判为类1: 10] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 09:32:37,153 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 61.54% | SEN/Recall: 53.33% | SPE: 80.77% | F1: 57.14% | AUC: 73.91%
# 2026-05-26 09:32:37,155 - Train - INFO - 训练损失: 0.3035 | 训练准确率: 72.26%
# 2026-05-26 09:32:37,157 - Train - INFO - 验证损失: 0.3116 | 验证准确率: 70.73%
# 2026-05-26 09:32:37,158 - Train - INFO - 当前学习率: 0.00005765
# 2026-05-26 09:32:37,159 - Train - INFO -
# Epoch [38/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.98it/s]
# 2026-05-26 09:34:10,698 - Train - INFO - 👉 混淆矩阵: [类0正确: 41, 误判为类1: 11] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 09:34:10,699 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.71% | SEN/Recall: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 74.62%
# 2026-05-26 09:34:10,700 - Train - INFO - 训练损失: 0.3228 | 训练准确率: 70.43%
# 2026-05-26 09:34:10,701 - Train - INFO - 验证损失: 0.2930 | 验证准确率: 70.73%
# 2026-05-26 09:34:10,701 - Train - INFO - 当前学习率: 0.00004963
# 2026-05-26 09:34:10,701 - Train - INFO -
# Epoch [39/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-26 09:35:42,008 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:35:42,010 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 57.58% | SEN/Recall: 63.33% | SPE: 73.08% | F1: 60.32% | AUC: 74.29%
# 2026-05-26 09:35:42,011 - Train - INFO - 训练损失: 0.3076 | 训练准确率: 71.19%
# 2026-05-26 09:35:42,012 - Train - INFO - 验证损失: 0.3141 | 验证准确率: 69.51%
# 2026-05-26 09:35:42,013 - Train - INFO - 当前学习率: 0.00004210
# 2026-05-26 09:35:42,013 - Train - INFO -
# Epoch [40/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.97it/s]
# 2026-05-26 09:37:15,682 - Train - INFO - 👉 混淆矩阵: [类0正确: 45, 误判为类1: 7] | [类1漏判: 16, 类1正确: 14]
# 2026-05-26 09:37:15,684 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 66.67% | SEN/Recall: 46.67% | SPE: 86.54% | F1: 54.90% | AUC: 74.29%
# 2026-05-26 09:37:15,686 - Train - INFO - 训练损失: 0.3085 | 训练准确率: 72.10%
# 2026-05-26 09:37:15,687 - Train - INFO - 验证损失: 0.3203 | 验证准确率: 71.95%
# 2026-05-26 09:37:15,687 - Train - INFO - 当前学习率: 0.00003509
# 2026-05-26 09:37:15,688 - Train - INFO -
# Epoch [41/50]
# 训练中: 100%|██████████| 328/328 [01:24<00:00,  3.90it/s]
# 2026-05-26 09:38:49,964 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:38:49,967 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.06% | SEN/Recall: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 74.74%
# 2026-05-26 09:38:49,968 - Train - INFO - 训练损失: 0.3254 | 训练准确率: 69.66%
# 2026-05-26 09:38:49,969 - Train - INFO - 验证损失: 0.3098 | 验证准确率: 69.51%
# 2026-05-26 09:38:49,970 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-26 09:38:49,971 - Train - INFO -
# Epoch [42/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.06it/s]
# 2026-05-26 09:40:21,880 - Train - INFO - 👉 混淆矩阵: [类0正确: 42, 误判为类1: 10] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 09:40:21,882 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 61.54% | SEN/Recall: 53.33% | SPE: 80.77% | F1: 57.14% | AUC: 74.94%
# 2026-05-26 09:40:21,884 - Train - INFO - 训练损失: 0.3099 | 训练准确率: 70.73%
# 2026-05-26 09:40:21,885 - Train - INFO - 验证损失: 0.3165 | 验证准确率: 70.73%
# 2026-05-26 09:40:21,886 - Train - INFO - 当前学习率: 0.00002279
# 2026-05-26 09:40:21,887 - Train - INFO -
# Epoch [43/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.04it/s]
# 2026-05-26 09:41:53,657 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:41:53,659 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.06% | SEN/Recall: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 74.81%
# 2026-05-26 09:41:53,661 - Train - INFO - 训练损失: 0.2972 | 训练准确率: 72.10%
# 2026-05-26 09:41:53,662 - Train - INFO - 验证损失: 0.3212 | 验证准确率: 69.51%
# 2026-05-26 09:41:53,662 - Train - INFO - 当前学习率: 0.00001756
# 2026-05-26 09:41:53,663 - Train - INFO -
# Epoch [44/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.04it/s]
# 2026-05-26 09:43:25,427 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:43:25,428 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.06% | SEN/Recall: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 75.06%
# 2026-05-26 09:43:25,430 - Train - INFO - 训练损失: 0.3002 | 训练准确率: 70.88%
# 2026-05-26 09:43:25,431 - Train - INFO - 验证损失: 0.3178 | 验证准确率: 69.51%
# 2026-05-26 09:43:25,431 - Train - INFO - 当前学习率: 0.00001297
# 2026-05-26 09:43:25,432 - Train - INFO -
# Epoch [45/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.98it/s]
# 2026-05-26 09:44:58,179 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:44:58,181 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 74.94%
# 2026-05-26 09:44:58,183 - Train - INFO - 训练损失: 0.2914 | 训练准确率: 71.95%
# 2026-05-26 09:44:58,183 - Train - INFO - 验证损失: 0.3199 | 验证准确率: 70.73%
# 2026-05-26 09:44:58,184 - Train - INFO - 当前学习率: 0.00000905
# 2026-05-26 09:44:58,185 - Train - INFO -
# Epoch [46/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.11it/s]
# 2026-05-26 09:46:28,684 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:46:28,686 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 74.94%
# 2026-05-26 09:46:28,688 - Train - INFO - 训练损失: 0.3100 | 训练准确率: 71.95%
# 2026-05-26 09:46:28,688 - Train - INFO - 验证损失: 0.3219 | 验证准确率: 70.73%
# 2026-05-26 09:46:28,689 - Train - INFO - 当前学习率: 0.00000581
# 2026-05-26 09:46:28,690 - Train - INFO -
# Epoch [47/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.12it/s]
# 2026-05-26 09:47:58,253 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:47:58,258 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.06% | SEN/Recall: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 75.06%
# 2026-05-26 09:47:58,260 - Train - INFO - 训练损失: 0.3067 | 训练准确率: 72.41%
# 2026-05-26 09:47:58,261 - Train - INFO - 验证损失: 0.3239 | 验证准确率: 69.51%
# 2026-05-26 09:47:58,262 - Train - INFO - 当前学习率: 0.00000328
# 2026-05-26 09:47:58,264 - Train - INFO -
# Epoch [48/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.20it/s]
# 2026-05-26 09:49:26,117 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:49:26,120 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 74.94%
# 2026-05-26 09:49:26,122 - Train - INFO - 训练损失: 0.2965 | 训练准确率: 71.49%
# 2026-05-26 09:49:26,123 - Train - INFO - 验证损失: 0.3231 | 验证准确率: 70.73%
# 2026-05-26 09:49:26,123 - Train - INFO - 当前学习率: 0.00000146
# 2026-05-26 09:49:26,124 - Train - INFO -
# Epoch [49/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.34it/s]
# 2026-05-26 09:50:51,108 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:50:51,110 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.06% | SEN/Recall: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 75.00%
# 2026-05-26 09:50:51,112 - Train - INFO - 训练损失: 0.3019 | 训练准确率: 71.49%
# 2026-05-26 09:50:51,113 - Train - INFO - 验证损失: 0.3227 | 验证准确率: 69.51%
# 2026-05-26 09:50:51,113 - Train - INFO - 当前学习率: 0.00000037
# 2026-05-26 09:50:51,115 - Train - INFO -
# Epoch [50/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-05-26 09:52:16,694 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:52:16,697 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.06% | SEN/Recall: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 75.00%
# 2026-05-26 09:52:16,700 - Train - INFO - 训练损失: 0.2984 | 训练准确率: 71.95%
# 2026-05-26 09:52:16,701 - Train - INFO - 验证损失: 0.3230 | 验证准确率: 69.51%
# 2026-05-26 09:52:16,702 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-26 09:52:16,704 - Train - INFO -
# 🎉 训练完成！
# 2026-05-26 09:52:16,705 - Train - INFO - 最终最佳验证准确率: 71.95%

# %%
# import torch
# import torch.nn.functional as F
# import numpy as np
# import matplotlib.pyplot as plt

# # ==========================================
# # 第一步：加载你跑出 74.39% 的最佳模型权重
# # ==========================================
# print("🔄 正在加载最佳模型权重...")

# # 实例化模型 (确保这里的参数和你跑出最好成绩的那次完全一致)
# # 之前确认过 FEATURE_SIZE 是 24
# vis_model = APM_Former_ImageOnly(
#     feature_size=24,  
#     num_classes=2
# ).to(DEVICE)

# # ⚠️ 注意：把这里的 'best_model.pth' 换成你实际保存的权重文件名！
# # 比如可能是 'checkpoint_epoch_xx.pth'
# checkpoint_path = 'checkpoints/best_3407model2.pth'  
# state_dict = torch.load(checkpoint_path, map_location=DEVICE)
# vis_model.load_state_dict(state_dict)

# vis_model.eval() # 切换到评估模式
# print(f"✅ 成功加载权重: {checkpoint_path}")
# print("-" * 50)


# # ==========================================
# # 第二步：定义并运行可视化探针
# # ==========================================
# @torch.no_grad()
# def visualize_pMCI_attention(model, val_loader, device, num_cases_to_show=3):
#     model.eval()
#     found_cases = 0
    
#     # 解决 matplotlib 中文显示问题
#     # plt.rcParams['font.sans-serif'] = ['SimHei'] 
#     # plt.rcParams['axes.unicode_minus'] = False
    
#     print("🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...\n")
    
#     for images, labels in val_loader:
#         images = images.to(device)
#         labels = labels.to(device)
        
#         logits, _, spatial_attention = model(images)
#         preds = torch.argmax(logits, dim=1)
        
#         # 寻找 True Positives (真实为pMCI，预测也为pMCI)
#         for i in range(len(labels)):
#             if labels[i].item() == 1 and preds[i].item() == 1:
#                 found_cases += 1
                
#                 # 1. 提取原始 3D MRI 图像
#                 img_3d = images[i, 0].cpu().numpy()  
                
#                 # 2. 提取注意力掩码，并插值放大到原始图像大小 (96, 96, 96)
#                 attn_tensor = spatial_attention[i:i+1] 
#                 attn_resized = F.interpolate(attn_tensor, size=img_3d.shape, mode='trilinear', align_corners=False)
#                 attn_3d = attn_resized[0, 0].cpu().numpy()
                
#                 # 3. 智能寻找网络最关注的切片位置
#                 slice_x = np.argmax(np.sum(attn_3d, axis=(1, 2))) 
#                 slice_y = np.argmax(np.sum(attn_3d, axis=(0, 2))) 
#                 slice_z = np.argmax(np.sum(attn_3d, axis=(0, 1))) 
                
#                 # 4. 绘图
#                 fig, axes = plt.subplots(1, 3, figsize=(18, 6))
#                 # 成功识别的pMCI阳性病例  高亮区域为网络空间对齐中点关注区域
#                 fig.suptitle(f"True Positive pMCI Case #{found_cases}\n(Spatial Attention Guided Alignment)", fontsize=18, fontweight='bold', y=1.05)
                
#                 # 矢状面 矢状面切片
#                 axes[0].imshow(img_3d[slice_x, :, :], cmap='gray') 
#                 im = axes[0].imshow(attn_3d[slice_x, :, :], cmap='jet', alpha=0.45) 
#                 axes[0].set_title(f"Sagittal View (Slice {slice_x})", fontsize=14)
#                 axes[0].axis('off')
                
#                 # 冠状面 冠状面切片
#                 axes[1].imshow(img_3d[:, slice_y, :], cmap='gray')
#                 axes[1].imshow(attn_3d[:, slice_y, :], cmap='jet', alpha=0.45)
#                 axes[1].set_title(f"Coronal View (Slice {slice_y})", fontsize=14)
#                 axes[1].axis('off')
                
#                 # 轴状面 轴状面切片
#                 axes[2].imshow(img_3d[:, :, slice_z], cmap='gray')
#                 axes[2].imshow(attn_3d[:, :, slice_z], cmap='jet', alpha=0.45)
#                 axes[2].set_title(f"Axial View (Slice {slice_z})", fontsize=14)
#                 axes[2].axis('off')
                
#                 # 颜色条的标签 解剖引导强度
#                 cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
#                 cbar.set_label('Attention Weight', fontsize=12)
                
#                 plt.show()
                
#                 if found_cases >= num_cases_to_show:
#                     print(f"\n✅ 成功提取 {num_cases_to_show} 组 pMCI 空间注意力图！")
#                     return

#     print(f"\n搜索结束，共找到 {found_cases} 个符合条件的病例。")

# # 执行探针！展示前 5 个最典型的病例
# visualize_pMCI_attention(vis_model, val_loader, DEVICE, num_cases_to_show=5)
