# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 71.95% 74.39%
# seed 3407 71.95% 75.61%
# seed 1234 73.17% 69.51%
# seed 98 71.95% 73.17%
# seed 20  69.51%
# seed 1024

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
UNFREEZE_EPOCH = 5  # 设定前 5 个 epoch 为阶段一
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 50
GRADIENT_ACCUMULATION_STEPS = 1
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SAVE_PATH = "checkpoints/best_model.pth"
PRETRAINED_SWIN_PATH = "checkpoints/model_swinvit.pt"
SEED = 3407

set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-05-18 04:53:55,797 - Train - INFO - ==================================================
# 2026-05-18 04:53:55,798 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-05-18 04:53:55,800 - Train - INFO - ==================================================
# 2026-05-18 04:53:55,801 - Train - INFO - ▶ 随机种子 (SEED): 3407
# 2026-05-18 04:53:55,802 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-05-18 04:53:55,803 - Train - INFO - ▶ 预热轮数 (Warmup Epochs): 5
# 2026-05-18 04:53:55,805 - Train - INFO - ▶ 批次大小 (Batch Size): 1
# 2026-05-18 04:53:55,805 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-05-18 04:53:55,807 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-05-18 04:53:55,808 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-05-18 04:53:55,809 - Train - INFO - ==================================================
# 2026-05-18 04:53:55,810 - Train - INFO - 训练设备: cuda
# 2026-05-18 04:53:55,811 - Train - INFO - 批次大小: 1
# 2026-05-18 04:53:55,812 - Train - INFO - 总轮数: 50

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS
)
# Out:
# 2026-05-18 04:53:55,870 - Train - INFO - 正在加载数据集...
# 2026-05-18 04:53:55,914 - utils.dataset - INFO - ✅ 成功加载 656 个样本
# 2026-05-18 04:53:55,921 - utils.dataset - INFO - ✅ 成功加载 82 个样本
# 2026-05-18 04:53:55,923 - utils.dataset - INFO - ✅ DataLoader 构建完成！
# 2026-05-18 04:53:55,924 - utils.dataset - INFO - 训练集批次: 656，验证集批次: 82

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model = APM_Former_ImageOnly(
    img_size=TRAIN_IMG_SIZE,
    in_channels=1,
    num_classes=NUM_CLASSES,
    feature_size=FEATURE_SIZE,
    guide_channels=GUIDE_CHANNELS,
    pretrained_swin_path=PRETRAINED_SWIN_PATH # 传入刚刚下载的权重
).to(DEVICE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-05-18 04:53:55,976 - Train - INFO - 初始化 APM-Former 模型...
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-05-18 04:53:57,786 - Train - INFO - 模型总参数量: 16.32 M

# %%
# 5. 损失函数 + 两阶段优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR

# ==========================================
# 损失函数 (保持你原来的完美配置不变)
# ==========================================
weights = torch.tensor([1.0, 1.755]).to(DEVICE) 
criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)

# ==========================================
# 两阶段训练：阶段一 (冻结主干)
# ==========================================

# 1. 冻结 Swin 主干网络
logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
for name, param in model.named_parameters():
    if "swin_backbone" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

# 2. 定义优化器：极其重要！这里加了 filter，只把没冻结的参数交给优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# 3. 阶段一的调度器：不需要预热，直接用 5 个 epoch 的余弦退火
scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
# Out:
# 2026-05-18 04:53:57,833 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1))
        # loss = criterion(logits, labels)
        loss = loss / accum_steps

        loss.backward()
        # 👇 就在 optimizer.step() 之前，加入这行“梯度裁剪”代码！
        # max_norm=1.0 或 2.0 是最常用的安全值
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc

from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    # correct = 0
    # total = 0
    all_preds = []
    all_labels = []
    all_probs = []  # 🌟 新增：专门用于收集预测为 pMCI 的概率，计算 AUC 必须用

    for images, labels in loader: 
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1)) # 如果用的是交叉熵，这里不用 unsqueeze

        total_loss += loss.item()
        
        # 获取预测类别 (0 或 1)
        preds = torch.argmax(logits, dim=1)
        
        # 🌟 获取预测为类别 1 (pMCI) 的概率
        probs = F.softmax(logits, dim=1)[:, 1] 
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    # ==========================
    # 🌟 计算所有医学黄金指标
    # ==========================
    acc = accuracy_score(all_labels, all_preds) * 100
    sen = recall_score(all_labels, all_preds, pos_label=1) * 100  # Sensitivity / Recall
    spe = recall_score(all_labels, all_preds, pos_label=0) * 100  # Specificity (反向召回)
    f1 = f1_score(all_labels, all_preds, pos_label=1) * 100
    
    # 计算 AUC (注意：有些 batch 如果只有一个类别会报错，这里做了容错)
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    
    # 打印超级豪华版日志
    logger.info(f"👉 混淆矩阵: [sMCI正确: {cm[0][0]}, 误判为pMCI: {cm[0][1]}] | [pMCI漏判: {cm[1][0]}, pMCI正确: {cm[1][1]}]")
    logger.info(f"🏆 评估指标: ACC: {acc:.2f}% | SEN: {sen:.2f}% | SPE: {spe:.2f}% | F1: {f1:.2f}% | AUC: {auc:.2f}%")
    
    return avg_loss, acc, auc

# %%
# # %% 训练1个batch，打印梯度！！！
# model.train()
# images, labels = next(iter(train_loader))
# images = images.to(DEVICE)
# labels = labels.to(DEVICE)

# optimizer.zero_grad()
# logits, _, _ = model(images)
# loss = criterion(logits, labels)
# loss.backward()

# # 打印Swin主干的梯度（如果是None/0，就是主干冻结！）
# print("Loss:", loss.item())
# print("Swin主干参数梯度：")
# for name, param in model.swin_backbone.named_parameters():
#     if param.grad is not None:
#         print(f"{name}: 梯度均值 = {param.grad.mean().item()}")
#         break
#     else:
#         print(f"{name}: 梯度为 None ❌（冻结了！）")
#         break

# %%
# 7. 主训练循环
best_val_acc = 0.0
logger.info("=" * 50)
logger.info("开始训练！")
logger.info("=" * 50)

for epoch in range(NUM_EPOCHS):
    # 👇 ================= 新增：解冻机关 ================= 👇
    if epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 重新定义优化器（包含主干网络），并大幅降低学习率来保护老专家！
        # 这里用 1e-4 或 5e-5 进行微调最合适
        optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    val_loss, val_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    scheduler.step()

    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {val_acc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), SAVE_PATH)
        logger.info(f"✅ 最佳模型已保存！最佳验证准确率: {best_val_acc:.2f}%")

logger.info("\n🎉 训练完成！")
logger.info(f"最终最佳验证准确率: {best_val_acc:.2f}%")
# Out:
# 2026-05-18 04:53:57,968 - Train - INFO - ==================================================
# 2026-05-18 04:53:57,969 - Train - INFO - 开始训练！
# 2026-05-18 04:53:57,971 - Train - INFO - ==================================================
# 2026-05-18 04:53:57,973 - Train - INFO -
# Epoch [1/50]
# 训练中: 100%|██████████| 656/656 [01:18<00:00,  8.33it/s]
# 2026-05-18 04:55:26,620 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 04:55:26,622 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 76.54%
# 2026-05-18 04:55:26,623 - Train - INFO - 训练损失: 0.3116 | 训练准确率: 62.20%
# 2026-05-18 04:55:26,624 - Train - INFO - 验证损失: 0.2499 | 验证准确率: 63.41%
# 2026-05-18 04:55:26,625 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-18 04:55:27,836 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 63.41%
# 2026-05-18 04:55:27,837 - Train - INFO -
# Epoch [2/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.72it/s]
# 2026-05-18 04:56:53,908 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 04:56:53,909 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 76.28%
# 2026-05-18 04:56:53,911 - Train - INFO - 训练损失: 0.2967 | 训练准确率: 63.72%
# 2026-05-18 04:56:53,912 - Train - INFO - 验证损失: 0.3035 | 验证准确率: 63.41%
# 2026-05-18 04:56:53,913 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-18 04:56:53,914 - Train - INFO -
# Epoch [3/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.76it/s]
# 2026-05-18 04:58:19,622 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 04:58:19,624 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.19%
# 2026-05-18 04:58:19,626 - Train - INFO - 训练损失: 0.3029 | 训练准确率: 63.72%
# 2026-05-18 04:58:19,626 - Train - INFO - 验证损失: 0.2592 | 验证准确率: 63.41%
# 2026-05-18 04:58:19,627 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-18 04:58:19,628 - Train - INFO -
# Epoch [4/50]
# 训练中: 100%|██████████| 656/656 [01:17<00:00,  8.47it/s]
# 2026-05-18 04:59:47,410 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 04:59:47,412 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 73.91%
# 2026-05-18 04:59:47,413 - Train - INFO - 训练损失: 0.2878 | 训练准确率: 63.72%
# 2026-05-18 04:59:47,414 - Train - INFO - 验证损失: 0.2634 | 验证准确率: 63.41%
# 2026-05-18 04:59:47,415 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-18 04:59:47,415 - Train - INFO -
# Epoch [5/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.64it/s]
# 2026-05-18 05:01:13,208 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:01:13,210 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.32%
# 2026-05-18 05:01:13,212 - Train - INFO - 训练损失: 0.2795 | 训练准确率: 63.72%
# 2026-05-18 05:01:13,212 - Train - INFO - 验证损失: 0.2722 | 验证准确率: 63.41%
# 2026-05-18 05:01:13,213 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-18 05:01:13,213 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-18 05:01:13,213 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！
# 2026-05-18 05:01:13,214 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-18 05:01:13,216 - Train - INFO -
# Epoch [6/50]
# 训练中: 100%|██████████| 656/656 [01:13<00:00,  8.96it/s]
# 2026-05-18 05:02:36,324 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:02:36,326 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 73.91%
# 2026-05-18 05:02:36,328 - Train - INFO - 训练损失: 0.3370 | 训练准确率: 63.72%
# 2026-05-18 05:02:36,329 - Train - INFO - 验证损失: 0.2862 | 验证准确率: 63.41%
# 2026-05-18 05:02:36,329 - Train - INFO - 当前学习率: 0.00029963
# 2026-05-18 05:02:36,330 - Train - INFO -
# Epoch [7/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.83it/s]
# 2026-05-18 05:03:59,918 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:03:59,920 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.92%
# 2026-05-18 05:03:59,922 - Train - INFO - 训练损失: 0.3177 | 训练准确率: 63.72%
# 2026-05-18 05:03:59,923 - Train - INFO - 验证损失: 0.2990 | 验证准确率: 63.41%
# 2026-05-18 05:03:59,924 - Train - INFO - 当前学习率: 0.00029854
# 2026-05-18 05:03:59,924 - Train - INFO -
# Epoch [8/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.75it/s]
# 2026-05-18 05:05:25,520 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:05:25,522 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 72.44%
# 2026-05-18 05:05:25,524 - Train - INFO - 训练损失: 0.2999 | 训练准确率: 63.72%
# 2026-05-18 05:05:25,525 - Train - INFO - 验证损失: 0.3326 | 验证准确率: 63.41%
# 2026-05-18 05:05:25,525 - Train - INFO - 当前学习率: 0.00029672
# 2026-05-18 05:05:25,526 - Train - INFO -
# Epoch [9/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.69it/s]
# 2026-05-18 05:06:51,031 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:06:51,033 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 70.64%
# 2026-05-18 05:06:51,035 - Train - INFO - 训练损失: 0.2951 | 训练准确率: 63.72%
# 2026-05-18 05:06:51,036 - Train - INFO - 验证损失: 0.3416 | 验证准确率: 63.41%
# 2026-05-18 05:06:51,037 - Train - INFO - 当前学习率: 0.00029419
# 2026-05-18 05:06:51,038 - Train - INFO -
# Epoch [10/50]
# 训练中: 100%|██████████| 656/656 [01:16<00:00,  8.55it/s]
# 2026-05-18 05:08:18,061 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:08:18,063 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.22%
# 2026-05-18 05:08:18,064 - Train - INFO - 训练损失: 0.3055 | 训练准确率: 63.72%
# 2026-05-18 05:08:18,065 - Train - INFO - 验证损失: 0.2666 | 验证准确率: 63.41%
# 2026-05-18 05:08:18,066 - Train - INFO - 当前学习率: 0.00029095
# 2026-05-18 05:08:18,066 - Train - INFO -
# Epoch [11/50]
# 训练中: 100%|██████████| 656/656 [01:16<00:00,  8.55it/s]
# 2026-05-18 05:09:44,333 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:09:44,334 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 73.33%
# 2026-05-18 05:09:44,334 - Train - INFO - 训练损失: 0.2914 | 训练准确率: 63.72%
# 2026-05-18 05:09:44,335 - Train - INFO - 验证损失: 0.3057 | 验证准确率: 63.41%
# 2026-05-18 05:09:44,336 - Train - INFO - 当前学习率: 0.00028703
# 2026-05-18 05:09:44,336 - Train - INFO -
# Epoch [12/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.86it/s]
# 2026-05-18 05:11:08,238 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:11:08,241 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 70.71%
# 2026-05-18 05:11:08,242 - Train - INFO - 训练损失: 0.3208 | 训练准确率: 63.72%
# 2026-05-18 05:11:08,243 - Train - INFO - 验证损失: 0.2378 | 验证准确率: 63.41%
# 2026-05-18 05:11:08,244 - Train - INFO - 当前学习率: 0.00028244
# 2026-05-18 05:11:08,244 - Train - INFO -
# Epoch [13/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.78it/s]
# 2026-05-18 05:12:33,252 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:12:33,254 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.67%
# 2026-05-18 05:12:33,256 - Train - INFO - 训练损失: 0.3106 | 训练准确率: 63.72%
# 2026-05-18 05:12:33,257 - Train - INFO - 验证损失: 0.2619 | 验证准确率: 63.41%
# 2026-05-18 05:12:33,257 - Train - INFO - 当前学习率: 0.00027721
# 2026-05-18 05:12:33,258 - Train - INFO -
# Epoch [14/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.75it/s]
# 2026-05-18 05:13:58,533 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:13:58,535 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 74.04%
# 2026-05-18 05:13:58,537 - Train - INFO - 训练损失: 0.3040 | 训练准确率: 63.72%
# 2026-05-18 05:13:58,538 - Train - INFO - 验证损失: 0.3254 | 验证准确率: 63.41%
# 2026-05-18 05:13:58,539 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-18 05:13:58,540 - Train - INFO -
# Epoch [15/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.78it/s]
# 2026-05-18 05:15:23,641 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:15:23,643 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.45%
# 2026-05-18 05:15:23,645 - Train - INFO - 训练损失: 0.3025 | 训练准确率: 63.72%
# 2026-05-18 05:15:23,646 - Train - INFO - 验证损失: 0.2263 | 验证准确率: 63.41%
# 2026-05-18 05:15:23,647 - Train - INFO - 当前学习率: 0.00026491
# 2026-05-18 05:15:23,648 - Train - INFO -
# Epoch [16/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.66it/s]
# 2026-05-18 05:16:48,883 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:16:48,885 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 76.86%
# 2026-05-18 05:16:48,887 - Train - INFO - 训练损失: 0.2613 | 训练准确率: 63.72%
# 2026-05-18 05:16:48,888 - Train - INFO - 验证损失: 0.2769 | 验证准确率: 63.41%
# 2026-05-18 05:16:48,889 - Train - INFO - 当前学习率: 0.00025790
# 2026-05-18 05:16:48,890 - Train - INFO -
# Epoch [17/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.75it/s]
# 2026-05-18 05:18:14,394 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:18:14,396 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 76.22%
# 2026-05-18 05:18:14,398 - Train - INFO - 训练损失: 0.2855 | 训练准确率: 63.72%
# 2026-05-18 05:18:14,398 - Train - INFO - 验证损失: 0.2678 | 验证准确率: 63.41%
# 2026-05-18 05:18:14,399 - Train - INFO - 当前学习率: 0.00025037
# 2026-05-18 05:18:14,400 - Train - INFO -
# Epoch [18/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.86it/s]
# 2026-05-18 05:19:39,015 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:19:39,017 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.32%
# 2026-05-18 05:19:39,018 - Train - INFO - 训练损失: 0.3012 | 训练准确率: 63.72%
# 2026-05-18 05:19:39,019 - Train - INFO - 验证损失: 0.2254 | 验证准确率: 63.41%
# 2026-05-18 05:19:39,020 - Train - INFO - 当前学习率: 0.00024235
# 2026-05-18 05:19:39,021 - Train - INFO -
# Epoch [19/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.68it/s]
# 2026-05-18 05:21:04,144 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:21:04,146 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.19%
# 2026-05-18 05:21:04,148 - Train - INFO - 训练损失: 0.3150 | 训练准确率: 63.72%
# 2026-05-18 05:21:04,149 - Train - INFO - 验证损失: 0.2141 | 验证准确率: 63.41%
# 2026-05-18 05:21:04,150 - Train - INFO - 当前学习率: 0.00023388
# 2026-05-18 05:21:04,151 - Train - INFO -
# Epoch [20/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.69it/s]
# 2026-05-18 05:22:30,115 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:22:30,117 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.00%
# 2026-05-18 05:22:30,119 - Train - INFO - 训练损失: 0.3223 | 训练准确率: 63.72%
# 2026-05-18 05:22:30,120 - Train - INFO - 验证损失: 0.3120 | 验证准确率: 63.41%
# 2026-05-18 05:22:30,120 - Train - INFO - 当前学习率: 0.00022500
# 2026-05-18 05:22:30,121 - Train - INFO -
# Epoch [21/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.84it/s]
# 2026-05-18 05:23:54,594 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-18 05:23:54,596 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 75.58%
# 2026-05-18 05:23:54,598 - Train - INFO - 训练损失: 0.3340 | 训练准确率: 63.72%
# 2026-05-18 05:23:54,598 - Train - INFO - 验证损失: 0.3197 | 验证准确率: 63.41%
# 2026-05-18 05:23:54,599 - Train - INFO - 当前学习率: 0.00021576
# 2026-05-18 05:23:54,600 - Train - INFO -
# Epoch [22/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.70it/s]
# 2026-05-18 05:25:20,701 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-18 05:25:20,703 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 50.00% | SPE: 82.69% | F1: 55.56% | AUC: 75.77%
# 2026-05-18 05:25:20,705 - Train - INFO - 训练损失: 0.3331 | 训练准确率: 65.09%
# 2026-05-18 05:25:20,705 - Train - INFO - 验证损失: 0.1995 | 验证准确率: 70.73%
# 2026-05-18 05:25:20,706 - Train - INFO - 当前学习率: 0.00020619
# 2026-05-18 05:25:21,931 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 70.73%
# 2026-05-18 05:25:21,932 - Train - INFO -
# Epoch [23/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.83it/s]
# 2026-05-18 05:26:46,976 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 51, 误判为pMCI: 1] | [pMCI漏判: 25, pMCI正确: 5]
# 2026-05-18 05:26:46,978 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 16.67% | SPE: 98.08% | F1: 27.78% | AUC: 75.45%
# 2026-05-18 05:26:46,979 - Train - INFO - 训练损失: 0.3556 | 训练准确率: 66.77%
# 2026-05-18 05:26:46,980 - Train - INFO - 验证损失: 0.3165 | 验证准确率: 68.29%
# 2026-05-18 05:26:46,981 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-18 05:26:46,982 - Train - INFO -
# Epoch [24/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.67it/s]
# 2026-05-18 05:28:12,107 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 49, 误判为pMCI: 3] | [pMCI漏判: 24, pMCI正确: 6]
# 2026-05-18 05:28:12,111 - Train - INFO - 🏆 评估指标: ACC: 67.07% | SEN: 20.00% | SPE: 94.23% | F1: 30.77% | AUC: 75.51%
# 2026-05-18 05:28:12,113 - Train - INFO - 训练损失: 0.3773 | 训练准确率: 67.38%
# 2026-05-18 05:28:12,114 - Train - INFO - 验证损失: 0.2475 | 验证准确率: 67.07%
# 2026-05-18 05:28:12,114 - Train - INFO - 当前学习率: 0.00018629
# 2026-05-18 05:28:12,115 - Train - INFO -
# Epoch [25/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.76it/s]
# 2026-05-18 05:29:37,707 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 23, 误判为pMCI: 29] | [pMCI漏判: 4, pMCI正确: 26]
# 2026-05-18 05:29:37,709 - Train - INFO - 🏆 评估指标: ACC: 59.76% | SEN: 86.67% | SPE: 44.23% | F1: 61.18% | AUC: 76.67%
# 2026-05-18 05:29:37,711 - Train - INFO - 训练损失: 0.3449 | 训练准确率: 66.46%
# 2026-05-18 05:29:37,712 - Train - INFO - 验证损失: 0.5320 | 验证准确率: 59.76%
# 2026-05-18 05:29:37,712 - Train - INFO - 当前学习率: 0.00017605
# 2026-05-18 05:29:37,713 - Train - INFO -
# Epoch [26/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.78it/s]
# 2026-05-18 05:31:02,416 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 16, pMCI正确: 14]
# 2026-05-18 05:31:02,418 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 46.67% | SPE: 84.62% | F1: 53.85% | AUC: 76.03%
# 2026-05-18 05:31:02,420 - Train - INFO - 训练损失: 0.3838 | 训练准确率: 68.60%
# 2026-05-18 05:31:02,420 - Train - INFO - 验证损失: 0.3024 | 验证准确率: 70.73%
# 2026-05-18 05:31:02,421 - Train - INFO - 当前学习率: 0.00016568
# 2026-05-18 05:31:02,422 - Train - INFO -
# Epoch [27/50]
# 训练中: 100%|██████████| 656/656 [01:16<00:00,  8.58it/s]
# 2026-05-18 05:32:29,051 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 24, 误判为pMCI: 28] | [pMCI漏判: 5, pMCI正确: 25]
# 2026-05-18 05:32:29,053 - Train - INFO - 🏆 评估指标: ACC: 59.76% | SEN: 83.33% | SPE: 46.15% | F1: 60.24% | AUC: 76.28%
# 2026-05-18 05:32:29,055 - Train - INFO - 训练损失: 0.3747 | 训练准确率: 67.68%
# 2026-05-18 05:32:29,056 - Train - INFO - 验证损失: 0.6452 | 验证准确率: 59.76%
# 2026-05-18 05:32:29,057 - Train - INFO - 当前学习率: 0.00015523
# 2026-05-18 05:32:29,058 - Train - INFO -
# Epoch [28/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.75it/s]
# 2026-05-18 05:33:53,426 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 49, 误判为pMCI: 3] | [pMCI漏判: 20, pMCI正确: 10]
# 2026-05-18 05:33:53,428 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 33.33% | SPE: 94.23% | F1: 46.51% | AUC: 75.32%
# 2026-05-18 05:33:53,430 - Train - INFO - 训练损失: 0.3747 | 训练准确率: 70.73%
# 2026-05-18 05:33:53,430 - Train - INFO - 验证损失: 0.3188 | 验证准确率: 71.95%
# 2026-05-18 05:33:53,431 - Train - INFO - 当前学习率: 0.00014477
# 2026-05-18 05:33:54,763 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 71.95%
# 2026-05-18 05:33:54,764 - Train - INFO -
# Epoch [29/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.66it/s]
# 2026-05-18 05:35:19,985 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 47, 误判为pMCI: 5] | [pMCI漏判: 19, pMCI正确: 11]
# 2026-05-18 05:35:19,988 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 36.67% | SPE: 90.38% | F1: 47.83% | AUC: 75.51%
# 2026-05-18 05:35:19,989 - Train - INFO - 训练损失: 0.3805 | 训练准确率: 66.31%
# 2026-05-18 05:35:19,990 - Train - INFO - 验证损失: 0.3174 | 验证准确率: 70.73%
# 2026-05-18 05:35:19,992 - Train - INFO - 当前学习率: 0.00013432
# 2026-05-18 05:35:19,993 - Train - INFO -
# Epoch [30/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.64it/s]
# 2026-05-18 05:36:46,654 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 49, 误判为pMCI: 3] | [pMCI漏判: 23, pMCI正确: 7]
# 2026-05-18 05:36:46,657 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 23.33% | SPE: 94.23% | F1: 35.00% | AUC: 75.32%
# 2026-05-18 05:36:46,659 - Train - INFO - 训练损失: 0.3877 | 训练准确率: 66.16%
# 2026-05-18 05:36:46,660 - Train - INFO - 验证损失: 0.3231 | 验证准确率: 68.29%
# 2026-05-18 05:36:46,661 - Train - INFO - 当前学习率: 0.00012395
# 2026-05-18 05:36:46,662 - Train - INFO -
# Epoch [31/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.78it/s]
# 2026-05-18 05:38:11,383 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 46, 误判为pMCI: 6] | [pMCI漏判: 17, pMCI正确: 13]
# 2026-05-18 05:38:11,385 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 43.33% | SPE: 88.46% | F1: 53.06% | AUC: 75.51%
# 2026-05-18 05:38:11,386 - Train - INFO - 训练损失: 0.3744 | 训练准确率: 68.60%
# 2026-05-18 05:38:11,387 - Train - INFO - 验证损失: 0.2854 | 验证准确率: 71.95%
# 2026-05-18 05:38:11,388 - Train - INFO - 当前学习率: 0.00011371
# 2026-05-18 05:38:11,389 - Train - INFO -
# Epoch [32/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.79it/s]
# 2026-05-18 05:39:36,736 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 17, pMCI正确: 13]
# 2026-05-18 05:39:36,738 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 43.33% | SPE: 84.62% | F1: 50.98% | AUC: 75.64%
# 2026-05-18 05:39:36,740 - Train - INFO - 训练损失: 0.3768 | 训练准确率: 68.75%
# 2026-05-18 05:39:36,741 - Train - INFO - 验证损失: 0.3356 | 验证准确率: 69.51%
# 2026-05-18 05:39:36,742 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-18 05:39:36,743 - Train - INFO -
# Epoch [33/50]
# 训练中: 100%|██████████| 656/656 [01:16<00:00,  8.58it/s]
# 2026-05-18 05:41:04,131 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 11, pMCI正确: 19]
# 2026-05-18 05:41:04,133 - Train - INFO - 🏆 评估指标: ACC: 74.39% | SEN: 63.33% | SPE: 80.77% | F1: 64.41% | AUC: 76.15%
# 2026-05-18 05:41:04,134 - Train - INFO - 训练损失: 0.3909 | 训练准确率: 67.84%
# 2026-05-18 05:41:04,135 - Train - INFO - 验证损失: 0.3315 | 验证准确率: 74.39%
# 2026-05-18 05:41:04,136 - Train - INFO - 当前学习率: 0.00009381
# 2026-05-18 05:41:05,582 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 74.39%
# 2026-05-18 05:41:05,583 - Train - INFO -
# Epoch [34/50]
# 训练中: 100%|██████████| 656/656 [01:13<00:00,  8.98it/s]
# 2026-05-18 05:42:28,583 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 36, 误判为pMCI: 16] | [pMCI漏判: 10, pMCI正确: 20]
# 2026-05-18 05:42:28,585 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 66.67% | SPE: 69.23% | F1: 60.61% | AUC: 76.54%
# 2026-05-18 05:42:28,587 - Train - INFO - 训练损失: 0.3796 | 训练准确率: 71.04%
# 2026-05-18 05:42:28,588 - Train - INFO - 验证损失: 0.3696 | 验证准确率: 68.29%
# 2026-05-18 05:42:28,588 - Train - INFO - 当前学习率: 0.00008424
# 2026-05-18 05:42:28,589 - Train - INFO -
# Epoch [35/50]
# 训练中: 100%|██████████| 656/656 [01:19<00:00,  8.24it/s]
# 2026-05-18 05:43:58,811 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 47, 误判为pMCI: 5] | [pMCI漏判: 19, pMCI正确: 11]
# 2026-05-18 05:43:58,813 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 36.67% | SPE: 90.38% | F1: 47.83% | AUC: 74.74%
# 2026-05-18 05:43:58,815 - Train - INFO - 训练损失: 0.3756 | 训练准确率: 69.05%
# 2026-05-18 05:43:58,816 - Train - INFO - 验证损失: 0.3315 | 验证准确率: 70.73%
# 2026-05-18 05:43:58,817 - Train - INFO - 当前学习率: 0.00007500
# 2026-05-18 05:43:58,817 - Train - INFO -
# Epoch [36/50]
# 训练中: 100%|██████████| 656/656 [01:17<00:00,  8.46it/s]
# 2026-05-18 05:45:25,465 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 14, pMCI正确: 16]
# 2026-05-18 05:45:25,467 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 53.33% | SPE: 82.69% | F1: 58.18% | AUC: 75.45%
# 2026-05-18 05:45:25,469 - Train - INFO - 训练损失: 0.3685 | 训练准确率: 70.73%
# 2026-05-18 05:45:25,470 - Train - INFO - 验证损失: 0.3231 | 验证准确率: 71.95%
# 2026-05-18 05:45:25,470 - Train - INFO - 当前学习率: 0.00006612
# 2026-05-18 05:45:25,471 - Train - INFO -
# Epoch [37/50]
# 训练中: 100%|██████████| 656/656 [01:13<00:00,  8.91it/s]
# 2026-05-18 05:46:49,065 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 12, pMCI正确: 18]
# 2026-05-18 05:46:49,069 - Train - INFO - 🏆 评估指标: ACC: 73.17% | SEN: 60.00% | SPE: 80.77% | F1: 62.07% | AUC: 75.32%
# 2026-05-18 05:46:49,071 - Train - INFO - 训练损失: 0.3821 | 训练准确率: 70.73%
# 2026-05-18 05:46:49,072 - Train - INFO - 验证损失: 0.3562 | 验证准确率: 73.17%
# 2026-05-18 05:46:49,073 - Train - INFO - 当前学习率: 0.00005765
# 2026-05-18 05:46:49,074 - Train - INFO -
# Epoch [38/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.70it/s]
# 2026-05-18 05:48:15,122 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 49, 误判为pMCI: 3] | [pMCI漏判: 21, pMCI正确: 9]
# 2026-05-18 05:48:15,124 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 30.00% | SPE: 94.23% | F1: 42.86% | AUC: 74.29%
# 2026-05-18 05:48:15,126 - Train - INFO - 训练损失: 0.3663 | 训练准确率: 72.10%
# 2026-05-18 05:48:15,127 - Train - INFO - 验证损失: 0.3899 | 验证准确率: 70.73%
# 2026-05-18 05:48:15,128 - Train - INFO - 当前学习率: 0.00004963
# 2026-05-18 05:48:15,129 - Train - INFO -
# Epoch [39/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.73it/s]
# 2026-05-18 05:49:41,130 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 16, pMCI正确: 14]
# 2026-05-18 05:49:41,132 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 46.67% | SPE: 84.62% | F1: 53.85% | AUC: 74.36%
# 2026-05-18 05:49:41,136 - Train - INFO - 训练损失: 0.3659 | 训练准确率: 71.80%
# 2026-05-18 05:49:41,137 - Train - INFO - 验证损失: 0.3368 | 验证准确率: 70.73%
# 2026-05-18 05:49:41,138 - Train - INFO - 当前学习率: 0.00004210
# 2026-05-18 05:49:41,139 - Train - INFO -
# Epoch [40/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.66it/s]
# 2026-05-18 05:51:05,844 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 49, 误判为pMCI: 3] | [pMCI漏判: 21, pMCI正确: 9]
# 2026-05-18 05:51:05,846 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 30.00% | SPE: 94.23% | F1: 42.86% | AUC: 74.29%
# 2026-05-18 05:51:05,847 - Train - INFO - 训练损失: 0.3567 | 训练准确率: 69.21%
# 2026-05-18 05:51:05,848 - Train - INFO - 验证损失: 0.3956 | 验证准确率: 70.73%
# 2026-05-18 05:51:05,849 - Train - INFO - 当前学习率: 0.00003509
# 2026-05-18 05:51:05,851 - Train - INFO -
# Epoch [41/50]
# 训练中: 100%|██████████| 656/656 [01:13<00:00,  8.98it/s]
# 2026-05-18 05:52:29,693 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-18 05:52:29,696 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.19%
# 2026-05-18 05:52:29,698 - Train - INFO - 训练损失: 0.3948 | 训练准确率: 69.97%
# 2026-05-18 05:52:29,699 - Train - INFO - 验证损失: 0.3608 | 验证准确率: 69.51%
# 2026-05-18 05:52:29,700 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-18 05:52:29,702 - Train - INFO -
# Epoch [42/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.69it/s]
# 2026-05-18 05:53:55,646 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 45, 误判为pMCI: 7] | [pMCI漏判: 17, pMCI正确: 13]
# 2026-05-18 05:53:55,648 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 43.33% | SPE: 86.54% | F1: 52.00% | AUC: 74.29%
# 2026-05-18 05:53:55,650 - Train - INFO - 训练损失: 0.3627 | 训练准确率: 70.73%
# 2026-05-18 05:53:55,651 - Train - INFO - 验证损失: 0.3550 | 验证准确率: 70.73%
# 2026-05-18 05:53:55,652 - Train - INFO - 当前学习率: 0.00002279
# 2026-05-18 05:53:55,652 - Train - INFO -
# Epoch [43/50]
# 训练中: 100%|██████████| 656/656 [01:13<00:00,  8.87it/s]
# 2026-05-18 05:55:20,421 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-18 05:55:20,423 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 50.00% | SPE: 82.69% | F1: 55.56% | AUC: 74.94%
# 2026-05-18 05:55:20,425 - Train - INFO - 训练损失: 0.3691 | 训练准确率: 72.71%
# 2026-05-18 05:55:20,426 - Train - INFO - 验证损失: 0.3582 | 验证准确率: 70.73%
# 2026-05-18 05:55:20,427 - Train - INFO - 当前学习率: 0.00001756
# 2026-05-18 05:55:20,428 - Train - INFO -
# Epoch [44/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.73it/s]
# 2026-05-18 05:56:46,312 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 16, pMCI正确: 14]
# 2026-05-18 05:56:46,313 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 46.67% | SPE: 82.69% | F1: 52.83% | AUC: 74.74%
# 2026-05-18 05:56:46,314 - Train - INFO - 训练损失: 0.3594 | 训练准确率: 71.49%
# 2026-05-18 05:56:46,315 - Train - INFO - 验证损失: 0.3604 | 验证准确率: 69.51%
# 2026-05-18 05:56:46,316 - Train - INFO - 当前学习率: 0.00001297
# 2026-05-18 05:56:46,317 - Train - INFO -
# Epoch [45/50]
# 训练中: 100%|██████████| 656/656 [01:16<00:00,  8.58it/s]
# 2026-05-18 05:58:13,655 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 16, pMCI正确: 14]
# 2026-05-18 05:58:13,656 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 46.67% | SPE: 84.62% | F1: 53.85% | AUC: 74.42%
# 2026-05-18 05:58:13,657 - Train - INFO - 训练损失: 0.3576 | 训练准确率: 69.82%
# 2026-05-18 05:58:13,658 - Train - INFO - 验证损失: 0.3557 | 验证准确率: 70.73%
# 2026-05-18 05:58:13,659 - Train - INFO - 当前学习率: 0.00000905
# 2026-05-18 05:58:13,660 - Train - INFO -
# Epoch [46/50]
# 训练中: 100%|██████████| 656/656 [01:17<00:00,  8.44it/s]
# 2026-05-18 05:59:41,094 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-18 05:59:41,096 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 50.00% | SPE: 82.69% | F1: 55.56% | AUC: 74.74%
# 2026-05-18 05:59:41,098 - Train - INFO - 训练损失: 0.3653 | 训练准确率: 70.73%
# 2026-05-18 05:59:41,099 - Train - INFO - 验证损失: 0.3652 | 验证准确率: 70.73%
# 2026-05-18 05:59:41,100 - Train - INFO - 当前学习率: 0.00000581
# 2026-05-18 05:59:41,101 - Train - INFO -
# Epoch [47/50]
# 训练中: 100%|██████████| 656/656 [01:14<00:00,  8.77it/s]
# 2026-05-18 06:01:05,763 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 16, pMCI正确: 14]
# 2026-05-18 06:01:05,766 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 46.67% | SPE: 82.69% | F1: 52.83% | AUC: 74.68%
# 2026-05-18 06:01:05,769 - Train - INFO - 训练损失: 0.3674 | 训练准确率: 70.73%
# 2026-05-18 06:01:05,771 - Train - INFO - 验证损失: 0.3641 | 验证准确率: 69.51%
# 2026-05-18 06:01:05,772 - Train - INFO - 当前学习率: 0.00000328
# 2026-05-18 06:01:05,772 - Train - INFO -
# Epoch [48/50]
# 训练中: 100%|██████████| 656/656 [01:13<00:00,  8.87it/s]
# 2026-05-18 06:02:30,526 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-18 06:02:30,530 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 50.00% | SPE: 82.69% | F1: 55.56% | AUC: 74.81%
# 2026-05-18 06:02:30,532 - Train - INFO - 训练损失: 0.3568 | 训练准确率: 72.10%
# 2026-05-18 06:02:30,533 - Train - INFO - 验证损失: 0.3686 | 验证准确率: 70.73%
# 2026-05-18 06:02:30,533 - Train - INFO - 当前学习率: 0.00000146
# 2026-05-18 06:02:30,534 - Train - INFO -
# Epoch [49/50]
# 训练中: 100%|██████████| 656/656 [01:15<00:00,  8.64it/s]
# 2026-05-18 06:03:57,242 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-18 06:03:57,244 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.06%
# 2026-05-18 06:03:57,246 - Train - INFO - 训练损失: 0.3568 | 训练准确率: 71.34%
# 2026-05-18 06:03:57,247 - Train - INFO - 验证损失: 0.3709 | 验证准确率: 69.51%
# 2026-05-18 06:03:57,248 - Train - INFO - 当前学习率: 0.00000037
# 2026-05-18 06:03:57,249 - Train - INFO -
# Epoch [50/50]
# 训练中: 100%|██████████| 656/656 [01:18<00:00,  8.39it/s]
# 2026-05-18 06:05:25,831 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-18 06:05:25,833 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 50.00% | SPE: 80.77% | F1: 54.55% | AUC: 75.00%
# 2026-05-18 06:05:25,835 - Train - INFO - 训练损失: 0.3753 | 训练准确率: 69.51%
# 2026-05-18 06:05:25,836 - Train - INFO - 验证损失: 0.3704 | 验证准确率: 69.51%
# 2026-05-18 06:05:25,837 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-18 06:05:25,839 - Train - INFO -
# 🎉 训练完成！
# 2026-05-18 06:05:25,840 - Train - INFO - 最终最佳验证准确率: 74.39%

# %%
# import torch
# import torch.nn.functional as F
# import numpy as np
# import matplotlib.pyplot as plt

# # ==========================================
# # 第一步：加载你跑出 74.39% 的最佳模型权重
# # ==========================================
# print("🔄 正在加载最佳模型权重...")

# # 实例化模型 (确保这里的参数和你跑出最好成绩的那次完全一致)
# # 之前确认过 FEATURE_SIZE 是 24
# vis_model = APM_Former_ImageOnly(
#     feature_size=24,  
#     num_classes=2
# ).to(DEVICE)

# # ⚠️ 注意：把这里的 'best_model.pth' 换成你实际保存的权重文件名！
# # 比如可能是 'checkpoint_epoch_xx.pth'
# checkpoint_path = 'checkpoints/best_model.pth'  
# state_dict = torch.load(checkpoint_path, map_location=DEVICE)
# vis_model.load_state_dict(state_dict)

# vis_model.eval() # 切换到评估模式
# print(f"✅ 成功加载权重: {checkpoint_path}")
# print("-" * 50)


# # ==========================================
# # 第二步：定义并运行可视化探针
# # ==========================================
# @torch.no_grad()
# def visualize_pMCI_attention(model, val_loader, device, num_cases_to_show=3):
#     model.eval()
#     found_cases = 0
    
#     # 解决 matplotlib 中文显示问题
#     # plt.rcParams['font.sans-serif'] = ['SimHei'] 
#     # plt.rcParams['axes.unicode_minus'] = False
    
#     print("🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...\n")
    
#     for images, labels in val_loader:
#         images = images.to(device)
#         labels = labels.to(device)
        
#         logits, _, spatial_attention = model(images)
#         preds = torch.argmax(logits, dim=1)
        
#         # 寻找 True Positives (真实为pMCI，预测也为pMCI)
#         for i in range(len(labels)):
#             if labels[i].item() == 1 and preds[i].item() == 1:
#                 found_cases += 1
                
#                 # 1. 提取原始 3D MRI 图像
#                 img_3d = images[i, 0].cpu().numpy()  
                
#                 # 2. 提取注意力掩码，并插值放大到原始图像大小 (96, 96, 96)
#                 attn_tensor = spatial_attention[i:i+1] 
#                 attn_resized = F.interpolate(attn_tensor, size=img_3d.shape, mode='trilinear', align_corners=False)
#                 attn_3d = attn_resized[0, 0].cpu().numpy()
                
#                 # 3. 智能寻找网络最关注的切片位置
#                 slice_x = np.argmax(np.sum(attn_3d, axis=(1, 2))) 
#                 slice_y = np.argmax(np.sum(attn_3d, axis=(0, 2))) 
#                 slice_z = np.argmax(np.sum(attn_3d, axis=(0, 1))) 
                
#                 # 4. 绘图
#                 fig, axes = plt.subplots(1, 3, figsize=(18, 6))
#                 # 成功识别的pMCI阳性病例  高亮区域为网络空间对齐中点关注区域
#                 fig.suptitle(f"True Positive pMCI Case #{found_cases}\n(Spatial Attention Guided Alignment)", fontsize=18, fontweight='bold', y=1.05)
                
#                 # 矢状面 矢状面切片
#                 axes[0].imshow(img_3d[slice_x, :, :], cmap='gray') 
#                 im = axes[0].imshow(attn_3d[slice_x, :, :], cmap='jet', alpha=0.45) 
#                 axes[0].set_title(f"Sagittal View (Slice {slice_x})", fontsize=14)
#                 axes[0].axis('off')
                
#                 # 冠状面 冠状面切片
#                 axes[1].imshow(img_3d[:, slice_y, :], cmap='gray')
#                 axes[1].imshow(attn_3d[:, slice_y, :], cmap='jet', alpha=0.45)
#                 axes[1].set_title(f"Coronal View (Slice {slice_y})", fontsize=14)
#                 axes[1].axis('off')
                
#                 # 轴状面 轴状面切片
#                 axes[2].imshow(img_3d[:, :, slice_z], cmap='gray')
#                 axes[2].imshow(attn_3d[:, :, slice_z], cmap='jet', alpha=0.45)
#                 axes[2].set_title(f"Axial View (Slice {slice_z})", fontsize=14)
#                 axes[2].axis('off')
                
#                 # 颜色条的标签 解剖引导强度
#                 cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
#                 cbar.set_label('Attention Weight', fontsize=12)
                
#                 plt.show()
                
#                 if found_cases >= num_cases_to_show:
#                     print(f"\n✅ 成功提取 {num_cases_to_show} 组 pMCI 空间注意力图！")
#                     return

#     print(f"\n搜索结束，共找到 {found_cases} 个符合条件的病例。")

# # 执行探针！展示前 5 个最典型的病例
# visualize_pMCI_attention(vis_model, val_loader, DEVICE, num_cases_to_show=5)
