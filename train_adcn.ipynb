# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 
# seed 3407 ACC: 81.20% | SEN: 61.54% | SPE: 91.03% | F1: 68.57% | AUC: 86.26%    ACC: 80.34% | SEN: 56.41% | SPE: 92.31% | F1: 65.67% | AUC: 83.86%
# seed 1234 
# seed 98 
# seed 20  
# seed 1024

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
UNFREEZE_EPOCH = 5  # 设定前 5 个 epoch 为阶段一
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 50
GRADIENT_ACCUMULATION_STEPS = 1
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SAVE_PATH = "checkpoints/best_adcn_model.pth"
PRETRAINED_SWIN_PATH = "checkpoints/model_swinvit.pt"
SEED = 3407

set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-05-21 01:58:56,876 - Train - INFO - ==================================================
# 2026-05-21 01:58:56,878 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-05-21 01:58:56,879 - Train - INFO - ==================================================
# 2026-05-21 01:58:56,880 - Train - INFO - ▶ 随机种子 (SEED): 3407
# 2026-05-21 01:58:56,881 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-05-21 01:58:56,883 - Train - INFO - ▶ 预热轮数 (Warmup Epochs): 5
# 2026-05-21 01:58:56,884 - Train - INFO - ▶ 批次大小 (Batch Size): 2
# 2026-05-21 01:58:56,886 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-05-21 01:58:56,887 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-05-21 01:58:56,888 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-05-21 01:58:56,890 - Train - INFO - ==================================================
# 2026-05-21 01:58:56,891 - Train - INFO - 训练设备: cuda
# 2026-05-21 01:58:56,893 - Train - INFO - 批次大小: 2
# 2026-05-21 01:58:56,894 - Train - INFO - 总轮数: 50

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS
)
# Out:
# 2026-05-21 01:58:56,947 - Train - INFO - 正在加载数据集...
# 2026-05-21 01:58:57,002 - utils.dataset - INFO - ✅ 成功加载 932 个样本
# 2026-05-21 01:58:57,012 - utils.dataset - INFO - ✅ 成功加载 117 个样本
# 2026-05-21 01:58:57,013 - utils.dataset - INFO - ✅ DataLoader 构建完成！
# 2026-05-21 01:58:57,015 - utils.dataset - INFO - 训练集批次: 466，验证集批次: 59

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model = APM_Former_ImageOnly(
    img_size=TRAIN_IMG_SIZE,
    in_channels=1,
    num_classes=NUM_CLASSES,
    feature_size=FEATURE_SIZE,
    guide_channels=GUIDE_CHANNELS,
    pretrained_swin_path=PRETRAINED_SWIN_PATH # 传入刚刚下载的权重
).to(DEVICE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-05-21 01:58:57,065 - Train - INFO - 初始化 APM-Former 模型...
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-05-21 01:58:59,076 - Train - INFO - 模型总参数量: 16.32 M

# %%
# 5. 损失函数 + 两阶段优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR

# ==========================================
# 损失函数 (保持你原来的完美配置不变)
# ==========================================
weights = torch.tensor([1.0, 626.0/306.0]).to(DEVICE) 
criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)

# ==========================================
# 两阶段训练：阶段一 (冻结主干)
# ==========================================

# 1. 冻结 Swin 主干网络
logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
for name, param in model.named_parameters():
    if "swin_backbone" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

# 2. 定义优化器：极其重要！这里加了 filter，只把没冻结的参数交给优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# 3. 阶段一的调度器：不需要预热，直接用 5 个 epoch 的余弦退火
scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
# Out:
# 2026-05-21 01:58:59,127 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1))
        # loss = criterion(logits, labels)
        loss = loss / accum_steps

        loss.backward()
        # 👇 就在 optimizer.step() 之前，加入这行“梯度裁剪”代码！
        # max_norm=1.0 或 2.0 是最常用的安全值
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc

from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    # correct = 0
    # total = 0
    all_preds = []
    all_labels = []
    all_probs = []  # 🌟 新增：专门用于收集预测为 pMCI 的概率，计算 AUC 必须用

    for images, labels in loader: 
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1)) # 如果用的是交叉熵，这里不用 unsqueeze

        total_loss += loss.item()
        
        # # 获取预测类别 (0 或 1)
        # preds = torch.argmax(logits, dim=1)
        
        # # 🌟 获取预测为类别 1 (pMCI) 的概率
        # probs = F.softmax(logits, dim=1)[:, 1] 
        # 1. 将 logits 转换为 0~1 之间的概率分布
        probs = F.softmax(logits, dim=1)[:, 1]
        # 2. 手动设定阈值（比如 0.35 或 0.40）
        # 意思是：只要模型认为有 35% 的可能是 AD，我们就判定为 AD，宁可错杀降低一点SPE，也要把SEN拉上来
        preds = (probs > 0.35).long()       

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    # ==========================
    # 🌟 计算所有医学黄金指标
    # ==========================
    acc = accuracy_score(all_labels, all_preds) * 100
    sen = recall_score(all_labels, all_preds, pos_label=1) * 100  # Sensitivity / Recall
    spe = recall_score(all_labels, all_preds, pos_label=0) * 100  # Specificity (反向召回)
    f1 = f1_score(all_labels, all_preds, pos_label=1) * 100
    
    # 计算 AUC (注意：有些 batch 如果只有一个类别会报错，这里做了容错)
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    
    # 打印超级豪华版日志
    logger.info(f"👉 混淆矩阵: [sMCI正确: {cm[0][0]}, 误判为pMCI: {cm[0][1]}] | [pMCI漏判: {cm[1][0]}, pMCI正确: {cm[1][1]}]")
    logger.info(f"🏆 评估指标: ACC: {acc:.2f}% | SEN: {sen:.2f}% | SPE: {spe:.2f}% | F1: {f1:.2f}% | AUC: {auc:.2f}%")
    
    return avg_loss, acc, auc

# %%
# # %% 训练1个batch，打印梯度！！！
# model.train()
# images, labels = next(iter(train_loader))
# images = images.to(DEVICE)
# labels = labels.to(DEVICE)

# optimizer.zero_grad()
# logits, _, _ = model(images)
# loss = criterion(logits, labels)
# loss.backward()

# # 打印Swin主干的梯度（如果是None/0，就是主干冻结！）
# print("Loss:", loss.item())
# print("Swin主干参数梯度：")
# for name, param in model.swin_backbone.named_parameters():
#     if param.grad is not None:
#         print(f"{name}: 梯度均值 = {param.grad.mean().item()}")
#         break
#     else:
#         print(f"{name}: 梯度为 None ❌（冻结了！）")
#         break

# %%
# 7. 主训练循环
best_val_auc = 0.0
logger.info("=" * 50)
logger.info("开始训练！")
logger.info("=" * 50)

for epoch in range(NUM_EPOCHS):
    # 👇 ================= 新增：解冻机关 ================= 👇
    if epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 重新定义优化器（包含主干网络），并大幅降低学习率来保护老专家！
        # 这里用 1e-4 或 5e-5 进行微调最合适
        optimizer = optim.AdamW(model.parameters(), lr=5e-5, weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    val_loss, val_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    scheduler.step()

    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {val_acc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    if val_auc > best_val_auc:
        best_val_auc = val_auc
        torch.save(model.state_dict(), SAVE_PATH)
        logger.info(f"✅ 最佳模型已保存！最佳验证AUC: {best_val_auc:.2f}%")

logger.info("\n🎉 训练完成！")
logger.info(f"最终最佳验证AUC: {best_val_auc:.2f}%")
# Out:
# 2026-05-21 01:58:59,264 - Train - INFO - ==================================================
# 2026-05-21 01:58:59,266 - Train - INFO - 开始训练！
# 2026-05-21 01:58:59,268 - Train - INFO - ==================================================
# 2026-05-21 01:58:59,270 - Train - INFO -
# Epoch [1/50]
# 训练中: 100%|██████████| 466/466 [01:48<00:00,  4.30it/s]
# 2026-05-21 02:01:01,193 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 0, 误判为pMCI: 78] | [pMCI漏判: 0, pMCI正确: 39]
# 2026-05-21 02:01:01,196 - Train - INFO - 🏆 评估指标: ACC: 33.33% | SEN: 100.00% | SPE: 0.00% | F1: 50.00% | AUC: 66.04%
# 2026-05-21 02:01:01,197 - Train - INFO - 训练损失: 0.2554 | 训练准确率: 65.99%
# 2026-05-21 02:01:01,198 - Train - INFO - 验证损失: 0.2456 | 验证准确率: 33.33%
# 2026-05-21 02:01:01,199 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-21 02:01:02,992 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 66.04%
# 2026-05-21 02:01:02,993 - Train - INFO -
# Epoch [2/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.44it/s]
# 2026-05-21 02:03:01,237 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 77, 误判为pMCI: 1] | [pMCI漏判: 36, pMCI正确: 3]
# 2026-05-21 02:03:01,241 - Train - INFO - 🏆 评估指标: ACC: 68.38% | SEN: 7.69% | SPE: 98.72% | F1: 13.95% | AUC: 72.49%
# 2026-05-21 02:03:01,244 - Train - INFO - 训练损失: 0.2469 | 训练准确率: 67.17%
# 2026-05-21 02:03:01,245 - Train - INFO - 验证损失: 0.2463 | 验证准确率: 68.38%
# 2026-05-21 02:03:01,246 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-21 02:03:02,425 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 72.49%
# 2026-05-21 02:03:02,429 - Train - INFO -
# Epoch [3/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.37it/s]
# 2026-05-21 02:05:04,185 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 77, 误判为pMCI: 1] | [pMCI漏判: 39, pMCI正确: 0]
# 2026-05-21 02:05:04,188 - Train - INFO - 🏆 评估指标: ACC: 65.81% | SEN: 0.00% | SPE: 98.72% | F1: 0.00% | AUC: 75.41%
# 2026-05-21 02:05:04,190 - Train - INFO - 训练损失: 0.2460 | 训练准确率: 67.17%
# 2026-05-21 02:05:04,191 - Train - INFO - 验证损失: 0.2462 | 验证准确率: 65.81%
# 2026-05-21 02:05:04,192 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-21 02:05:05,861 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 75.41%
# 2026-05-21 02:05:05,863 - Train - INFO -
# Epoch [4/50]
# 训练中: 100%|██████████| 466/466 [01:42<00:00,  4.53it/s]
# 2026-05-21 02:07:02,440 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 2, 误判为pMCI: 76] | [pMCI漏判: 0, pMCI正确: 39]
# 2026-05-21 02:07:02,443 - Train - INFO - 🏆 评估指标: ACC: 35.04% | SEN: 100.00% | SPE: 2.56% | F1: 50.65% | AUC: 75.90%
# 2026-05-21 02:07:02,446 - Train - INFO - 训练损失: 0.2443 | 训练准确率: 67.17%
# 2026-05-21 02:07:02,447 - Train - INFO - 验证损失: 0.2436 | 验证准确率: 35.04%
# 2026-05-21 02:07:02,448 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-21 02:07:03,792 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 75.90%
# 2026-05-21 02:07:03,793 - Train - INFO -
# Epoch [5/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.38it/s]
# 2026-05-21 02:09:04,013 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 60, 误判为pMCI: 18] | [pMCI漏判: 16, pMCI正确: 23]
# 2026-05-21 02:09:04,015 - Train - INFO - 🏆 评估指标: ACC: 70.94% | SEN: 58.97% | SPE: 76.92% | F1: 57.50% | AUC: 76.04%
# 2026-05-21 02:09:04,017 - Train - INFO - 训练损失: 0.2428 | 训练准确率: 67.17%
# 2026-05-21 02:09:04,018 - Train - INFO - 验证损失: 0.2437 | 验证准确率: 70.94%
# 2026-05-21 02:09:04,018 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-21 02:09:05,743 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 76.04%
# 2026-05-21 02:09:05,745 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-21 02:09:05,747 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！
# 2026-05-21 02:09:05,749 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-21 02:09:05,751 - Train - INFO -
# Epoch [6/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.38it/s]
# 2026-05-21 02:11:05,177 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 78, 误判为pMCI: 0] | [pMCI漏判: 39, pMCI正确: 0]
# 2026-05-21 02:11:05,179 - Train - INFO - 🏆 评估指标: ACC: 66.67% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 77.05%
# 2026-05-21 02:11:05,181 - Train - INFO - 训练损失: 0.2533 | 训练准确率: 67.17%
# 2026-05-21 02:11:05,182 - Train - INFO - 验证损失: 0.2816 | 验证准确率: 66.67%
# 2026-05-21 02:11:05,183 - Train - INFO - 当前学习率: 0.00004994
# 2026-05-21 02:11:06,674 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 77.05%
# 2026-05-21 02:11:06,676 - Train - INFO -
# Epoch [7/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.44it/s]
# 2026-05-21 02:13:04,687 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 78, 误判为pMCI: 0] | [pMCI漏判: 39, pMCI正确: 0]
# 2026-05-21 02:13:04,689 - Train - INFO - 🏆 评估指标: ACC: 66.67% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 77.78%
# 2026-05-21 02:13:04,692 - Train - INFO - 训练损失: 0.2595 | 训练准确率: 67.17%
# 2026-05-21 02:13:04,693 - Train - INFO - 验证损失: 0.2647 | 验证准确率: 66.67%
# 2026-05-21 02:13:04,694 - Train - INFO - 当前学习率: 0.00004976
# 2026-05-21 02:13:06,170 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 77.78%
# 2026-05-21 02:13:06,171 - Train - INFO -
# Epoch [8/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.50it/s]
# 2026-05-21 02:15:03,339 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 47, 误判为pMCI: 31] | [pMCI漏判: 7, pMCI正确: 32]
# 2026-05-21 02:15:03,341 - Train - INFO - 🏆 评估指标: ACC: 67.52% | SEN: 82.05% | SPE: 60.26% | F1: 62.75% | AUC: 76.63%
# 2026-05-21 02:15:03,343 - Train - INFO - 训练损失: 0.2467 | 训练准确率: 67.17%
# 2026-05-21 02:15:03,344 - Train - INFO - 验证损失: 0.2317 | 验证准确率: 67.52%
# 2026-05-21 02:15:03,345 - Train - INFO - 当前学习率: 0.00004945
# 2026-05-21 02:15:03,346 - Train - INFO -
# Epoch [9/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.46it/s]
# 2026-05-21 02:17:01,396 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 68, 误判为pMCI: 10] | [pMCI漏判: 20, pMCI正确: 19]
# 2026-05-21 02:17:01,398 - Train - INFO - 🏆 评估指标: ACC: 74.36% | SEN: 48.72% | SPE: 87.18% | F1: 55.88% | AUC: 77.09%
# 2026-05-21 02:17:01,400 - Train - INFO - 训练损失: 0.2467 | 训练准确率: 67.17%
# 2026-05-21 02:17:01,401 - Train - INFO - 验证损失: 0.2313 | 验证准确率: 74.36%
# 2026-05-21 02:17:01,402 - Train - INFO - 当前学习率: 0.00004903
# 2026-05-21 02:17:01,403 - Train - INFO -
# Epoch [10/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.48it/s]
# 2026-05-21 02:18:58,496 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 62, 误判为pMCI: 16] | [pMCI漏判: 17, pMCI正确: 22]
# 2026-05-21 02:18:58,498 - Train - INFO - 🏆 评估指标: ACC: 71.79% | SEN: 56.41% | SPE: 79.49% | F1: 57.14% | AUC: 77.61%
# 2026-05-21 02:18:58,500 - Train - INFO - 训练损失: 0.2387 | 训练准确率: 68.67%
# 2026-05-21 02:18:58,501 - Train - INFO - 验证损失: 0.2208 | 验证准确率: 71.79%
# 2026-05-21 02:18:58,502 - Train - INFO - 当前学习率: 0.00004849
# 2026-05-21 02:18:58,503 - Train - INFO -
# Epoch [11/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.49it/s]
# 2026-05-21 02:20:55,773 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 62, 误判为pMCI: 16] | [pMCI漏判: 15, pMCI正确: 24]
# 2026-05-21 02:20:55,776 - Train - INFO - 🏆 评估指标: ACC: 73.50% | SEN: 61.54% | SPE: 79.49% | F1: 60.76% | AUC: 78.53%
# 2026-05-21 02:20:55,778 - Train - INFO - 训练损失: 0.2257 | 训练准确率: 69.74%
# 2026-05-21 02:20:55,779 - Train - INFO - 验证损失: 0.2134 | 验证准确率: 73.50%
# 2026-05-21 02:20:55,780 - Train - INFO - 当前学习率: 0.00004784
# 2026-05-21 02:20:57,429 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 78.53%
# 2026-05-21 02:20:57,430 - Train - INFO -
# Epoch [12/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.43it/s]
# 2026-05-21 02:22:56,058 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 76, 误判为pMCI: 2] | [pMCI漏判: 30, pMCI正确: 9]
# 2026-05-21 02:22:56,061 - Train - INFO - 🏆 评估指标: ACC: 72.65% | SEN: 23.08% | SPE: 97.44% | F1: 36.00% | AUC: 79.65%
# 2026-05-21 02:22:56,063 - Train - INFO - 训练损失: 0.2385 | 训练准确率: 69.42%
# 2026-05-21 02:22:56,064 - Train - INFO - 验证损失: 0.3024 | 验证准确率: 72.65%
# 2026-05-21 02:22:56,065 - Train - INFO - 当前学习率: 0.00004707
# 2026-05-21 02:22:57,780 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 79.65%
# 2026-05-21 02:22:57,782 - Train - INFO -
# Epoch [13/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.51it/s]
# 2026-05-21 02:24:55,112 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 49, 误判为pMCI: 29] | [pMCI漏判: 8, pMCI正确: 31]
# 2026-05-21 02:24:55,115 - Train - INFO - 🏆 评估指标: ACC: 68.38% | SEN: 79.49% | SPE: 62.82% | F1: 62.63% | AUC: 79.49%
# 2026-05-21 02:24:55,118 - Train - INFO - 训练损失: 0.2574 | 训练准确率: 72.10%
# 2026-05-21 02:24:55,119 - Train - INFO - 验证损失: 0.2051 | 验证准确率: 68.38%
# 2026-05-21 02:24:55,120 - Train - INFO - 当前学习率: 0.00004620
# 2026-05-21 02:24:55,121 - Train - INFO -
# Epoch [14/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.38it/s]
# 2026-05-21 02:26:55,423 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 77, 误判为pMCI: 1] | [pMCI漏判: 35, pMCI正确: 4]
# 2026-05-21 02:26:55,427 - Train - INFO - 🏆 评估指标: ACC: 69.23% | SEN: 10.26% | SPE: 98.72% | F1: 18.18% | AUC: 79.75%
# 2026-05-21 02:26:55,428 - Train - INFO - 训练损失: 0.2566 | 训练准确率: 72.10%
# 2026-05-21 02:26:55,429 - Train - INFO - 验证损失: 0.4128 | 验证准确率: 69.23%
# 2026-05-21 02:26:55,431 - Train - INFO - 当前学习率: 0.00004523
# 2026-05-21 02:26:57,162 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 79.75%
# 2026-05-21 02:26:57,164 - Train - INFO -
# Epoch [15/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.48it/s]
# 2026-05-21 02:28:54,372 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 71, 误判为pMCI: 7] | [pMCI漏判: 20, pMCI正确: 19]
# 2026-05-21 02:28:54,374 - Train - INFO - 🏆 评估指标: ACC: 76.92% | SEN: 48.72% | SPE: 91.03% | F1: 58.46% | AUC: 80.34%
# 2026-05-21 02:28:54,375 - Train - INFO - 训练损失: 0.2935 | 训练准确率: 72.10%
# 2026-05-21 02:28:54,376 - Train - INFO - 验证损失: 0.2459 | 验证准确率: 76.92%
# 2026-05-21 02:28:54,378 - Train - INFO - 当前学习率: 0.00004415
# 2026-05-21 02:28:55,952 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 80.34%
# 2026-05-21 02:28:55,953 - Train - INFO -
# Epoch [16/50]
# 训练中: 100%|██████████| 466/466 [01:47<00:00,  4.34it/s]
# 2026-05-21 02:30:57,565 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 51, 误判为pMCI: 27] | [pMCI漏判: 9, pMCI正确: 30]
# 2026-05-21 02:30:57,567 - Train - INFO - 🏆 评估指标: ACC: 69.23% | SEN: 76.92% | SPE: 65.38% | F1: 62.50% | AUC: 80.28%
# 2026-05-21 02:30:57,568 - Train - INFO - 训练损失: 0.2733 | 训练准确率: 72.00%
# 2026-05-21 02:30:57,568 - Train - INFO - 验证损失: 0.2242 | 验证准确率: 69.23%
# 2026-05-21 02:30:57,569 - Train - INFO - 当前学习率: 0.00004298
# 2026-05-21 02:30:57,569 - Train - INFO -
# Epoch [17/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.36it/s]
# 2026-05-21 02:32:58,337 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 35] | [pMCI漏判: 6, pMCI正确: 33]
# 2026-05-21 02:32:58,340 - Train - INFO - 🏆 评估指标: ACC: 64.96% | SEN: 84.62% | SPE: 55.13% | F1: 61.68% | AUC: 80.18%
# 2026-05-21 02:32:58,341 - Train - INFO - 训练损失: 0.2786 | 训练准确率: 75.75%
# 2026-05-21 02:32:58,342 - Train - INFO - 验证损失: 0.2554 | 验证准确率: 64.96%
# 2026-05-21 02:32:58,343 - Train - INFO - 当前学习率: 0.00004173
# 2026-05-21 02:32:58,344 - Train - INFO -
# Epoch [18/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.39it/s]
# 2026-05-21 02:34:58,395 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 65, 误判为pMCI: 13] | [pMCI漏判: 15, pMCI正确: 24]
# 2026-05-21 02:34:58,397 - Train - INFO - 🏆 评估指标: ACC: 76.07% | SEN: 61.54% | SPE: 83.33% | F1: 63.16% | AUC: 81.53%
# 2026-05-21 02:34:58,399 - Train - INFO - 训练损失: 0.2941 | 训练准确率: 74.79%
# 2026-05-21 02:34:58,400 - Train - INFO - 验证损失: 0.2449 | 验证准确率: 76.07%
# 2026-05-21 02:34:58,402 - Train - INFO - 当前学习率: 0.00004039
# 2026-05-21 02:35:00,177 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 81.53%
# 2026-05-21 02:35:00,178 - Train - INFO -
# Epoch [19/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.41it/s]
# 2026-05-21 02:36:59,029 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 67, 误判为pMCI: 11] | [pMCI漏判: 15, pMCI正确: 24]
# 2026-05-21 02:36:59,031 - Train - INFO - 🏆 评估指标: ACC: 77.78% | SEN: 61.54% | SPE: 85.90% | F1: 64.86% | AUC: 81.46%
# 2026-05-21 02:36:59,033 - Train - INFO - 训练损失: 0.2773 | 训练准确率: 76.93%
# 2026-05-21 02:36:59,034 - Train - INFO - 验证损失: 0.2683 | 验证准确率: 77.78%
# 2026-05-21 02:36:59,035 - Train - INFO - 当前学习率: 0.00003898
# 2026-05-21 02:36:59,036 - Train - INFO -
# Epoch [20/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.40it/s]
# 2026-05-21 02:38:58,671 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 77, 误判为pMCI: 1] | [pMCI漏判: 32, pMCI正确: 7]
# 2026-05-21 02:38:58,673 - Train - INFO - 🏆 评估指标: ACC: 71.79% | SEN: 17.95% | SPE: 98.72% | F1: 29.79% | AUC: 82.31%
# 2026-05-21 02:38:58,675 - Train - INFO - 训练损失: 0.3216 | 训练准确率: 76.07%
# 2026-05-21 02:38:58,676 - Train - INFO - 验证损失: 0.4903 | 验证准确率: 71.79%
# 2026-05-21 02:38:58,676 - Train - INFO - 当前学习率: 0.00003750
# 2026-05-21 02:39:00,351 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 82.31%
# 2026-05-21 02:39:00,353 - Train - INFO -
# Epoch [21/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.49it/s]
# 2026-05-21 02:40:58,052 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 59, 误判为pMCI: 19] | [pMCI漏判: 12, pMCI正确: 27]
# 2026-05-21 02:40:58,055 - Train - INFO - 🏆 评估指标: ACC: 73.50% | SEN: 69.23% | SPE: 75.64% | F1: 63.53% | AUC: 81.92%
# 2026-05-21 02:40:58,057 - Train - INFO - 训练损失: 0.2999 | 训练准确率: 76.18%
# 2026-05-21 02:40:58,058 - Train - INFO - 验证损失: 0.2511 | 验证准确率: 73.50%
# 2026-05-21 02:40:58,059 - Train - INFO - 当前学习率: 0.00003596
# 2026-05-21 02:40:58,059 - Train - INFO -
# Epoch [22/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.37it/s]
# 2026-05-21 02:42:58,356 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 45, 误判为pMCI: 33] | [pMCI漏判: 6, pMCI正确: 33]
# 2026-05-21 02:42:58,359 - Train - INFO - 🏆 评估指标: ACC: 66.67% | SEN: 84.62% | SPE: 57.69% | F1: 62.86% | AUC: 81.13%
# 2026-05-21 02:42:58,360 - Train - INFO - 训练损失: 0.2809 | 训练准确率: 76.93%
# 2026-05-21 02:42:58,362 - Train - INFO - 验证损失: 0.3498 | 验证准确率: 66.67%
# 2026-05-21 02:42:58,362 - Train - INFO - 当前学习率: 0.00003437
# 2026-05-21 02:42:58,364 - Train - INFO -
# Epoch [23/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.38it/s]
# 2026-05-21 02:44:57,668 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 54, 误判为pMCI: 24] | [pMCI漏判: 11, pMCI正确: 28]
# 2026-05-21 02:44:57,671 - Train - INFO - 🏆 评估指标: ACC: 70.09% | SEN: 71.79% | SPE: 69.23% | F1: 61.54% | AUC: 81.89%
# 2026-05-21 02:44:57,673 - Train - INFO - 训练损失: 0.3001 | 训练准确率: 77.58%
# 2026-05-21 02:44:57,674 - Train - INFO - 验证损失: 0.3011 | 验证准确率: 70.09%
# 2026-05-21 02:44:57,675 - Train - INFO - 当前学习率: 0.00003273
# 2026-05-21 02:44:57,677 - Train - INFO -
# Epoch [24/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.52it/s]
# 2026-05-21 02:46:55,106 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 69, 误判为pMCI: 9] | [pMCI漏判: 17, pMCI正确: 22]
# 2026-05-21 02:46:55,110 - Train - INFO - 🏆 评估指标: ACC: 77.78% | SEN: 56.41% | SPE: 88.46% | F1: 62.86% | AUC: 83.37%
# 2026-05-21 02:46:55,112 - Train - INFO - 训练损失: 0.2844 | 训练准确率: 78.22%
# 2026-05-21 02:46:55,114 - Train - INFO - 验证损失: 0.3160 | 验证准确率: 77.78%
# 2026-05-21 02:46:55,115 - Train - INFO - 当前学习率: 0.00003105
# 2026-05-21 02:46:56,983 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 83.37%
# 2026-05-21 02:46:56,985 - Train - INFO -
# Epoch [25/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.45it/s]
# 2026-05-21 02:48:55,238 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 70, 误判为pMCI: 8] | [pMCI漏判: 17, pMCI正确: 22]
# 2026-05-21 02:48:55,240 - Train - INFO - 🏆 评估指标: ACC: 78.63% | SEN: 56.41% | SPE: 89.74% | F1: 63.77% | AUC: 83.56%
# 2026-05-21 02:48:55,242 - Train - INFO - 训练损失: 0.3047 | 训练准确率: 79.40%
# 2026-05-21 02:48:55,243 - Train - INFO - 验证损失: 0.3150 | 验证准确率: 78.63%
# 2026-05-21 02:48:55,244 - Train - INFO - 当前学习率: 0.00002934
# 2026-05-21 02:48:56,937 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 83.56%
# 2026-05-21 02:48:56,940 - Train - INFO -
# Epoch [26/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.40it/s]
# 2026-05-21 02:50:57,609 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 51, 误判为pMCI: 27] | [pMCI漏判: 9, pMCI正确: 30]
# 2026-05-21 02:50:57,611 - Train - INFO - 🏆 评估指标: ACC: 69.23% | SEN: 76.92% | SPE: 65.38% | F1: 62.50% | AUC: 82.35%
# 2026-05-21 02:50:57,613 - Train - INFO - 训练损失: 0.2892 | 训练准确率: 78.11%
# 2026-05-21 02:50:57,614 - Train - INFO - 验证损失: 0.3276 | 验证准确率: 69.23%
# 2026-05-21 02:50:57,615 - Train - INFO - 当前学习率: 0.00002761
# 2026-05-21 02:50:57,616 - Train - INFO -
# Epoch [27/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.49it/s]
# 2026-05-21 02:52:56,946 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 60, 误判为pMCI: 18] | [pMCI漏判: 13, pMCI正确: 26]
# 2026-05-21 02:52:56,948 - Train - INFO - 🏆 评估指标: ACC: 73.50% | SEN: 66.67% | SPE: 76.92% | F1: 62.65% | AUC: 83.14%
# 2026-05-21 02:52:56,949 - Train - INFO - 训练损失: 0.3028 | 训练准确率: 78.97%
# 2026-05-21 02:52:56,950 - Train - INFO - 验证损失: 0.2979 | 验证准确率: 73.50%
# 2026-05-21 02:52:56,951 - Train - INFO - 当前学习率: 0.00002587
# 2026-05-21 02:52:56,953 - Train - INFO -
# Epoch [28/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.36it/s]
# 2026-05-21 02:54:57,322 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 76, 误判为pMCI: 2] | [pMCI漏判: 23, pMCI正确: 16]
# 2026-05-21 02:54:57,324 - Train - INFO - 🏆 评估指标: ACC: 78.63% | SEN: 41.03% | SPE: 97.44% | F1: 56.14% | AUC: 84.25%
# 2026-05-21 02:54:57,326 - Train - INFO - 训练损失: 0.3082 | 训练准确率: 80.15%
# 2026-05-21 02:54:57,327 - Train - INFO - 验证损失: 0.3939 | 验证准确率: 78.63%
# 2026-05-21 02:54:57,328 - Train - INFO - 当前学习率: 0.00002413
# 2026-05-21 02:54:58,896 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 84.25%
# 2026-05-21 02:54:58,897 - Train - INFO -
# Epoch [29/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.47it/s]
# 2026-05-21 02:56:56,573 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 54, 误判为pMCI: 24] | [pMCI漏判: 10, pMCI正确: 29]
# 2026-05-21 02:56:56,575 - Train - INFO - 🏆 评估指标: ACC: 70.94% | SEN: 74.36% | SPE: 69.23% | F1: 63.04% | AUC: 82.77%
# 2026-05-21 02:56:56,577 - Train - INFO - 训练损失: 0.2922 | 训练准确率: 78.43%
# 2026-05-21 02:56:56,578 - Train - INFO - 验证损失: 0.3032 | 验证准确率: 70.94%
# 2026-05-21 02:56:56,579 - Train - INFO - 当前学习率: 0.00002239
# 2026-05-21 02:56:56,580 - Train - INFO -
# Epoch [30/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.46it/s]
# 2026-05-21 02:58:55,933 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 65, 误判为pMCI: 13] | [pMCI漏判: 13, pMCI正确: 26]
# 2026-05-21 02:58:55,935 - Train - INFO - 🏆 评估指标: ACC: 77.78% | SEN: 66.67% | SPE: 83.33% | F1: 66.67% | AUC: 83.76%
# 2026-05-21 02:58:55,937 - Train - INFO - 训练损失: 0.2857 | 训练准确率: 81.12%
# 2026-05-21 02:58:55,938 - Train - INFO - 验证损失: 0.3290 | 验证准确率: 77.78%
# 2026-05-21 02:58:55,939 - Train - INFO - 当前学习率: 0.00002066
# 2026-05-21 02:58:55,939 - Train - INFO -
# Epoch [31/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.39it/s]
# 2026-05-21 03:00:56,795 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 67, 误判为pMCI: 11] | [pMCI漏判: 14, pMCI正确: 25]
# 2026-05-21 03:00:56,797 - Train - INFO - 🏆 评估指标: ACC: 78.63% | SEN: 64.10% | SPE: 85.90% | F1: 66.67% | AUC: 84.39%
# 2026-05-21 03:00:56,798 - Train - INFO - 训练损失: 0.3132 | 训练准确率: 80.47%
# 2026-05-21 03:00:56,799 - Train - INFO - 验证损失: 0.3041 | 验证准确率: 78.63%
# 2026-05-21 03:00:56,800 - Train - INFO - 当前学习率: 0.00001895
# 2026-05-21 03:00:58,522 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 84.39%
# 2026-05-21 03:00:58,525 - Train - INFO -
# Epoch [32/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.48it/s]
# 2026-05-21 03:02:56,273 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 50, 误判为pMCI: 28] | [pMCI漏判: 7, pMCI正确: 32]
# 2026-05-21 03:02:56,275 - Train - INFO - 🏆 评估指标: ACC: 70.09% | SEN: 82.05% | SPE: 64.10% | F1: 64.65% | AUC: 82.51%
# 2026-05-21 03:02:56,277 - Train - INFO - 训练损失: 0.2870 | 训练准确率: 81.65%
# 2026-05-21 03:02:56,278 - Train - INFO - 验证损失: 0.3384 | 验证准确率: 70.09%
# 2026-05-21 03:02:56,279 - Train - INFO - 当前学习率: 0.00001727
# 2026-05-21 03:02:56,279 - Train - INFO -
# Epoch [33/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.51it/s]
# 2026-05-21 03:04:53,635 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 67, 误判为pMCI: 11] | [pMCI漏判: 14, pMCI正确: 25]
# 2026-05-21 03:04:53,638 - Train - INFO - 🏆 评估指标: ACC: 78.63% | SEN: 64.10% | SPE: 85.90% | F1: 66.67% | AUC: 84.35%
# 2026-05-21 03:04:53,640 - Train - INFO - 训练损失: 0.2884 | 训练准确率: 80.15%
# 2026-05-21 03:04:53,640 - Train - INFO - 验证损失: 0.3016 | 验证准确率: 78.63%
# 2026-05-21 03:04:53,641 - Train - INFO - 当前学习率: 0.00001563
# 2026-05-21 03:04:53,642 - Train - INFO -
# Epoch [34/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.49it/s]
# 2026-05-21 03:06:51,003 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 67, 误判为pMCI: 11] | [pMCI漏判: 14, pMCI正确: 25]
# 2026-05-21 03:06:51,005 - Train - INFO - 🏆 评估指标: ACC: 78.63% | SEN: 64.10% | SPE: 85.90% | F1: 66.67% | AUC: 84.45%
# 2026-05-21 03:06:51,007 - Train - INFO - 训练损失: 0.3127 | 训练准确率: 79.94%
# 2026-05-21 03:06:51,007 - Train - INFO - 验证损失: 0.3129 | 验证准确率: 78.63%
# 2026-05-21 03:06:51,008 - Train - INFO - 当前学习率: 0.00001404
# 2026-05-21 03:06:52,146 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 84.45%
# 2026-05-21 03:06:52,147 - Train - INFO -
# Epoch [35/50]
# 训练中: 100%|██████████| 466/466 [01:43<00:00,  4.49it/s]
# 2026-05-21 03:08:50,258 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 61, 误判为pMCI: 17] | [pMCI漏判: 13, pMCI正确: 26]
# 2026-05-21 03:08:50,260 - Train - INFO - 🏆 评估指标: ACC: 74.36% | SEN: 66.67% | SPE: 78.21% | F1: 63.41% | AUC: 84.39%
# 2026-05-21 03:08:50,262 - Train - INFO - 训练损失: 0.2856 | 训练准确率: 80.04%
# 2026-05-21 03:08:50,263 - Train - INFO - 验证损失: 0.3175 | 验证准确率: 74.36%
# 2026-05-21 03:08:50,264 - Train - INFO - 当前学习率: 0.00001250
# 2026-05-21 03:08:50,265 - Train - INFO -
# Epoch [36/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.43it/s]
# 2026-05-21 03:10:49,794 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 64, 误判为pMCI: 14] | [pMCI漏判: 13, pMCI正确: 26]
# 2026-05-21 03:10:49,795 - Train - INFO - 🏆 评估指标: ACC: 76.92% | SEN: 66.67% | SPE: 82.05% | F1: 65.82% | AUC: 84.32%
# 2026-05-21 03:10:49,797 - Train - INFO - 训练损失: 0.2868 | 训练准确率: 81.22%
# 2026-05-21 03:10:49,798 - Train - INFO - 验证损失: 0.3310 | 验证准确率: 76.92%
# 2026-05-21 03:10:49,799 - Train - INFO - 当前学习率: 0.00001102
# 2026-05-21 03:10:49,800 - Train - INFO -
# Epoch [37/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.45it/s]
# 2026-05-21 03:12:48,347 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 67, 误判为pMCI: 11] | [pMCI漏判: 14, pMCI正确: 25]
# 2026-05-21 03:12:48,349 - Train - INFO - 🏆 评估指标: ACC: 78.63% | SEN: 64.10% | SPE: 85.90% | F1: 66.67% | AUC: 84.45%
# 2026-05-21 03:12:48,351 - Train - INFO - 训练损失: 0.2896 | 训练准确率: 81.55%
# 2026-05-21 03:12:48,352 - Train - INFO - 验证损失: 0.3435 | 验证准确率: 78.63%
# 2026-05-21 03:12:48,353 - Train - INFO - 当前学习率: 0.00000961
# 2026-05-21 03:12:48,354 - Train - INFO -
# Epoch [38/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.40it/s]
# 2026-05-21 03:14:49,428 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 65, 误判为pMCI: 13] | [pMCI漏判: 14, pMCI正确: 25]
# 2026-05-21 03:14:49,431 - Train - INFO - 🏆 评估指标: ACC: 76.92% | SEN: 64.10% | SPE: 83.33% | F1: 64.94% | AUC: 84.52%
# 2026-05-21 03:14:49,432 - Train - INFO - 训练损失: 0.3034 | 训练准确率: 81.76%
# 2026-05-21 03:14:49,434 - Train - INFO - 验证损失: 0.3376 | 验证准确率: 76.92%
# 2026-05-21 03:14:49,435 - Train - INFO - 当前学习率: 0.00000827
# 2026-05-21 03:14:51,440 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 84.52%
# 2026-05-21 03:14:51,442 - Train - INFO -
# Epoch [39/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.39it/s]
# 2026-05-21 03:16:50,462 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 72, 误判为pMCI: 6] | [pMCI漏判: 16, pMCI正确: 23]
# 2026-05-21 03:16:50,464 - Train - INFO - 🏆 评估指标: ACC: 81.20% | SEN: 58.97% | SPE: 92.31% | F1: 67.65% | AUC: 84.91%
# 2026-05-21 03:16:50,466 - Train - INFO - 训练损失: 0.2977 | 训练准确率: 82.30%
# 2026-05-21 03:16:50,467 - Train - INFO - 验证损失: 0.3687 | 验证准确率: 81.20%
# 2026-05-21 03:16:50,468 - Train - INFO - 当前学习率: 0.00000702
# 2026-05-21 03:16:52,141 - Train - INFO - ✅ 最佳模型已保存！最佳验证AUC: 84.91%
# 2026-05-21 03:16:52,143 - Train - INFO -
# Epoch [40/50]
# 训练中: 100%|██████████| 466/466 [01:42<00:00,  4.54it/s]
# 2026-05-21 03:18:48,725 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 65, 误判为pMCI: 13] | [pMCI漏判: 14, pMCI正确: 25]
# 2026-05-21 03:18:48,727 - Train - INFO - 🏆 评估指标: ACC: 76.92% | SEN: 64.10% | SPE: 83.33% | F1: 64.94% | AUC: 84.62%
# 2026-05-21 03:18:48,729 - Train - INFO - 训练损失: 0.2955 | 训练准确率: 81.55%
# 2026-05-21 03:18:48,730 - Train - INFO - 验证损失: 0.3175 | 验证准确率: 76.92%
# 2026-05-21 03:18:48,731 - Train - INFO - 当前学习率: 0.00000585
# 2026-05-21 03:18:48,732 - Train - INFO -
# Epoch [41/50]
# 训练中: 100%|██████████| 466/466 [01:42<00:00,  4.55it/s]
# 2026-05-21 03:20:44,358 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 55, 误判为pMCI: 23] | [pMCI漏判: 9, pMCI正确: 30]
# 2026-05-21 03:20:44,360 - Train - INFO - 🏆 评估指标: ACC: 72.65% | SEN: 76.92% | SPE: 70.51% | F1: 65.22% | AUC: 84.19%
# 2026-05-21 03:20:44,362 - Train - INFO - 训练损失: 0.3037 | 训练准确率: 80.04%
# 2026-05-21 03:20:44,363 - Train - INFO - 验证损失: 0.3561 | 验证准确率: 72.65%
# 2026-05-21 03:20:44,364 - Train - INFO - 当前学习率: 0.00000477
# 2026-05-21 03:20:44,366 - Train - INFO -
# Epoch [42/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.45it/s]
# 2026-05-21 03:22:43,106 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 63, 误判为pMCI: 15] | [pMCI漏判: 14, pMCI正确: 25]
# 2026-05-21 03:22:43,108 - Train - INFO - 🏆 评估指标: ACC: 75.21% | SEN: 64.10% | SPE: 80.77% | F1: 63.29% | AUC: 84.55%
# 2026-05-21 03:22:43,110 - Train - INFO - 训练损失: 0.2744 | 训练准确率: 83.15%
# 2026-05-21 03:22:43,111 - Train - INFO - 验证损失: 0.3226 | 验证准确率: 75.21%
# 2026-05-21 03:22:43,112 - Train - INFO - 当前学习率: 0.00000380
# 2026-05-21 03:22:43,113 - Train - INFO -
# Epoch [43/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.44it/s]
# 2026-05-21 03:24:41,466 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 60, 误判为pMCI: 18] | [pMCI漏判: 12, pMCI正确: 27]
# 2026-05-21 03:24:41,468 - Train - INFO - 🏆 评估指标: ACC: 74.36% | SEN: 69.23% | SPE: 76.92% | F1: 64.29% | AUC: 84.39%
# 2026-05-21 03:24:41,471 - Train - INFO - 训练损失: 0.2886 | 训练准确率: 82.62%
# 2026-05-21 03:24:41,472 - Train - INFO - 验证损失: 0.3182 | 验证准确率: 74.36%
# 2026-05-21 03:24:41,473 - Train - INFO - 当前学习率: 0.00000293
# 2026-05-21 03:24:41,474 - Train - INFO -
# Epoch [44/50]
# 训练中: 100%|██████████| 466/466 [01:47<00:00,  4.35it/s]
# 2026-05-21 03:26:41,452 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 60, 误判为pMCI: 18] | [pMCI漏判: 12, pMCI正确: 27]
# 2026-05-21 03:26:41,454 - Train - INFO - 🏆 评估指标: ACC: 74.36% | SEN: 69.23% | SPE: 76.92% | F1: 64.29% | AUC: 84.45%
# 2026-05-21 03:26:41,456 - Train - INFO - 训练损失: 0.2588 | 训练准确率: 83.69%
# 2026-05-21 03:26:41,457 - Train - INFO - 验证损失: 0.3238 | 验证准确率: 74.36%
# 2026-05-21 03:26:41,458 - Train - INFO - 当前学习率: 0.00000216
# 2026-05-21 03:26:41,459 - Train - INFO -
# Epoch [45/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.42it/s]
# 2026-05-21 03:28:40,250 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 54, 误判为pMCI: 24] | [pMCI漏判: 8, pMCI正确: 31]
# 2026-05-21 03:28:40,252 - Train - INFO - 🏆 评估指标: ACC: 72.65% | SEN: 79.49% | SPE: 69.23% | F1: 65.96% | AUC: 84.25%
# 2026-05-21 03:28:40,254 - Train - INFO - 训练损失: 0.2827 | 训练准确率: 82.40%
# 2026-05-21 03:28:40,255 - Train - INFO - 验证损失: 0.3737 | 验证准确率: 72.65%
# 2026-05-21 03:28:40,255 - Train - INFO - 当前学习率: 0.00000151
# 2026-05-21 03:28:40,256 - Train - INFO -
# Epoch [46/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.42it/s]
# 2026-05-21 03:30:38,755 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 58, 误判为pMCI: 20] | [pMCI漏判: 11, pMCI正确: 28]
# 2026-05-21 03:30:38,758 - Train - INFO - 🏆 评估指标: ACC: 73.50% | SEN: 71.79% | SPE: 74.36% | F1: 64.37% | AUC: 84.35%
# 2026-05-21 03:30:38,760 - Train - INFO - 训练损失: 0.2806 | 训练准确率: 83.05%
# 2026-05-21 03:30:38,761 - Train - INFO - 验证损失: 0.3377 | 验证准确率: 73.50%
# 2026-05-21 03:30:38,761 - Train - INFO - 当前学习率: 0.00000097
# 2026-05-21 03:30:38,762 - Train - INFO -
# Epoch [47/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.45it/s]
# 2026-05-21 03:32:38,676 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 58, 误判为pMCI: 20] | [pMCI漏判: 11, pMCI正确: 28]
# 2026-05-21 03:32:38,679 - Train - INFO - 🏆 评估指标: ACC: 73.50% | SEN: 71.79% | SPE: 74.36% | F1: 64.37% | AUC: 84.29%
# 2026-05-21 03:32:38,681 - Train - INFO - 训练损失: 0.2707 | 训练准确率: 82.73%
# 2026-05-21 03:32:38,682 - Train - INFO - 验证损失: 0.3352 | 验证准确率: 73.50%
# 2026-05-21 03:32:38,683 - Train - INFO - 当前学习率: 0.00000055
# 2026-05-21 03:32:38,684 - Train - INFO -
# Epoch [48/50]
# 训练中: 100%|██████████| 466/466 [01:44<00:00,  4.45it/s]
# 2026-05-21 03:34:36,743 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 60, 误判为pMCI: 18] | [pMCI漏判: 12, pMCI正确: 27]
# 2026-05-21 03:34:36,745 - Train - INFO - 🏆 评估指标: ACC: 74.36% | SEN: 69.23% | SPE: 76.92% | F1: 64.29% | AUC: 84.45%
# 2026-05-21 03:34:36,747 - Train - INFO - 训练损失: 0.2674 | 训练准确率: 82.30%
# 2026-05-21 03:34:36,749 - Train - INFO - 验证损失: 0.3291 | 验证准确率: 74.36%
# 2026-05-21 03:34:36,750 - Train - INFO - 当前学习率: 0.00000024
# 2026-05-21 03:34:36,751 - Train - INFO -
# Epoch [49/50]
# 训练中: 100%|██████████| 466/466 [01:46<00:00,  4.39it/s]
# 2026-05-21 03:36:36,786 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 60, 误判为pMCI: 18] | [pMCI漏判: 11, pMCI正确: 28]
# 2026-05-21 03:36:36,788 - Train - INFO - 🏆 评估指标: ACC: 75.21% | SEN: 71.79% | SPE: 76.92% | F1: 65.88% | AUC: 84.42%
# 2026-05-21 03:36:36,790 - Train - INFO - 训练损失: 0.2697 | 训练准确率: 83.37%
# 2026-05-21 03:36:36,791 - Train - INFO - 验证损失: 0.3303 | 验证准确率: 75.21%
# 2026-05-21 03:36:36,792 - Train - INFO - 当前学习率: 0.00000006
# 2026-05-21 03:36:36,793 - Train - INFO -
# Epoch [50/50]
# 训练中: 100%|██████████| 466/466 [01:45<00:00,  4.42it/s]
# 2026-05-21 03:38:35,358 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 60, 误判为pMCI: 18] | [pMCI漏判: 11, pMCI正确: 28]
# 2026-05-21 03:38:35,361 - Train - INFO - 🏆 评估指标: ACC: 75.21% | SEN: 71.79% | SPE: 76.92% | F1: 65.88% | AUC: 84.42%
# 2026-05-21 03:38:35,363 - Train - INFO - 训练损失: 0.2713 | 训练准确率: 83.26%
# 2026-05-21 03:38:35,364 - Train - INFO - 验证损失: 0.3306 | 验证准确率: 75.21%
# 2026-05-21 03:38:35,365 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-21 03:38:35,366 - Train - INFO -
# 🎉 训练完成！
# 2026-05-21 03:38:35,367 - Train - INFO - 最终最佳验证AUC: 84.91%

# %%
# import torch
# import torch.nn.functional as F
# import numpy as np
# import matplotlib.pyplot as plt

# # ==========================================
# # 第一步：加载你跑出 74.39% 的最佳模型权重
# # ==========================================
# print("🔄 正在加载最佳模型权重...")

# # 实例化模型 (确保这里的参数和你跑出最好成绩的那次完全一致)
# # 之前确认过 FEATURE_SIZE 是 24
# vis_model = APM_Former_ImageOnly(
#     feature_size=24,  
#     num_classes=2
# ).to(DEVICE)

# # ⚠️ 注意：把这里的 'best_model.pth' 换成你实际保存的权重文件名！
# # 比如可能是 'checkpoint_epoch_xx.pth'
# checkpoint_path = 'checkpoints/best_model.pth'  
# state_dict = torch.load(checkpoint_path, map_location=DEVICE)
# vis_model.load_state_dict(state_dict)

# vis_model.eval() # 切换到评估模式
# print(f"✅ 成功加载权重: {checkpoint_path}")
# print("-" * 50)


# # ==========================================
# # 第二步：定义并运行可视化探针
# # ==========================================
# @torch.no_grad()
# def visualize_pMCI_attention(model, val_loader, device, num_cases_to_show=3):
#     model.eval()
#     found_cases = 0
    
#     # 解决 matplotlib 中文显示问题
#     # plt.rcParams['font.sans-serif'] = ['SimHei'] 
#     # plt.rcParams['axes.unicode_minus'] = False
    
#     print("🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...\n")
    
#     for images, labels in val_loader:
#         images = images.to(device)
#         labels = labels.to(device)
        
#         logits, _, spatial_attention = model(images)
#         preds = torch.argmax(logits, dim=1)
        
#         # 寻找 True Positives (真实为pMCI，预测也为pMCI)
#         for i in range(len(labels)):
#             if labels[i].item() == 1 and preds[i].item() == 1:
#                 found_cases += 1
                
#                 # 1. 提取原始 3D MRI 图像
#                 img_3d = images[i, 0].cpu().numpy()  
                
#                 # 2. 提取注意力掩码，并插值放大到原始图像大小 (96, 96, 96)
#                 attn_tensor = spatial_attention[i:i+1] 
#                 attn_resized = F.interpolate(attn_tensor, size=img_3d.shape, mode='trilinear', align_corners=False)
#                 attn_3d = attn_resized[0, 0].cpu().numpy()
                
#                 # 3. 智能寻找网络最关注的切片位置
#                 slice_x = np.argmax(np.sum(attn_3d, axis=(1, 2))) 
#                 slice_y = np.argmax(np.sum(attn_3d, axis=(0, 2))) 
#                 slice_z = np.argmax(np.sum(attn_3d, axis=(0, 1))) 
                
#                 # 4. 绘图
#                 fig, axes = plt.subplots(1, 3, figsize=(18, 6))
#                 # 成功识别的pMCI阳性病例  高亮区域为网络空间对齐中点关注区域
#                 fig.suptitle(f"True Positive pMCI Case #{found_cases}\n(Spatial Attention Guided Alignment)", fontsize=18, fontweight='bold', y=1.05)
                
#                 # 矢状面 矢状面切片
#                 axes[0].imshow(img_3d[slice_x, :, :], cmap='gray') 
#                 im = axes[0].imshow(attn_3d[slice_x, :, :], cmap='jet', alpha=0.45) 
#                 axes[0].set_title(f"Sagittal View (Slice {slice_x})", fontsize=14)
#                 axes[0].axis('off')
                
#                 # 冠状面 冠状面切片
#                 axes[1].imshow(img_3d[:, slice_y, :], cmap='gray')
#                 axes[1].imshow(attn_3d[:, slice_y, :], cmap='jet', alpha=0.45)
#                 axes[1].set_title(f"Coronal View (Slice {slice_y})", fontsize=14)
#                 axes[1].axis('off')
                
#                 # 轴状面 轴状面切片
#                 axes[2].imshow(img_3d[:, :, slice_z], cmap='gray')
#                 axes[2].imshow(attn_3d[:, :, slice_z], cmap='jet', alpha=0.45)
#                 axes[2].set_title(f"Axial View (Slice {slice_z})", fontsize=14)
#                 axes[2].axis('off')
                
#                 # 颜色条的标签 解剖引导强度
#                 cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
#                 cbar.set_label('Attention Weight', fontsize=12)
                
#                 plt.show()
                
#                 if found_cases >= num_cases_to_show:
#                     print(f"\n✅ 成功提取 {num_cases_to_show} 组 pMCI 空间注意力图！")
#                     return

#     print(f"\n搜索结束，共找到 {found_cases} 个符合条件的病例。")

# # 执行探针！展示前 5 个最典型的病例
# visualize_pMCI_attention(vis_model, val_loader, DEVICE, num_cases_to_show=5)
