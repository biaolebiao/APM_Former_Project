# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 71.95% 74.39%
# seed 3407 71.95% 75.61%
# seed 1234 73.17% 69.51%
# seed 98 71.95% 73.17%
# seed 20  69.51%
# seed 1024
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
UNFREEZE_EPOCH = 5  # 设定前 5 个 epoch 为阶段一
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 50
GRADIENT_ACCUMULATION_STEPS = 1
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SAVE_PATH = "checkpoints/best_mci_A.pth"
PRETRAINED_SWIN_PATH = "checkpoints/model_swinvit.pt"
SEED = 3407

set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-05-26 08:31:50,268 - Train - INFO - ==================================================
# 2026-05-26 08:31:50,269 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-05-26 08:31:50,270 - Train - INFO - ==================================================
# 2026-05-26 08:31:50,271 - Train - INFO - ▶ 随机种子 (SEED): 3407
# 2026-05-26 08:31:50,272 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-05-26 08:31:50,273 - Train - INFO - ▶ 预热轮数 (Warmup Epochs): 5
# 2026-05-26 08:31:50,274 - Train - INFO - ▶ 批次大小 (Batch Size): 2
# 2026-05-26 08:31:50,275 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-05-26 08:31:50,276 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-05-26 08:31:50,277 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-05-26 08:31:50,278 - Train - INFO - ==================================================
# 2026-05-26 08:31:50,279 - Train - INFO - 训练设备: cuda
# 2026-05-26 08:31:50,280 - Train - INFO - 批次大小: 2
# 2026-05-26 08:31:50,281 - Train - INFO - 总轮数: 50

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS,
    use_sampler=False
)
# Out:
# 2026-05-26 08:31:50,334 - Train - INFO - 正在加载数据集...
# 2026-05-26 08:31:50,345 - utils.dataset - INFO - ✅ 成功加载 82 个样本
# 2026-05-26 08:31:50,346 - utils.dataset - INFO - 🧪 启用【原生数据分布 (Shuffle) + 基础增强】策略
# 2026-05-26 08:31:50,391 - utils.dataset - INFO - ✅ 成功加载 656 个样本
# 2026-05-26 08:31:50,392 - utils.dataset - INFO - 训练集批次: 328，验证集批次: 41

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model = APM_Former_ImageOnly(
    img_size=TRAIN_IMG_SIZE,
    in_channels=1,
    num_classes=NUM_CLASSES,
    feature_size=FEATURE_SIZE,
    guide_channels=GUIDE_CHANNELS,
    pretrained_swin_path=PRETRAINED_SWIN_PATH,
    use_anatomy_prior=False,
    use_dcn_alignment=False
).to(DEVICE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-05-26 08:31:50,433 - Train - INFO - 初始化 APM-Former 模型...
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-05-26 08:31:51,758 - Train - INFO - 模型总参数量: 16.32 M

# %%
# 5. 损失函数 + 两阶段优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR

# ==========================================
# 损失函数 (保持你原来的完美配置不变)
# ==========================================
# weights = torch.tensor([1.0, 1.755]).to(DEVICE) 
weights = torch.tensor([1.0, 2.5]).to(DEVICE)
criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)

# ==========================================
# 两阶段训练：阶段一 (冻结主干)
# ==========================================

# 1. 冻结 Swin 主干网络
logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
for name, param in model.named_parameters():
    if "swin_backbone" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

# 2. 定义优化器：极其重要！这里加了 filter，只把没冻结的参数交给优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# 3. 阶段一的调度器：不需要预热，直接用 5 个 epoch 的余弦退火
scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
# Out:
# 2026-05-26 08:31:51,797 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 对比实验：增加TV Loss
def total_variation_loss_3d(displacement_field):
    """
    计算 3D 形变场的 TV Loss，促使相邻像素的偏移方向和幅度保持平滑
    displacement_field shape: (Batch_size, 3, Depth, Height, Width)
    """
    # 计算三个空间维度的梯度（相邻体素的差值绝对值）
    d_diff = torch.abs(displacement_field[:, :, 1:, :, :] - displacement_field[:, :, :-1, :, :])
    h_diff = torch.abs(displacement_field[:, :, :, 1:, :] - displacement_field[:, :, :, :-1, :])
    w_diff = torch.abs(displacement_field[:, :, :, :, 1:] - displacement_field[:, :, :, :, :-1])
    
    # 将三个方向的平滑度误差求平均并相加
    tv_loss = torch.mean(d_diff) + torch.mean(h_diff) + torch.mean(w_diff)
    return tv_loss

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0
    tv_weight = 0

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _, displacement_field = model(images)
        cls_loss = criterion(logits, labels.unsqueeze(1))
        # 增加tv_loss
        tv_loss = total_variation_loss_3d(displacement_field)

        loss = cls_loss + tv_loss *tv_weight

        loss = loss / accum_steps

        loss.backward()
        # 👇 就在 optimizer.step() 之前，加入这行“梯度裁剪”代码！
        # max_norm=1.0 或 2.0 是最常用的安全值
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc

from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    # correct = 0
    # total = 0
    all_preds = []
    all_labels = []
    all_probs = []  # 🌟 新增：专门用于收集预测为 pMCI 的概率，计算 AUC 必须用

    for images, labels in loader: 
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1)) # 如果用的是交叉熵，这里不用 unsqueeze

        total_loss += loss.item()
        
        # 获取预测类别 (0 或 1)
        preds = torch.argmax(logits, dim=1)
        
        # 🌟 获取预测为类别 1 (pMCI) 的概率
        probs = F.softmax(logits, dim=1)[:, 1] 
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    # ==========================
    # 🌟 计算所有医学黄金指标
    # ==========================
    acc = accuracy_score(all_labels, all_preds) * 100
    precision = precision_score(all_labels, all_preds, pos_label=1, zero_division=0) * 100
    sen = recall_score(all_labels, all_preds, pos_label=1) * 100  # Sensitivity / Recall
    spe = recall_score(all_labels, all_preds, pos_label=0) * 100  # Specificity (反向召回)
    f1 = f1_score(all_labels, all_preds, pos_label=1,zero_division=0) * 100
    
    # 计算 AUC (注意：有些 batch 如果只有一个类别会报错，这里做了容错)
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    
    # 打印超级豪华版日志
    logger.info(f"👉 混淆矩阵: [类0正确: {cm[0][0]}, 误判为类1: {cm[0][1]}] | [类1漏判: {cm[1][0]}, 类1正确: {cm[1][1]}]")
    logger.info(f"🏆 评估指标: ACC: {acc:.2f}% | Precision: {precision:.2f}% | SEN/Recall: {sen:.2f}% | SPE: {spe:.2f}% | F1: {f1:.2f}% | AUC: {auc:.2f}%")
    return avg_loss, acc, auc

# %%
# 7. 主训练循环
best_val_acc = 0.0
logger.info("=" * 50)
logger.info("开始训练！")
logger.info("=" * 50)

for epoch in range(NUM_EPOCHS):
    # 👇 ================= 新增：解冻机关 ================= 👇
    if epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 重新定义优化器（包含主干网络），并大幅降低学习率来保护老专家！
        # 这里用 1e-4 或 5e-5 进行微调最合适
        optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    val_loss, val_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    scheduler.step()

    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {val_acc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), SAVE_PATH)
        logger.info(f"✅ 最佳模型已保存！最佳验证准确率: {best_val_acc:.2f}%")

logger.info("\n🎉 训练完成！")
logger.info(f"最终最佳验证准确率: {best_val_acc:.2f}%")
# Out:
# 2026-05-26 08:31:51,910 - Train - INFO - ==================================================
# 2026-05-26 08:31:51,912 - Train - INFO - 开始训练！
# 2026-05-26 08:31:51,913 - Train - INFO - ==================================================
# 2026-05-26 08:31:51,914 - Train - INFO -
# Epoch [1/50]
# 训练中:   0%|          | 0/328 [00:00<?, ?it/s]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-26 08:33:22,944 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:33:22,946 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 55.06%
# 2026-05-26 08:33:22,948 - Train - INFO - 训练损失: 0.3060 | 训练准确率: 61.28%
# 2026-05-26 08:33:22,948 - Train - INFO - 验证损失: 0.2909 | 验证准确率: 63.41%
# 2026-05-26 08:33:22,949 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-26 08:33:24,013 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 63.41%
# 2026-05-26 08:33:24,014 - Train - INFO -
# Epoch [2/50]
# 训练中: 100%|██████████| 328/328 [01:26<00:00,  3.80it/s]
# 2026-05-26 08:35:01,338 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:35:01,340 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 53.59%
# 2026-05-26 08:35:01,342 - Train - INFO - 训练损失: 0.3019 | 训练准确率: 63.87%
# 2026-05-26 08:35:01,343 - Train - INFO - 验证损失: 0.2972 | 验证准确率: 63.41%
# 2026-05-26 08:35:01,344 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-26 08:35:01,345 - Train - INFO -
# Epoch [3/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.96it/s]
# 2026-05-26 08:36:35,068 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:36:35,070 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 54.87%
# 2026-05-26 08:36:35,072 - Train - INFO - 训练损失: 0.2991 | 训练准确率: 63.72%
# 2026-05-26 08:36:35,073 - Train - INFO - 验证损失: 0.2913 | 验证准确率: 63.41%
# 2026-05-26 08:36:35,074 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-26 08:36:35,075 - Train - INFO -
# Epoch [4/50]
# 训练中: 100%|██████████| 328/328 [01:23<00:00,  3.93it/s]
# 2026-05-26 08:38:08,800 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:38:08,802 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 54.74%
# 2026-05-26 08:38:08,804 - Train - INFO - 训练损失: 0.2990 | 训练准确率: 63.72%
# 2026-05-26 08:38:08,805 - Train - INFO - 验证损失: 0.2934 | 验证准确率: 63.41%
# 2026-05-26 08:38:08,806 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-26 08:38:08,807 - Train - INFO -
# Epoch [5/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.28it/s]
# 2026-05-26 08:39:36,068 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:39:36,070 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 54.62%
# 2026-05-26 08:39:36,071 - Train - INFO - 训练损失: 0.2968 | 训练准确率: 63.57%
# 2026-05-26 08:39:36,072 - Train - INFO - 验证损失: 0.2919 | 验证准确率: 63.41%
# 2026-05-26 08:39:36,073 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-26 08:39:36,074 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-26 08:39:36,075 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！
# 2026-05-26 08:39:36,076 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-26 08:39:36,079 - Train - INFO -
# Epoch [6/50]
# 训练中: 100%|██████████| 328/328 [01:26<00:00,  3.81it/s]
# 2026-05-26 08:41:13,011 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:41:13,013 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 53.21%
# 2026-05-26 08:41:13,015 - Train - INFO - 训练损失: 0.3199 | 训练准确率: 62.04%
# 2026-05-26 08:41:13,016 - Train - INFO - 验证损失: 0.2958 | 验证准确率: 63.41%
# 2026-05-26 08:41:13,017 - Train - INFO - 当前学习率: 0.00029963
# 2026-05-26 08:41:13,017 - Train - INFO -
# Epoch [7/50]
# 训练中: 100%|██████████| 328/328 [01:27<00:00,  3.75it/s]
# 2026-05-26 08:42:50,186 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:42:50,188 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 53.65%
# 2026-05-26 08:42:50,189 - Train - INFO - 训练损失: 0.3014 | 训练准确率: 61.74%
# 2026-05-26 08:42:50,190 - Train - INFO - 验证损失: 0.2964 | 验证准确率: 63.41%
# 2026-05-26 08:42:50,191 - Train - INFO - 当前学习率: 0.00029854
# 2026-05-26 08:42:50,192 - Train - INFO -
# Epoch [8/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.23it/s]
# 2026-05-26 08:44:17,759 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:44:17,762 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 57.56%
# 2026-05-26 08:44:17,764 - Train - INFO - 训练损失: 0.3059 | 训练准确率: 62.20%
# 2026-05-26 08:44:17,765 - Train - INFO - 验证损失: 0.2892 | 验证准确率: 63.41%
# 2026-05-26 08:44:17,766 - Train - INFO - 当前学习率: 0.00029672
# 2026-05-26 08:44:17,766 - Train - INFO -
# Epoch [9/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.28it/s]
# 2026-05-26 08:45:45,047 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:45:45,049 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 52.44%
# 2026-05-26 08:45:45,051 - Train - INFO - 训练损失: 0.2967 | 训练准确率: 63.57%
# 2026-05-26 08:45:45,052 - Train - INFO - 验证损失: 0.2894 | 验证准确率: 63.41%
# 2026-05-26 08:45:45,053 - Train - INFO - 当前学习率: 0.00029419
# 2026-05-26 08:45:45,053 - Train - INFO -
# Epoch [10/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  4.00it/s]
# 2026-05-26 08:47:19,215 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:47:19,217 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 55.06%
# 2026-05-26 08:47:19,219 - Train - INFO - 训练损失: 0.2912 | 训练准确率: 64.02%
# 2026-05-26 08:47:19,220 - Train - INFO - 验证损失: 0.2939 | 验证准确率: 63.41%
# 2026-05-26 08:47:19,220 - Train - INFO - 当前学习率: 0.00029095
# 2026-05-26 08:47:19,222 - Train - INFO -
# Epoch [11/50]
# 训练中: 100%|██████████| 328/328 [01:25<00:00,  3.83it/s]
# 2026-05-26 08:48:56,039 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:48:56,041 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 58.08%
# 2026-05-26 08:48:56,043 - Train - INFO - 训练损失: 0.2915 | 训练准确率: 62.80%
# 2026-05-26 08:48:56,043 - Train - INFO - 验证损失: 0.2882 | 验证准确率: 63.41%
# 2026-05-26 08:48:56,044 - Train - INFO - 当前学习率: 0.00028703
# 2026-05-26 08:48:56,045 - Train - INFO -
# Epoch [12/50]
# 训练中: 100%|██████████| 328/328 [01:28<00:00,  3.71it/s]
# 2026-05-26 08:50:36,386 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:50:36,388 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 60.26%
# 2026-05-26 08:50:36,390 - Train - INFO - 训练损失: 0.2897 | 训练准确率: 63.72%
# 2026-05-26 08:50:36,391 - Train - INFO - 验证损失: 0.2870 | 验证准确率: 63.41%
# 2026-05-26 08:50:36,392 - Train - INFO - 当前学习率: 0.00028244
# 2026-05-26 08:50:36,393 - Train - INFO -
# Epoch [13/50]
# 训练中: 100%|██████████| 328/328 [01:30<00:00,  3.63it/s]
# 2026-05-26 08:52:17,487 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:52:17,490 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 63.97%
# 2026-05-26 08:52:17,492 - Train - INFO - 训练损失: 0.2890 | 训练准确率: 63.72%
# 2026-05-26 08:52:17,492 - Train - INFO - 验证损失: 0.2865 | 验证准确率: 63.41%
# 2026-05-26 08:52:17,493 - Train - INFO - 当前学习率: 0.00027721
# 2026-05-26 08:52:17,494 - Train - INFO -
# Epoch [14/50]
# 训练中: 100%|██████████| 328/328 [01:28<00:00,  3.71it/s]
# 2026-05-26 08:53:57,522 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:53:57,523 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.95%
# 2026-05-26 08:53:57,525 - Train - INFO - 训练损失: 0.2888 | 训练准确率: 63.57%
# 2026-05-26 08:53:57,526 - Train - INFO - 验证损失: 0.2856 | 验证准确率: 63.41%
# 2026-05-26 08:53:57,527 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-26 08:53:57,528 - Train - INFO -
# Epoch [15/50]
# 训练中: 100%|██████████| 328/328 [01:30<00:00,  3.63it/s]
# 2026-05-26 08:55:38,300 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 29, 类1正确: 1]
# 2026-05-26 08:55:38,303 - Train - INFO - 🏆 评估指标: ACC: 64.63% | Precision: 100.00% | SEN/Recall: 3.33% | SPE: 100.00% | F1: 6.45% | AUC: 66.47%
# 2026-05-26 08:55:38,304 - Train - INFO - 训练损失: 0.2861 | 训练准确率: 63.72%
# 2026-05-26 08:55:38,305 - Train - INFO - 验证损失: 0.2876 | 验证准确率: 64.63%
# 2026-05-26 08:55:38,306 - Train - INFO - 当前学习率: 0.00026491
# 2026-05-26 08:55:39,583 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 64.63%
# 2026-05-26 08:55:39,584 - Train - INFO -
# Epoch [16/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.98it/s]
# 2026-05-26 08:57:12,670 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:57:12,672 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 66.15%
# 2026-05-26 08:57:12,674 - Train - INFO - 训练损失: 0.2850 | 训练准确率: 63.87%
# 2026-05-26 08:57:12,675 - Train - INFO - 验证损失: 0.2816 | 验证准确率: 63.41%
# 2026-05-26 08:57:12,675 - Train - INFO - 当前学习率: 0.00025790
# 2026-05-26 08:57:12,676 - Train - INFO -
# Epoch [17/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.24it/s]
# 2026-05-26 08:58:39,484 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 08:58:39,487 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 65.71%
# 2026-05-26 08:58:39,488 - Train - INFO - 训练损失: 0.2851 | 训练准确率: 63.57%
# 2026-05-26 08:58:39,489 - Train - INFO - 验证损失: 0.2812 | 验证准确率: 63.41%
# 2026-05-26 08:58:39,490 - Train - INFO - 当前学习率: 0.00025037
# 2026-05-26 08:58:39,491 - Train - INFO -
# Epoch [18/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.05it/s]
# 2026-05-26 09:00:11,343 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 09:00:11,345 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 67.82%
# 2026-05-26 09:00:11,346 - Train - INFO - 训练损失: 0.2821 | 训练准确率: 63.11%
# 2026-05-26 09:00:11,347 - Train - INFO - 验证损失: 0.2818 | 验证准确率: 63.41%
# 2026-05-26 09:00:11,348 - Train - INFO - 当前学习率: 0.00024235
# 2026-05-26 09:00:11,349 - Train - INFO -
# Epoch [19/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.11it/s]
# 2026-05-26 09:01:42,617 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 09:01:42,619 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 68.27%
# 2026-05-26 09:01:42,621 - Train - INFO - 训练损失: 0.2846 | 训练准确率: 64.18%
# 2026-05-26 09:01:42,621 - Train - INFO - 验证损失: 0.2873 | 验证准确率: 63.41%
# 2026-05-26 09:01:42,622 - Train - INFO - 当前学习率: 0.00023388
# 2026-05-26 09:01:42,623 - Train - INFO -
# Epoch [20/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.99it/s]
# 2026-05-26 09:03:15,583 - Train - INFO - 👉 混淆矩阵: [类0正确: 49, 误判为类1: 3] | [类1漏判: 23, 类1正确: 7]
# 2026-05-26 09:03:15,585 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 70.00% | SEN/Recall: 23.33% | SPE: 94.23% | F1: 35.00% | AUC: 70.06%
# 2026-05-26 09:03:15,586 - Train - INFO - 训练损失: 0.2859 | 训练准确率: 63.26%
# 2026-05-26 09:03:15,587 - Train - INFO - 验证损失: 0.2673 | 验证准确率: 68.29%
# 2026-05-26 09:03:15,588 - Train - INFO - 当前学习率: 0.00022500
# 2026-05-26 09:03:16,760 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 68.29%
# 2026-05-26 09:03:16,762 - Train - INFO -
# Epoch [21/50]
# 训练中: 100%|██████████| 328/328 [01:22<00:00,  3.99it/s]
# 2026-05-26 09:04:49,425 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 29, 类1正确: 1]
# 2026-05-26 09:04:49,427 - Train - INFO - 🏆 评估指标: ACC: 64.63% | Precision: 100.00% | SEN/Recall: 3.33% | SPE: 100.00% | F1: 6.45% | AUC: 70.64%
# 2026-05-26 09:04:49,428 - Train - INFO - 训练损失: 0.2887 | 训练准确率: 64.33%
# 2026-05-26 09:04:49,429 - Train - INFO - 验证损失: 0.2869 | 验证准确率: 64.63%
# 2026-05-26 09:04:49,430 - Train - INFO - 当前学习率: 0.00021576
# 2026-05-26 09:04:49,431 - Train - INFO -
# Epoch [22/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.06it/s]
# 2026-05-26 09:06:20,584 - Train - INFO - 👉 混淆矩阵: [类0正确: 13, 误判为类1: 39] | [类1漏判: 3, 类1正确: 27]
# 2026-05-26 09:06:20,589 - Train - INFO - 🏆 评估指标: ACC: 48.78% | Precision: 40.91% | SEN/Recall: 90.00% | SPE: 25.00% | F1: 56.25% | AUC: 69.94%
# 2026-05-26 09:06:20,593 - Train - INFO - 训练损失: 0.2978 | 训练准确率: 65.55%
# 2026-05-26 09:06:20,593 - Train - INFO - 验证损失: 0.3186 | 验证准确率: 48.78%
# 2026-05-26 09:06:20,594 - Train - INFO - 当前学习率: 0.00020619
# 2026-05-26 09:06:20,595 - Train - INFO -
# Epoch [23/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.21it/s]
# 2026-05-26 09:07:49,223 - Train - INFO - 👉 混淆矩阵: [类0正确: 47, 误判为类1: 5] | [类1漏判: 20, 类1正确: 10]
# 2026-05-26 09:07:49,225 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 66.67% | SEN/Recall: 33.33% | SPE: 90.38% | F1: 44.44% | AUC: 71.47%
# 2026-05-26 09:07:49,227 - Train - INFO - 训练损失: 0.3009 | 训练准确率: 68.45%
# 2026-05-26 09:07:49,227 - Train - INFO - 验证损失: 0.2680 | 验证准确率: 69.51%
# 2026-05-26 09:07:49,228 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-26 09:07:50,270 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 69.51%
# 2026-05-26 09:07:50,271 - Train - INFO -
# Epoch [24/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-26 09:09:20,811 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 09:09:20,813 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 57.14% | SEN/Recall: 53.33% | SPE: 76.92% | F1: 55.17% | AUC: 72.44%
# 2026-05-26 09:09:20,815 - Train - INFO - 训练损失: 0.3157 | 训练准确率: 68.14%
# 2026-05-26 09:09:20,815 - Train - INFO - 验证损失: 0.2615 | 验证准确率: 68.29%
# 2026-05-26 09:09:20,817 - Train - INFO - 当前学习率: 0.00018629
# 2026-05-26 09:09:20,817 - Train - INFO -
# Epoch [25/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.28it/s]
# 2026-05-26 09:10:47,618 - Train - INFO - 👉 混淆矩阵: [类0正确: 21, 误判为类1: 31] | [类1漏判: 5, 类1正确: 25]
# 2026-05-26 09:10:47,620 - Train - INFO - 🏆 评估指标: ACC: 56.10% | Precision: 44.64% | SEN/Recall: 83.33% | SPE: 40.38% | F1: 58.14% | AUC: 70.51%
# 2026-05-26 09:10:47,622 - Train - INFO - 训练损失: 0.2849 | 训练准确率: 67.38%
# 2026-05-26 09:10:47,623 - Train - INFO - 验证损失: 0.3297 | 验证准确率: 56.10%
# 2026-05-26 09:10:47,625 - Train - INFO - 当前学习率: 0.00017605
# 2026-05-26 09:10:47,625 - Train - INFO -
# Epoch [26/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-05-26 09:12:12,512 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 09:12:12,514 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 56.67% | SEN/Recall: 56.67% | SPE: 75.00% | F1: 56.67% | AUC: 72.31%
# 2026-05-26 09:12:12,516 - Train - INFO - 训练损失: 0.3036 | 训练准确率: 66.92%
# 2026-05-26 09:12:12,516 - Train - INFO - 验证损失: 0.2599 | 验证准确率: 68.29%
# 2026-05-26 09:12:12,517 - Train - INFO - 当前学习率: 0.00016568
# 2026-05-26 09:12:12,518 - Train - INFO -
# Epoch [27/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.28it/s]
# 2026-05-26 09:13:38,721 - Train - INFO - 👉 混淆矩阵: [类0正确: 48, 误判为类1: 4] | [类1漏判: 19, 类1正确: 11]
# 2026-05-26 09:13:38,723 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 73.33% | SEN/Recall: 36.67% | SPE: 92.31% | F1: 48.89% | AUC: 72.69%
# 2026-05-26 09:13:38,725 - Train - INFO - 训练损失: 0.3121 | 训练准确率: 64.63%
# 2026-05-26 09:13:38,726 - Train - INFO - 验证损失: 0.2816 | 验证准确率: 71.95%
# 2026-05-26 09:13:38,726 - Train - INFO - 当前学习率: 0.00015523
# 2026-05-26 09:13:39,886 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 71.95%
# 2026-05-26 09:13:39,888 - Train - INFO -
# Epoch [28/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-05-26 09:15:05,256 - Train - INFO - 👉 混淆矩阵: [类0正确: 51, 误判为类1: 1] | [类1漏判: 28, 类1正确: 2]
# 2026-05-26 09:15:05,258 - Train - INFO - 🏆 评估指标: ACC: 64.63% | Precision: 66.67% | SEN/Recall: 6.67% | SPE: 98.08% | F1: 12.12% | AUC: 72.05%
# 2026-05-26 09:15:05,260 - Train - INFO - 训练损失: 0.3118 | 训练准确率: 67.84%
# 2026-05-26 09:15:05,261 - Train - INFO - 验证损失: 0.3872 | 验证准确率: 64.63%
# 2026-05-26 09:15:05,262 - Train - INFO - 当前学习率: 0.00014477
# 2026-05-26 09:15:05,262 - Train - INFO -
# Epoch [29/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-05-26 09:16:28,962 - Train - INFO - 👉 混淆矩阵: [类0正确: 36, 误判为类1: 16] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:16:28,964 - Train - INFO - 🏆 评估指标: ACC: 67.07% | Precision: 54.29% | SEN/Recall: 63.33% | SPE: 69.23% | F1: 58.46% | AUC: 72.69%
# 2026-05-26 09:16:28,966 - Train - INFO - 训练损失: 0.3038 | 训练准确率: 67.84%
# 2026-05-26 09:16:28,967 - Train - INFO - 验证损失: 0.2873 | 验证准确率: 67.07%
# 2026-05-26 09:16:28,967 - Train - INFO - 当前学习率: 0.00013432
# 2026-05-26 09:16:28,968 - Train - INFO -
# Epoch [30/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.21it/s]
# 2026-05-26 09:17:57,341 - Train - INFO - 👉 混淆矩阵: [类0正确: 41, 误判为类1: 11] | [类1漏判: 16, 类1正确: 14]
# 2026-05-26 09:17:57,343 - Train - INFO - 🏆 评估指标: ACC: 67.07% | Precision: 56.00% | SEN/Recall: 46.67% | SPE: 78.85% | F1: 50.91% | AUC: 72.37%
# 2026-05-26 09:17:57,344 - Train - INFO - 训练损失: 0.3241 | 训练准确率: 67.99%
# 2026-05-26 09:17:57,345 - Train - INFO - 验证损失: 0.2793 | 验证准确率: 67.07%
# 2026-05-26 09:17:57,346 - Train - INFO - 当前学习率: 0.00012395
# 2026-05-26 09:17:57,347 - Train - INFO -
# Epoch [31/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.08it/s]
# 2026-05-26 09:19:28,013 - Train - INFO - 👉 混淆矩阵: [类0正确: 48, 误判为类1: 4] | [类1漏判: 18, 类1正确: 12]
# 2026-05-26 09:19:28,015 - Train - INFO - 🏆 评估指标: ACC: 73.17% | Precision: 75.00% | SEN/Recall: 40.00% | SPE: 92.31% | F1: 52.17% | AUC: 72.63%
# 2026-05-26 09:19:28,017 - Train - INFO - 训练损失: 0.3333 | 训练准确率: 69.05%
# 2026-05-26 09:19:28,018 - Train - INFO - 验证损失: 0.2978 | 验证准确率: 73.17%
# 2026-05-26 09:19:28,019 - Train - INFO - 当前学习率: 0.00011371
# 2026-05-26 09:19:29,190 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 73.17%
# 2026-05-26 09:19:29,191 - Train - INFO -
# Epoch [32/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-05-26 09:20:54,360 - Train - INFO - 👉 混淆矩阵: [类0正确: 34, 误判为类1: 18] | [类1漏判: 9, 类1正确: 21]
# 2026-05-26 09:20:54,362 - Train - INFO - 🏆 评估指标: ACC: 67.07% | Precision: 53.85% | SEN/Recall: 70.00% | SPE: 65.38% | F1: 60.87% | AUC: 72.82%
# 2026-05-26 09:20:54,363 - Train - INFO - 训练损失: 0.3185 | 训练准确率: 69.82%
# 2026-05-26 09:20:54,364 - Train - INFO - 验证损失: 0.3012 | 验证准确率: 67.07%
# 2026-05-26 09:20:54,365 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-26 09:20:54,366 - Train - INFO -
# Epoch [33/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-05-26 09:22:18,867 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:22:18,869 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 72.88%
# 2026-05-26 09:22:18,871 - Train - INFO - 训练损失: 0.3136 | 训练准确率: 68.75%
# 2026-05-26 09:22:18,872 - Train - INFO - 验证损失: 0.2847 | 验证准确率: 70.73%
# 2026-05-26 09:22:18,873 - Train - INFO - 当前学习率: 0.00009381
# 2026-05-26 09:22:18,874 - Train - INFO -
# Epoch [34/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.37it/s]
# 2026-05-26 09:23:43,480 - Train - INFO - 👉 混淆矩阵: [类0正确: 36, 误判为类1: 16] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:23:43,482 - Train - INFO - 🏆 评估指标: ACC: 67.07% | Precision: 54.29% | SEN/Recall: 63.33% | SPE: 69.23% | F1: 58.46% | AUC: 73.14%
# 2026-05-26 09:23:43,483 - Train - INFO - 训练损失: 0.3255 | 训练准确率: 69.21%
# 2026-05-26 09:23:43,484 - Train - INFO - 验证损失: 0.3078 | 验证准确率: 67.07%
# 2026-05-26 09:23:43,485 - Train - INFO - 当前学习率: 0.00008424
# 2026-05-26 09:23:43,485 - Train - INFO -
# Epoch [35/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.34it/s]
# 2026-05-26 09:25:09,658 - Train - INFO - 👉 混淆矩阵: [类0正确: 28, 误判为类1: 24] | [类1漏判: 8, 类1正确: 22]
# 2026-05-26 09:25:09,661 - Train - INFO - 🏆 评估指标: ACC: 60.98% | Precision: 47.83% | SEN/Recall: 73.33% | SPE: 53.85% | F1: 57.89% | AUC: 73.21%
# 2026-05-26 09:25:09,662 - Train - INFO - 训练损失: 0.3124 | 训练准确率: 70.88%
# 2026-05-26 09:25:09,663 - Train - INFO - 验证损失: 0.3382 | 验证准确率: 60.98%
# 2026-05-26 09:25:09,663 - Train - INFO - 当前学习率: 0.00007500
# 2026-05-26 09:25:09,664 - Train - INFO -
# Epoch [36/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.21it/s]
# 2026-05-26 09:26:37,852 - Train - INFO - 👉 混淆矩阵: [类0正确: 44, 误判为类1: 8] | [类1漏判: 16, 类1正确: 14]
# 2026-05-26 09:26:37,854 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 63.64% | SEN/Recall: 46.67% | SPE: 84.62% | F1: 53.85% | AUC: 73.14%
# 2026-05-26 09:26:37,855 - Train - INFO - 训练损失: 0.3159 | 训练准确率: 69.05%
# 2026-05-26 09:26:37,856 - Train - INFO - 验证损失: 0.3067 | 验证准确率: 70.73%
# 2026-05-26 09:26:37,856 - Train - INFO - 当前学习率: 0.00006612
# 2026-05-26 09:26:37,857 - Train - INFO -
# Epoch [37/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.25it/s]
# 2026-05-26 09:28:04,480 - Train - INFO - 👉 混淆矩阵: [类0正确: 43, 误判为类1: 9] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 09:28:04,482 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 64.00% | SEN/Recall: 53.33% | SPE: 82.69% | F1: 58.18% | AUC: 73.08%
# 2026-05-26 09:28:04,483 - Train - INFO - 训练损失: 0.3042 | 训练准确率: 68.29%
# 2026-05-26 09:28:04,484 - Train - INFO - 验证损失: 0.3022 | 验证准确率: 71.95%
# 2026-05-26 09:28:04,485 - Train - INFO - 当前学习率: 0.00005765
# 2026-05-26 09:28:04,486 - Train - INFO -
# Epoch [38/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.23it/s]
# 2026-05-26 09:29:31,746 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:29:31,748 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 72.69%
# 2026-05-26 09:29:31,750 - Train - INFO - 训练损失: 0.3314 | 训练准确率: 68.90%
# 2026-05-26 09:29:31,750 - Train - INFO - 验证损失: 0.2961 | 验证准确率: 70.73%
# 2026-05-26 09:29:31,751 - Train - INFO - 当前学习率: 0.00004963
# 2026-05-26 09:29:31,752 - Train - INFO -
# Epoch [39/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.30it/s]
# 2026-05-26 09:30:57,606 - Train - INFO - 👉 混淆矩阵: [类0正确: 37, 误判为类1: 15] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:30:57,608 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 55.88% | SEN/Recall: 63.33% | SPE: 71.15% | F1: 59.38% | AUC: 73.27%
# 2026-05-26 09:30:57,610 - Train - INFO - 训练损失: 0.3237 | 训练准确率: 71.04%
# 2026-05-26 09:30:57,611 - Train - INFO - 验证损失: 0.3040 | 验证准确率: 68.29%
# 2026-05-26 09:30:57,612 - Train - INFO - 当前学习率: 0.00004210
# 2026-05-26 09:30:57,613 - Train - INFO -
# Epoch [40/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.43it/s]
# 2026-05-26 09:32:21,179 - Train - INFO - 👉 混淆矩阵: [类0正确: 42, 误判为类1: 10] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 09:32:21,181 - Train - INFO - 🏆 评估指标: ACC: 73.17% | Precision: 64.29% | SEN/Recall: 60.00% | SPE: 80.77% | F1: 62.07% | AUC: 73.14%
# 2026-05-26 09:32:21,183 - Train - INFO - 训练损失: 0.3177 | 训练准确率: 70.12%
# 2026-05-26 09:32:21,183 - Train - INFO - 验证损失: 0.3040 | 验证准确率: 73.17%
# 2026-05-26 09:32:21,184 - Train - INFO - 当前学习率: 0.00003509
# 2026-05-26 09:32:21,185 - Train - INFO -
# Epoch [41/50]
# 训练中: 100%|██████████| 328/328 [01:23<00:00,  3.94it/s]
# 2026-05-26 09:33:54,573 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:33:54,575 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 57.58% | SEN/Recall: 63.33% | SPE: 73.08% | F1: 60.32% | AUC: 73.01%
# 2026-05-26 09:33:54,576 - Train - INFO - 训练损失: 0.3209 | 训练准确率: 69.21%
# 2026-05-26 09:33:54,577 - Train - INFO - 验证损失: 0.3093 | 验证准确率: 69.51%
# 2026-05-26 09:33:54,578 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-26 09:33:54,579 - Train - INFO -
# Epoch [42/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.38it/s]
# 2026-05-26 09:35:19,214 - Train - INFO - 👉 混淆矩阵: [类0正确: 43, 误判为类1: 9] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 09:35:19,216 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 64.00% | SEN/Recall: 53.33% | SPE: 82.69% | F1: 58.18% | AUC: 73.21%
# 2026-05-26 09:35:19,218 - Train - INFO - 训练损失: 0.3122 | 训练准确率: 71.49%
# 2026-05-26 09:35:19,219 - Train - INFO - 验证损失: 0.3056 | 验证准确率: 71.95%
# 2026-05-26 09:35:19,219 - Train - INFO - 当前学习率: 0.00002279
# 2026-05-26 09:35:19,220 - Train - INFO -
# Epoch [43/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.34it/s]
# 2026-05-26 09:36:45,191 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:36:45,193 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 73.59%
# 2026-05-26 09:36:45,195 - Train - INFO - 训练损失: 0.3161 | 训练准确率: 72.41%
# 2026-05-26 09:36:45,195 - Train - INFO - 验证损失: 0.3038 | 验证准确率: 70.73%
# 2026-05-26 09:36:45,196 - Train - INFO - 当前学习率: 0.00001756
# 2026-05-26 09:36:45,197 - Train - INFO -
# Epoch [44/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-05-26 09:38:11,011 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:38:11,013 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 57.58% | SEN/Recall: 63.33% | SPE: 73.08% | F1: 60.32% | AUC: 73.59%
# 2026-05-26 09:38:11,014 - Train - INFO - 训练损失: 0.3044 | 训练准确率: 69.51%
# 2026-05-26 09:38:11,015 - Train - INFO - 验证损失: 0.3060 | 验证准确率: 69.51%
# 2026-05-26 09:38:11,016 - Train - INFO - 当前学习率: 0.00001297
# 2026-05-26 09:38:11,017 - Train - INFO -
# Epoch [45/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.36it/s]
# 2026-05-26 09:39:37,359 - Train - INFO - 👉 混淆矩阵: [类0正确: 42, 误判为类1: 10] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 09:39:37,360 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 62.96% | SEN/Recall: 56.67% | SPE: 80.77% | F1: 59.65% | AUC: 73.72%
# 2026-05-26 09:39:37,362 - Train - INFO - 训练损失: 0.2935 | 训练准确率: 70.27%
# 2026-05-26 09:39:37,363 - Train - INFO - 验证损失: 0.3039 | 验证准确率: 71.95%
# 2026-05-26 09:39:37,363 - Train - INFO - 当前学习率: 0.00000905
# 2026-05-26 09:39:37,364 - Train - INFO -
# Epoch [46/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-05-26 09:41:01,614 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:41:01,616 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 73.65%
# 2026-05-26 09:41:01,618 - Train - INFO - 训练损失: 0.3231 | 训练准确率: 71.34%
# 2026-05-26 09:41:01,618 - Train - INFO - 验证损失: 0.3037 | 验证准确率: 70.73%
# 2026-05-26 09:41:01,619 - Train - INFO - 当前学习率: 0.00000581
# 2026-05-26 09:41:01,620 - Train - INFO -
# Epoch [47/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.36it/s]
# 2026-05-26 09:42:28,178 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:42:28,180 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 73.65%
# 2026-05-26 09:42:28,182 - Train - INFO - 训练损失: 0.3024 | 训练准确率: 70.12%
# 2026-05-26 09:42:28,183 - Train - INFO - 验证损失: 0.3072 | 验证准确率: 70.73%
# 2026-05-26 09:42:28,184 - Train - INFO - 当前学习率: 0.00000328
# 2026-05-26 09:42:28,185 - Train - INFO -
# Epoch [48/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-05-26 09:43:53,018 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:43:53,019 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 73.65%
# 2026-05-26 09:43:53,020 - Train - INFO - 训练损失: 0.2868 | 训练准确率: 71.95%
# 2026-05-26 09:43:53,020 - Train - INFO - 验证损失: 0.3065 | 验证准确率: 70.73%
# 2026-05-26 09:43:53,020 - Train - INFO - 当前学习率: 0.00000146
# 2026-05-26 09:43:53,021 - Train - INFO -
# Epoch [49/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.22it/s]
# 2026-05-26 09:45:20,814 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:45:20,816 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 73.65%
# 2026-05-26 09:45:20,818 - Train - INFO - 训练损失: 0.3044 | 训练准确率: 68.90%
# 2026-05-26 09:45:20,818 - Train - INFO - 验证损失: 0.3075 | 验证准确率: 70.73%
# 2026-05-26 09:45:20,819 - Train - INFO - 当前学习率: 0.00000037
# 2026-05-26 09:45:20,820 - Train - INFO -
# Epoch [50/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.08it/s]
# 2026-05-26 09:46:50,495 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 11, 类1正确: 19]
# 2026-05-26 09:46:50,497 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 59.38% | SEN/Recall: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 73.65%
# 2026-05-26 09:46:50,499 - Train - INFO - 训练损失: 0.3002 | 训练准确率: 71.04%
# 2026-05-26 09:46:50,500 - Train - INFO - 验证损失: 0.3075 | 验证准确率: 70.73%
# 2026-05-26 09:46:50,501 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-26 09:46:50,502 - Train - INFO -
# 🎉 训练完成！
# 2026-05-26 09:46:50,502 - Train - INFO - 最终最佳验证准确率: 73.17%

# %%
# import torch
# import torch.nn.functional as F
# import numpy as np
# import matplotlib.pyplot as plt

# # ==========================================
# # 第一步：加载你跑出 74.39% 的最佳模型权重
# # ==========================================
# print("🔄 正在加载最佳模型权重...")

# # 实例化模型 (确保这里的参数和你跑出最好成绩的那次完全一致)
# # 之前确认过 FEATURE_SIZE 是 24
# vis_model = APM_Former_ImageOnly(
#     feature_size=24,  
#     num_classes=2
# ).to(DEVICE)

# # ⚠️ 注意：把这里的 'best_model.pth' 换成你实际保存的权重文件名！
# # 比如可能是 'checkpoint_epoch_xx.pth'
# checkpoint_path = 'checkpoints/best_3407model2.pth'  
# state_dict = torch.load(checkpoint_path, map_location=DEVICE)
# vis_model.load_state_dict(state_dict)

# vis_model.eval() # 切换到评估模式
# print(f"✅ 成功加载权重: {checkpoint_path}")
# print("-" * 50)


# # ==========================================
# # 第二步：定义并运行可视化探针
# # ==========================================
# @torch.no_grad()
# def visualize_pMCI_attention(model, val_loader, device, num_cases_to_show=3):
#     model.eval()
#     found_cases = 0
    
#     # 解决 matplotlib 中文显示问题
#     # plt.rcParams['font.sans-serif'] = ['SimHei'] 
#     # plt.rcParams['axes.unicode_minus'] = False
    
#     print("🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...\n")
    
#     for images, labels in val_loader:
#         images = images.to(device)
#         labels = labels.to(device)
        
#         logits, _, spatial_attention = model(images)
#         preds = torch.argmax(logits, dim=1)
        
#         # 寻找 True Positives (真实为pMCI，预测也为pMCI)
#         for i in range(len(labels)):
#             if labels[i].item() == 1 and preds[i].item() == 1:
#                 found_cases += 1
                
#                 # 1. 提取原始 3D MRI 图像
#                 img_3d = images[i, 0].cpu().numpy()  
                
#                 # 2. 提取注意力掩码，并插值放大到原始图像大小 (96, 96, 96)
#                 attn_tensor = spatial_attention[i:i+1] 
#                 attn_resized = F.interpolate(attn_tensor, size=img_3d.shape, mode='trilinear', align_corners=False)
#                 attn_3d = attn_resized[0, 0].cpu().numpy()
                
#                 # 3. 智能寻找网络最关注的切片位置
#                 slice_x = np.argmax(np.sum(attn_3d, axis=(1, 2))) 
#                 slice_y = np.argmax(np.sum(attn_3d, axis=(0, 2))) 
#                 slice_z = np.argmax(np.sum(attn_3d, axis=(0, 1))) 
                
#                 # 4. 绘图
#                 fig, axes = plt.subplots(1, 3, figsize=(18, 6))
#                 # 成功识别的pMCI阳性病例  高亮区域为网络空间对齐中点关注区域
#                 fig.suptitle(f"True Positive pMCI Case #{found_cases}\n(Spatial Attention Guided Alignment)", fontsize=18, fontweight='bold', y=1.05)
                
#                 # 矢状面 矢状面切片
#                 axes[0].imshow(img_3d[slice_x, :, :], cmap='gray') 
#                 im = axes[0].imshow(attn_3d[slice_x, :, :], cmap='jet', alpha=0.45) 
#                 axes[0].set_title(f"Sagittal View (Slice {slice_x})", fontsize=14)
#                 axes[0].axis('off')
                
#                 # 冠状面 冠状面切片
#                 axes[1].imshow(img_3d[:, slice_y, :], cmap='gray')
#                 axes[1].imshow(attn_3d[:, slice_y, :], cmap='jet', alpha=0.45)
#                 axes[1].set_title(f"Coronal View (Slice {slice_y})", fontsize=14)
#                 axes[1].axis('off')
                
#                 # 轴状面 轴状面切片
#                 axes[2].imshow(img_3d[:, :, slice_z], cmap='gray')
#                 axes[2].imshow(attn_3d[:, :, slice_z], cmap='jet', alpha=0.45)
#                 axes[2].set_title(f"Axial View (Slice {slice_z})", fontsize=14)
#                 axes[2].axis('off')
                
#                 # 颜色条的标签 解剖引导强度
#                 cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
#                 cbar.set_label('Attention Weight', fontsize=12)
                
#                 plt.show()
                
#                 if found_cases >= num_cases_to_show:
#                     print(f"\n✅ 成功提取 {num_cases_to_show} 组 pMCI 空间注意力图！")
#                     return

#     print(f"\n搜索结束，共找到 {found_cases} 个符合条件的病例。")

# # 执行探针！展示前 5 个最典型的病例
# visualize_pMCI_attention(vis_model, val_loader, DEVICE, num_cases_to_show=5)
