# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

from models.build_model import build_selected_model

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score,roc_curve


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 71.95% 74.39%
# seed 3407 71.95% 75.61%
# seed 1234 73.17% 69.51%
# seed 98 71.95% 73.17%
# seed 20  69.51%
# seed 1024

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 80
GRADIENT_ACCUMULATION_STEPS = 4
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SEED = 1024
MODEL_TYPE = "APM_Former"
SAVE_PATH = f"checkpoints/best_model3_{MODEL_TYPE}.pth"


set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 模型类型 (MODEL_TYPE): {MODEL_TYPE}")
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
# logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-07-02 05:49:35,636 - Train - INFO - ==================================================
# 2026-07-02 05:49:35,637 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-07-02 05:49:35,638 - Train - INFO - ==================================================
# 2026-07-02 05:49:35,639 - Train - INFO - ▶ 模型类型 (MODEL_TYPE): APM_Former
# 2026-07-02 05:49:35,640 - Train - INFO - ▶ 随机种子 (SEED): 1024
# 2026-07-02 05:49:35,641 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-07-02 05:49:35,642 - Train - INFO - ▶ 批次大小 (Batch Size): 2
# 2026-07-02 05:49:35,644 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-07-02 05:49:35,645 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-07-02 05:49:35,646 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-07-02 05:49:35,648 - Train - INFO - ==================================================
# 2026-07-02 05:49:35,649 - Train - INFO - 训练设备: cuda
# 2026-07-02 05:49:35,650 - Train - INFO - 批次大小: 2
# 2026-07-02 05:49:35,651 - Train - INFO - 总轮数: 80

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS,
    use_sampler=True
)
# Out:
# 2026-07-02 05:49:35,694 - Train - INFO - 正在加载数据集...
# 2026-07-02 05:49:35,703 - utils.dataset - INFO - ✅ 成功加载 82 个样本
# 2026-07-02 05:49:35,705 - utils.dataset - INFO - 🧪 启用1:1动态加权采样策略
# 2026-07-02 05:49:35,735 - utils.dataset - INFO - ✅ 成功加载 656 个样本
# 2026-07-02 05:49:35,737 - utils.dataset - INFO - 训练集批次: 328，验证集批次: 41

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model, UNFREEZE_EPOCH = build_selected_model(MODEL_TYPE, DEVICE, TRAIN_IMG_SIZE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-07-02 05:49:35,776 - Train - INFO - 初始化 APM-Former 模型...
# 2026-07-02 05:49:35,778 - Train - INFO - ============================================================
# 2026-07-02 05:49:35,779 - Train - INFO - 🚀 当前正在初始化的模型架构: APM_Former
# 2026-07-02 05:49:35,780 - Train - INFO - ============================================================
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-07-02 05:49:36,794 - Train - INFO - 📦 模型 [APM_Former] 总参数量: 15.80 M
# 2026-07-02 05:49:36,796 - Train - INFO - 模型总参数量: 15.80 M

# %%
# 5. 损失函数 + 优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR
import torch.optim as optim

# ==========================================
# 1. 损失函数 (保持不变)
# ==========================================
# weights = torch.tensor([1.0, 1.0]).to(DEVICE)
# criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)
weights = torch.tensor([1.0, 4.0]).to(DEVICE)
criterion = nn.CrossEntropyLoss(weight=weights).to(DEVICE)

# ==========================================
# 2. 冻结与优化器逻辑 (全兼容)
# ==========================================
if MODEL_TYPE == "APM_Former":
    logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
    for name, param in model.named_parameters():
        if "swin_backbone" in name:
            param.requires_grad = False
        else:
            param.requires_grad = True
else:
    # 其他 Baseline 模型默认全员解冻，直接参与训练
    for param in model.parameters():
        param.requires_grad = True

# 统一定义优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# ==========================================
# 3. 🌟 修复 Bug：动态计算调度器的 T_max
# ==========================================
if UNFREEZE_EPOCH > 0:
    # 情形 A (APM_Former)：第一阶段的 T_max 是预热轮数 (比如 10)
    scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
else:
    # 情形 B (ResNet 等 Baseline)：从头训到尾，T_max 直接是总轮数 (80)
    scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)
# Out:
# 2026-07-02 05:49:36,835 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 对比实验：增加TV Loss
def total_variation_loss_3d(displacement_field):
    """
    计算 3D 形变场的 TV Loss，促使相邻像素的偏移方向和幅度保持平滑
    displacement_field shape: (Batch_size, 3, Depth, Height, Width)
    """
    # 计算三个空间维度的梯度（相邻体素的差值绝对值）
    d_diff = torch.abs(displacement_field[:, :, 1:, :, :] - displacement_field[:, :, :-1, :, :])
    h_diff = torch.abs(displacement_field[:, :, :, 1:, :] - displacement_field[:, :, :, :-1, :])
    w_diff = torch.abs(displacement_field[:, :, :, :, 1:] - displacement_field[:, :, :, :, :-1])
    
    # 将三个方向的平滑度误差求平均并相加
    tv_loss = torch.mean(d_diff) + torch.mean(h_diff) + torch.mean(w_diff)
    return tv_loss

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0
    tv_weight = 1e-4  # 初始建议给一个较小的值，比如 0.001

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        # 🌟 核心兼容性修改：先统统接住模型的输出，不着急解包 (unpack)
        outputs = model(images)
        
        # 🌟 智能分流：判断当前跑的是哪个模型
        if isinstance(outputs, tuple):
            # 情形 A: 这是你的 APM_Former (返回了4个值)
            logits = outputs[0]
            displacement_field = outputs[3]
            # cls_loss = criterion(logits, labels.unsqueeze(1))
            cls_loss = criterion(logits, labels.long())
            # 加入特有的 tv_loss
            tv_loss = total_variation_loss_3d(displacement_field)
            loss = cls_loss + tv_loss * tv_weight
        else:
            # 情形 B: 这是经典的 ResNet/ViT 等模型 (直接返回 logits，无形变场)
            logits = outputs
            loss = criterion(logits, labels.unsqueeze(1))

        # 梯度累加缩放
        loss = loss / accum_steps

        loss.backward()
        
        # 👇 梯度裁剪，防止爆炸
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        
        # 注意：这里的 preds 只是为了在进度条看个大概，真实的实力还要看 val_epoch 的动态阈值
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc


from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    all_labels = []
    all_probs = []  

    for images, labels in loader: 
        images, labels = images.to(device), labels.to(device)
        # outputs = model(images)
        
        # # 🌟 兼容性处理：如果是 APM_Former 返回的是 tuple，否则直接是 logits
        # logits = outputs[0] if isinstance(outputs, tuple) else outputs
        
        # # loss = criterion(logits, labels.unsqueeze(1)) 
        # loss = criterion(logits, labels.long())
        # total_loss += loss.item()
        
        # probs = F.softmax(logits, dim=1)[:, 1] 
        # all_labels.extend(labels.cpu().numpy())
        # all_probs.extend(probs.detach().cpu().numpy())
        # 🌟 TTA 第一步：原图预测
        outputs1 = model(images)
        logits1 = outputs1[0] if isinstance(outputs1, tuple) else outputs1
        loss = criterion(logits1, labels.long()) 
        total_loss += loss.item()
        probs1 = F.softmax(logits1, dim=1)[:, 1] 
        
        # 🌟 TTA 第二步：翻转图像再次预测 (假设 W 维度在最后，即 dims=[-1])
        images_flipped = torch.flip(images, dims=[-1]) 
        outputs2 = model(images_flipped)
        logits2 = outputs2[0] if isinstance(outputs2, tuple) else outputs2
        probs2 = F.softmax(logits2, dim=1)[:, 1] 
        
        # 🌟 TTA 第三步：概率求平均！极其稳定！
        probs = (probs1 + probs2) / 2.0
        
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.detach().cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0
        
    # fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
    # # optimal_idx = np.argmax(tpr - fpr)
    # optimal_idx = np.argmax(1.5 * tpr - fpr)  
    # optimal_threshold = thresholds[optimal_idx]
    # ====== 替换为：直接暴力搜索让 F1 最高的阈值 =====
    # 1. 拿到 ROC 曲线的所有基础指标
    fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
    sen = tpr
    spe = 1 - fpr
    
    # 2. 巧妙推导 Precision 和 F1 (无需额外调用 PR 曲线函数，保证数组长度一致)
    P = sum(all_labels) # 真实的病人总数
    N = len(all_labels) - P # 真实的正常人总数
    
    TP = tpr * P
    FP = fpr * N
    
    precision = TP / (TP + FP + 1e-8)
    f1_scores = 2 * (precision * sen) / (precision + sen + 1e-8)
    
    # 3. 🌟 你的复合策略：约束 F1 >= 65%
    valid_idx = np.where(f1_scores >= 0.65)[0]
    
    if len(valid_idx) > 0:
        # 在满足 F1 >= 65% 的阈值里，寻找 SEN 和 SPE 的最佳平衡点 (最大化 SEN + SPE)
        youden_scores = sen[valid_idx] + spe[valid_idx]
        best_valid_idx = valid_idx[np.argmax(youden_scores)]
        optimal_threshold = thresholds[best_valid_idx]
        logger.info(f"💡 [F1>=65% 且平衡SEN/SPE] 最佳动态阈值: {optimal_threshold:.4f}")
    else:
        # 如果模型极其崩盘，连 F1=65% 都达不到，退化为传统平衡模式兜底
        optimal_idx = np.argmax(sen + spe)
        optimal_threshold = thresholds[optimal_idx]
        logger.info(f"⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: {optimal_threshold:.4f}")
    best_preds = [1 if p >= optimal_threshold else 0 for p in all_probs]

    adj_acc = accuracy_score(all_labels, best_preds) * 100
    adj_precision = precision_score(all_labels, best_preds, pos_label=1, zero_division=0) * 100
    adj_sen = recall_score(all_labels, best_preds, pos_label=1) * 100
    adj_spe = recall_score(all_labels, best_preds, pos_label=0) * 100
    adj_f1 = f1_score(all_labels, best_preds, pos_label=1, zero_division=0) * 100
    cm = confusion_matrix(all_labels, best_preds, labels=[0, 1])
    
    logger.info(f"💡 [{MODEL_TYPE}] 动态最佳判定阈值: {optimal_threshold:.4f}")
    logger.info(f"👉 混淆矩阵: [类0: {cm[0][0]}, 误判1: {cm[0][1]}] | [漏判1: {cm[1][0]}, 类1: {cm[1][1]}]")
    logger.info(f"🏆 真实指标: ACC: {adj_acc:.2f}% | Precision: {adj_precision:.2f}% | SEN: {adj_sen:.2f}% | SPE: {adj_spe:.2f}% | F1: {adj_f1:.2f}% | AUC: {auc:.2f}%")
    return avg_loss, adj_acc, auc

# %%
# ==========================================
# 🌟 7. 终极主训练循环 (支持多模型 & 动态阈值 & 早停)
# ==========================================
best_val_acc = 0.0
patience =  30  # 早停容忍轮数
no_improve_epochs = 0

logger.info("=" * 60)
logger.info(f"开始训练模型: {MODEL_TYPE} | 优化目标: 最大化真实潜能 (adj_acc)")
logger.info("=" * 60)

for epoch in range(NUM_EPOCHS):
    
    # 👇 ================= 新增：智能解冻机关 ================= 👇
    # 只有 APM_Former 才需要预热和解冻，其他 Baseline 直接跳过
    if MODEL_TYPE == "APM_Former" and epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始【分层学习率】全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 🌟 核心修改：将参数分为“预训练骨干”和“新增组件”两组
        backbone_params = []
        head_params = []
        
        for name, param in model.named_parameters():
            if not param.requires_grad:
                continue
            if "swin_backbone" in name:
                backbone_params.append(param)
            else:
                head_params.append(param)
                
        # 🌟 核心修改：配置分层优化器 (Layer-wise LR)
        optimizer = optim.AdamW([
            {'params': backbone_params, 'lr': 1e-5},  # 骨干网络：学习率缩小30倍，保护预训练特征
            {'params': head_params, 'lr': 3e-4}       # 新增组件：保持正常学习率，继续学习解剖先验
        ], weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        from torch.optim.lr_scheduler import CosineAnnealingLR
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}] - Model: {MODEL_TYPE}")
    
    # 1. 训练一轮
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    
    # 2. 验证一轮 (获取动态阈值算出的真实潜能 adj_acc 和 auc)
    val_loss, adj_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    
    # 学习率衰减
    scheduler.step()

    # 打印本轮总结 (注意这里打印的是 adj_acc)
    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {adj_acc:.2f}% | AUC: {val_auc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    # 3. 基于真实潜能 adj_acc 保存最佳模型
    if adj_acc > best_val_acc:
        best_val_acc = adj_acc
        torch.save(model.state_dict(), SAVE_PATH)  # SAVE_PATH 里已经包含了具体的 MODEL_TYPE 名字
        no_improve_epochs = 0
        logger.info(f"✅ 最佳模型已保存至 {SAVE_PATH}！当前最高准确率: {best_val_acc:.2f}%")
    else:
        no_improve_epochs += 1
        
    # 4. 早停机制 (Early Stopping)
    if no_improve_epochs >= patience:
        logger.info(f"\n🛑 已经连续 {patience} 轮没有刷新最高纪录，触发早停机制！")
        logger.info(f"🛑 {MODEL_TYPE} 的训练提前结束，防止过拟合。")
        break

logger.info("\n🎉 所有训练流程彻底完成！")
logger.info(f"🏆 {MODEL_TYPE} 最终锁定的最佳真实验证准确率: {best_val_acc:.2f}%")
# Out:
# 2026-07-02 05:49:37,166 - Train - INFO - ============================================================
# 2026-07-02 05:49:37,167 - Train - INFO - 开始训练模型: APM_Former | 优化目标: 最大化真实潜能 (adj_acc)
# 2026-07-02 05:49:37,168 - Train - INFO - ============================================================
# 2026-07-02 05:49:37,170 - Train - INFO -
# Epoch [1/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.19it/s]
# 2026-07-02 05:51:04,842 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6366
# 2026-07-02 05:51:04,853 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6366
# 2026-07-02 05:51:04,854 - Train - INFO - 👉 混淆矩阵: [类0: 37, 误判1: 15] | [漏判1: 12, 类1: 18]
# 2026-07-02 05:51:04,855 - Train - INFO - 🏆 真实指标: ACC: 67.07% | Precision: 54.55% | SEN: 60.00% | SPE: 71.15% | F1: 57.14% | AUC: 65.96%
# 2026-07-02 05:51:04,856 - Train - INFO - 训练损失: 0.6598 | 训练准确率: 47.56%
# 2026-07-02 05:51:04,857 - Train - INFO - 验证损失: 0.7247 | 验证准确率: 67.07% | AUC: 65.96%
# 2026-07-02 05:51:04,858 - Train - INFO - 当前学习率: 0.00029266
# 2026-07-02 05:51:05,990 - Train - INFO - ✅ 最佳模型已保存至 checkpoints/best_model3_APM_Former.pth！当前最高准确率: 67.07%
# 2026-07-02 05:51:05,992 - Train - INFO -
# Epoch [2/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-07-02 05:52:30,028 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6511
# 2026-07-02 05:52:30,040 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6511
# 2026-07-02 05:52:30,041 - Train - INFO - 👉 混淆矩阵: [类0: 14, 误判1: 38] | [漏判1: 3, 类1: 27]
# 2026-07-02 05:52:30,042 - Train - INFO - 🏆 真实指标: ACC: 50.00% | Precision: 41.54% | SEN: 90.00% | SPE: 26.92% | F1: 56.84% | AUC: 56.57%
# 2026-07-02 05:52:30,043 - Train - INFO - 训练损失: 0.6589 | 训练准确率: 48.63%
# 2026-07-02 05:52:30,044 - Train - INFO - 验证损失: 0.7333 | 验证准确率: 50.00% | AUC: 56.57%
# 2026-07-02 05:52:30,045 - Train - INFO - 当前学习率: 0.00027135
# 2026-07-02 05:52:30,045 - Train - INFO -
# Epoch [3/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.47it/s]
# 2026-07-02 05:53:54,015 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6674
# 2026-07-02 05:53:54,028 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6674
# 2026-07-02 05:53:54,029 - Train - INFO - 👉 混淆矩阵: [类0: 34, 误判1: 18] | [漏判1: 11, 类1: 19]
# 2026-07-02 05:53:54,031 - Train - INFO - 🏆 真实指标: ACC: 64.63% | Precision: 51.35% | SEN: 63.33% | SPE: 65.38% | F1: 56.72% | AUC: 66.15%
# 2026-07-02 05:53:54,032 - Train - INFO - 训练损失: 0.6477 | 训练准确率: 49.54%
# 2026-07-02 05:53:54,033 - Train - INFO - 验证损失: 0.7435 | 验证准确率: 64.63% | AUC: 66.15%
# 2026-07-02 05:53:54,034 - Train - INFO - 当前学习率: 0.00023817
# 2026-07-02 05:53:54,035 - Train - INFO -
# Epoch [4/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.42it/s]
# 2026-07-02 05:55:18,499 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6620
# 2026-07-02 05:55:18,510 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6620
# 2026-07-02 05:55:18,512 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 15, 类1: 15]
# 2026-07-02 05:55:18,512 - Train - INFO - 🏆 真实指标: ACC: 68.29% | Precision: 57.69% | SEN: 50.00% | SPE: 78.85% | F1: 53.57% | AUC: 63.65%
# 2026-07-02 05:55:18,514 - Train - INFO - 训练损失: 0.6493 | 训练准确率: 50.00%
# 2026-07-02 05:55:18,515 - Train - INFO - 验证损失: 0.7396 | 验证准确率: 68.29% | AUC: 63.65%
# 2026-07-02 05:55:18,515 - Train - INFO - 当前学习率: 0.00019635
# 2026-07-02 05:55:19,561 - Train - INFO - ✅ 最佳模型已保存至 checkpoints/best_model3_APM_Former.pth！当前最高准确率: 68.29%
# 2026-07-02 05:55:19,562 - Train - INFO -
# Epoch [5/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.47it/s]
# 2026-07-02 05:56:43,213 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6374
# 2026-07-02 05:56:43,224 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6374
# 2026-07-02 05:56:43,225 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 17, 类1: 13]
# 2026-07-02 05:56:43,226 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 72.22% | SEN: 43.33% | SPE: 90.38% | F1: 54.17% | AUC: 66.15%
# 2026-07-02 05:56:43,228 - Train - INFO - 训练损失: 0.6644 | 训练准确率: 48.02%
# 2026-07-02 05:56:43,228 - Train - INFO - 验证损失: 0.7244 | 验证准确率: 73.17% | AUC: 66.15%
# 2026-07-02 05:56:43,229 - Train - INFO - 当前学习率: 0.00015000
# 2026-07-02 05:56:44,391 - Train - INFO - ✅ 最佳模型已保存至 checkpoints/best_model3_APM_Former.pth！当前最高准确率: 73.17%
# 2026-07-02 05:56:44,392 - Train - INFO -
# Epoch [6/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.44it/s]
# 2026-07-02 05:58:08,029 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6389
# 2026-07-02 05:58:08,041 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6389
# 2026-07-02 05:58:08,042 - Train - INFO - 👉 混淆矩阵: [类0: 48, 误判1: 4] | [漏判1: 17, 类1: 13]
# 2026-07-02 05:58:08,043 - Train - INFO - 🏆 真实指标: ACC: 74.39% | Precision: 76.47% | SEN: 43.33% | SPE: 92.31% | F1: 55.32% | AUC: 65.90%
# 2026-07-02 05:58:08,044 - Train - INFO - 训练损失: 0.6513 | 训练准确率: 51.98%
# 2026-07-02 05:58:08,045 - Train - INFO - 验证损失: 0.7250 | 验证准确率: 74.39% | AUC: 65.90%
# 2026-07-02 05:58:08,046 - Train - INFO - 当前学习率: 0.00010365
# 2026-07-02 05:58:09,205 - Train - INFO - ✅ 最佳模型已保存至 checkpoints/best_model3_APM_Former.pth！当前最高准确率: 74.39%
# 2026-07-02 05:58:09,207 - Train - INFO -
# Epoch [7/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.45it/s]
# 2026-07-02 05:59:33,343 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6367
# 2026-07-02 05:59:33,356 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6367
# 2026-07-02 05:59:33,357 - Train - INFO - 👉 混淆矩阵: [类0: 48, 误判1: 4] | [漏判1: 16, 类1: 14]
# 2026-07-02 05:59:33,358 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 77.78% | SEN: 46.67% | SPE: 92.31% | F1: 58.33% | AUC: 67.28%
# 2026-07-02 05:59:33,359 - Train - INFO - 训练损失: 0.6649 | 训练准确率: 48.32%
# 2026-07-02 05:59:33,360 - Train - INFO - 验证损失: 0.7237 | 验证准确率: 75.61% | AUC: 67.28%
# 2026-07-02 05:59:33,361 - Train - INFO - 当前学习率: 0.00006183
# 2026-07-02 05:59:34,531 - Train - INFO - ✅ 最佳模型已保存至 checkpoints/best_model3_APM_Former.pth！当前最高准确率: 75.61%
# 2026-07-02 05:59:34,532 - Train - INFO -
# Epoch [8/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-07-02 06:01:00,137 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6311
# 2026-07-02 06:01:00,147 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6311
# 2026-07-02 06:01:00,148 - Train - INFO - 👉 混淆矩阵: [类0: 49, 误判1: 3] | [漏判1: 18, 类1: 12]
# 2026-07-02 06:01:00,148 - Train - INFO - 🏆 真实指标: ACC: 74.39% | Precision: 80.00% | SEN: 40.00% | SPE: 94.23% | F1: 53.33% | AUC: 67.69%
# 2026-07-02 06:01:00,150 - Train - INFO - 训练损失: 0.6603 | 训练准确率: 48.32%
# 2026-07-02 06:01:00,150 - Train - INFO - 验证损失: 0.7207 | 验证准确率: 74.39% | AUC: 67.69%
# 2026-07-02 06:01:00,151 - Train - INFO - 当前学习率: 0.00002865
# 2026-07-02 06:01:00,152 - Train - INFO -
# Epoch [9/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.43it/s]
# 2026-07-02 06:02:24,120 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6350
# 2026-07-02 06:02:24,131 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6350
# 2026-07-02 06:02:24,132 - Train - INFO - 👉 混淆矩阵: [类0: 51, 误判1: 1] | [漏判1: 19, 类1: 11]
# 2026-07-02 06:02:24,133 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 91.67% | SEN: 36.67% | SPE: 98.08% | F1: 52.38% | AUC: 67.76%
# 2026-07-02 06:02:24,134 - Train - INFO - 训练损失: 0.6461 | 训练准确率: 49.54%
# 2026-07-02 06:02:24,135 - Train - INFO - 验证损失: 0.7225 | 验证准确率: 75.61% | AUC: 67.76%
# 2026-07-02 06:02:24,136 - Train - INFO - 当前学习率: 0.00000734
# 2026-07-02 06:02:24,136 - Train - INFO -
# Epoch [10/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.45it/s]
# 2026-07-02 06:03:47,878 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6345
# 2026-07-02 06:03:47,889 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6345
# 2026-07-02 06:03:47,889 - Train - INFO - 👉 混淆矩阵: [类0: 49, 误判1: 3] | [漏判1: 18, 类1: 12]
# 2026-07-02 06:03:47,890 - Train - INFO - 🏆 真实指标: ACC: 74.39% | Precision: 80.00% | SEN: 40.00% | SPE: 94.23% | F1: 53.33% | AUC: 67.56%
# 2026-07-02 06:03:47,892 - Train - INFO - 训练损失: 0.6679 | 训练准确率: 46.19%
# 2026-07-02 06:03:47,892 - Train - INFO - 验证损失: 0.7223 | 验证准确率: 74.39% | AUC: 67.56%
# 2026-07-02 06:03:47,893 - Train - INFO - 当前学习率: 0.00000000
# 2026-07-02 06:03:47,894 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-07-02 06:03:47,894 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始【分层学习率】全员微调！
# 2026-07-02 06:03:47,895 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-07-02 06:03:47,898 - Train - INFO -
# Epoch [11/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-07-02 06:05:12,228 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6472
# 2026-07-02 06:05:12,239 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6472
# 2026-07-02 06:05:12,240 - Train - INFO - 👉 混淆矩阵: [类0: 46, 误判1: 6] | [漏判1: 16, 类1: 14]
# 2026-07-02 06:05:12,241 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 70.00% | SEN: 46.67% | SPE: 88.46% | F1: 56.00% | AUC: 65.00%
# 2026-07-02 06:05:12,242 - Train - INFO - 训练损失: 0.6576 | 训练准确率: 49.54%
# 2026-07-02 06:05:12,243 - Train - INFO - 验证损失: 0.7298 | 验证准确率: 73.17% | AUC: 65.00%
# 2026-07-02 06:05:12,244 - Train - INFO - 当前学习率: 0.00000999
# 2026-07-02 06:05:12,244 - Train - INFO -
# Epoch [12/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-07-02 06:06:36,830 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6462
# 2026-07-02 06:06:36,843 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6462
# 2026-07-02 06:06:36,844 - Train - INFO - 👉 混淆矩阵: [类0: 45, 误判1: 7] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:06:36,845 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 68.18% | SEN: 50.00% | SPE: 86.54% | F1: 57.69% | AUC: 68.97%
# 2026-07-02 06:06:36,846 - Train - INFO - 训练损失: 0.6629 | 训练准确率: 47.87%
# 2026-07-02 06:06:36,847 - Train - INFO - 验证损失: 0.7283 | 验证准确率: 73.17% | AUC: 68.97%
# 2026-07-02 06:06:36,848 - Train - INFO - 当前学习率: 0.00000998
# 2026-07-02 06:06:36,849 - Train - INFO -
# Epoch [13/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-07-02 06:08:02,659 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6559
# 2026-07-02 06:08:02,670 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6559
# 2026-07-02 06:08:02,670 - Train - INFO - 👉 混淆矩阵: [类0: 45, 误判1: 7] | [漏判1: 16, 类1: 14]
# 2026-07-02 06:08:02,671 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 66.67% | SEN: 46.67% | SPE: 86.54% | F1: 54.90% | AUC: 67.63%
# 2026-07-02 06:08:02,673 - Train - INFO - 训练损失: 0.6544 | 训练准确率: 49.24%
# 2026-07-02 06:08:02,674 - Train - INFO - 验证损失: 0.7329 | 验证准确率: 71.95% | AUC: 67.63%
# 2026-07-02 06:08:02,674 - Train - INFO - 当前学习率: 0.00000995
# 2026-07-02 06:08:02,675 - Train - INFO -
# Epoch [14/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.46it/s]
# 2026-07-02 06:09:25,637 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7047
# 2026-07-02 06:09:25,647 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7047
# 2026-07-02 06:09:25,647 - Train - INFO - 👉 混淆矩阵: [类0: 43, 误判1: 9] | [漏判1: 14, 类1: 16]
# 2026-07-02 06:09:25,648 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 64.00% | SEN: 53.33% | SPE: 82.69% | F1: 58.18% | AUC: 66.35%
# 2026-07-02 06:09:25,650 - Train - INFO - 训练损失: 0.6346 | 训练准确率: 53.05%
# 2026-07-02 06:09:25,650 - Train - INFO - 验证损失: 0.7712 | 验证准确率: 71.95% | AUC: 66.35%
# 2026-07-02 06:09:25,651 - Train - INFO - 当前学习率: 0.00000992
# 2026-07-02 06:09:25,652 - Train - INFO -
# Epoch [15/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.38it/s]
# 2026-07-02 06:10:50,264 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6079
# 2026-07-02 06:10:50,276 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6079
# 2026-07-02 06:10:50,277 - Train - INFO - 👉 混淆矩阵: [类0: 24, 误判1: 28] | [漏判1: 6, 类1: 24]
# 2026-07-02 06:10:50,278 - Train - INFO - 🏆 真实指标: ACC: 58.54% | Precision: 46.15% | SEN: 80.00% | SPE: 46.15% | F1: 58.54% | AUC: 63.78%
# 2026-07-02 06:10:50,280 - Train - INFO - 训练损失: 0.6678 | 训练准确率: 47.10%
# 2026-07-02 06:10:50,281 - Train - INFO - 验证损失: 0.7107 | 验证准确率: 58.54% | AUC: 63.78%
# 2026-07-02 06:10:50,282 - Train - INFO - 当前学习率: 0.00000987
# 2026-07-02 06:10:50,283 - Train - INFO -
# Epoch [16/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.44it/s]
# 2026-07-02 06:12:14,094 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6122
# 2026-07-02 06:12:14,106 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6122
# 2026-07-02 06:12:14,107 - Train - INFO - 👉 混淆矩阵: [类0: 33, 误判1: 19] | [漏判1: 11, 类1: 19]
# 2026-07-02 06:12:14,108 - Train - INFO - 🏆 真实指标: ACC: 63.41% | Precision: 50.00% | SEN: 63.33% | SPE: 63.46% | F1: 55.88% | AUC: 63.27%
# 2026-07-02 06:12:14,109 - Train - INFO - 训练损失: 0.6671 | 训练准确率: 48.17%
# 2026-07-02 06:12:14,110 - Train - INFO - 验证损失: 0.7116 | 验证准确率: 63.41% | AUC: 63.27%
# 2026-07-02 06:12:14,111 - Train - INFO - 当前学习率: 0.00000982
# 2026-07-02 06:12:14,112 - Train - INFO -
# Epoch [17/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-07-02 06:13:38,633 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6774
# 2026-07-02 06:13:38,643 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6774
# 2026-07-02 06:13:38,644 - Train - INFO - 👉 混淆矩阵: [类0: 42, 误判1: 10] | [漏判1: 14, 类1: 16]
# 2026-07-02 06:13:38,645 - Train - INFO - 🏆 真实指标: ACC: 70.73% | Precision: 61.54% | SEN: 53.33% | SPE: 80.77% | F1: 57.14% | AUC: 66.12%
# 2026-07-02 06:13:38,647 - Train - INFO - 训练损失: 0.6325 | 训练准确率: 53.66%
# 2026-07-02 06:13:38,648 - Train - INFO - 验证损失: 0.7469 | 验证准确率: 70.73% | AUC: 66.12%
# 2026-07-02 06:13:38,649 - Train - INFO - 当前学习率: 0.00000976
# 2026-07-02 06:13:38,649 - Train - INFO -
# Epoch [18/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.45it/s]
# 2026-07-02 06:15:01,599 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6819
# 2026-07-02 06:15:01,612 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6819
# 2026-07-02 06:15:01,613 - Train - INFO - 👉 混淆矩阵: [类0: 49, 误判1: 3] | [漏判1: 16, 类1: 14]
# 2026-07-02 06:15:01,614 - Train - INFO - 🏆 真实指标: ACC: 76.83% | Precision: 82.35% | SEN: 46.67% | SPE: 94.23% | F1: 59.57% | AUC: 68.85%
# 2026-07-02 06:15:01,615 - Train - INFO - 训练损失: 0.6397 | 训练准确率: 51.07%
# 2026-07-02 06:15:01,616 - Train - INFO - 验证损失: 0.7477 | 验证准确率: 76.83% | AUC: 68.85%
# 2026-07-02 06:15:01,617 - Train - INFO - 当前学习率: 0.00000968
# 2026-07-02 06:15:02,803 - Train - INFO - ✅ 最佳模型已保存至 checkpoints/best_model3_APM_Former.pth！当前最高准确率: 76.83%
# 2026-07-02 06:15:02,804 - Train - INFO -
# Epoch [19/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.48it/s]
# 2026-07-02 06:16:26,223 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7004
# 2026-07-02 06:16:26,235 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7004
# 2026-07-02 06:16:26,237 - Train - INFO - 👉 混淆矩阵: [类0: 46, 误判1: 6] | [漏判1: 17, 类1: 13]
# 2026-07-02 06:16:26,239 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 68.42% | SEN: 43.33% | SPE: 88.46% | F1: 53.06% | AUC: 66.22%
# 2026-07-02 06:16:26,241 - Train - INFO - 训练损失: 0.6285 | 训练准确率: 51.83%
# 2026-07-02 06:16:26,242 - Train - INFO - 验证损失: 0.7637 | 验证准确率: 71.95% | AUC: 66.22%
# 2026-07-02 06:16:26,243 - Train - INFO - 当前学习率: 0.00000960
# 2026-07-02 06:16:26,243 - Train - INFO -
# Epoch [20/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-07-02 06:17:51,009 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6141
# 2026-07-02 06:17:51,018 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6141
# 2026-07-02 06:17:51,019 - Train - INFO - 👉 混淆矩阵: [类0: 39, 误判1: 13] | [漏判1: 12, 类1: 18]
# 2026-07-02 06:17:51,020 - Train - INFO - 🏆 真实指标: ACC: 69.51% | Precision: 58.06% | SEN: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 70.00%
# 2026-07-02 06:17:51,021 - Train - INFO - 训练损失: 0.6591 | 训练准确率: 48.93%
# 2026-07-02 06:17:51,022 - Train - INFO - 验证损失: 0.7110 | 验证准确率: 69.51% | AUC: 70.00%
# 2026-07-02 06:17:51,023 - Train - INFO - 当前学习率: 0.00000950
# 2026-07-02 06:17:51,024 - Train - INFO -
# Epoch [21/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-07-02 06:19:18,347 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6070
# 2026-07-02 06:19:18,357 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6070
# 2026-07-02 06:19:18,358 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:19:18,359 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 75.00% | SEN: 50.00% | SPE: 90.38% | F1: 60.00% | AUC: 70.71%
# 2026-07-02 06:19:18,360 - Train - INFO - 训练损失: 0.6742 | 训练准确率: 45.58%
# 2026-07-02 06:19:18,361 - Train - INFO - 验证损失: 0.7079 | 验证准确率: 75.61% | AUC: 70.71%
# 2026-07-02 06:19:18,362 - Train - INFO - 当前学习率: 0.00000940
# 2026-07-02 06:19:18,362 - Train - INFO -
# Epoch [22/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.19it/s]
# 2026-07-02 06:20:47,388 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6211
# 2026-07-02 06:20:47,399 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6211
# 2026-07-02 06:20:47,400 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 16, 类1: 14]
# 2026-07-02 06:20:47,401 - Train - INFO - 🏆 真实指标: ACC: 74.39% | Precision: 73.68% | SEN: 46.67% | SPE: 90.38% | F1: 57.14% | AUC: 68.85%
# 2026-07-02 06:20:47,403 - Train - INFO - 训练损失: 0.6690 | 训练准确率: 45.88%
# 2026-07-02 06:20:47,404 - Train - INFO - 验证损失: 0.7097 | 验证准确率: 74.39% | AUC: 68.85%
# 2026-07-02 06:20:47,405 - Train - INFO - 当前学习率: 0.00000929
# 2026-07-02 06:20:47,406 - Train - INFO -
# Epoch [23/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.43it/s]
# 2026-07-02 06:22:11,223 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6504
# 2026-07-02 06:22:11,233 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6504
# 2026-07-02 06:22:11,233 - Train - INFO - 👉 混淆矩阵: [类0: 44, 误判1: 8] | [漏判1: 14, 类1: 16]
# 2026-07-02 06:22:11,234 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 66.67% | SEN: 53.33% | SPE: 84.62% | F1: 59.26% | AUC: 69.62%
# 2026-07-02 06:22:11,236 - Train - INFO - 训练损失: 0.6556 | 训练准确率: 48.17%
# 2026-07-02 06:22:11,236 - Train - INFO - 验证损失: 0.7222 | 验证准确率: 73.17% | AUC: 69.62%
# 2026-07-02 06:22:11,237 - Train - INFO - 当前学习率: 0.00000917
# 2026-07-02 06:22:11,238 - Train - INFO -
# Epoch [24/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.30it/s]
# 2026-07-02 06:23:37,323 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6388
# 2026-07-02 06:23:37,335 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6388
# 2026-07-02 06:23:37,336 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:23:37,336 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 75.00% | SEN: 50.00% | SPE: 90.38% | F1: 60.00% | AUC: 69.68%
# 2026-07-02 06:23:37,338 - Train - INFO - 训练损失: 0.6416 | 训练准确率: 49.09%
# 2026-07-02 06:23:37,339 - Train - INFO - 验证损失: 0.7115 | 验证准确率: 75.61% | AUC: 69.68%
# 2026-07-02 06:23:37,339 - Train - INFO - 当前学习率: 0.00000905
# 2026-07-02 06:23:37,340 - Train - INFO -
# Epoch [25/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-07-02 06:25:01,472 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6882
# 2026-07-02 06:25:01,480 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6882
# 2026-07-02 06:25:01,481 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 16, 类1: 14]
# 2026-07-02 06:25:01,481 - Train - INFO - 🏆 真实指标: ACC: 74.39% | Precision: 73.68% | SEN: 46.67% | SPE: 90.38% | F1: 57.14% | AUC: 70.26%
# 2026-07-02 06:25:01,482 - Train - INFO - 训练损失: 0.6273 | 训练准确率: 52.13%
# 2026-07-02 06:25:01,482 - Train - INFO - 验证损失: 0.7359 | 验证准确率: 74.39% | AUC: 70.26%
# 2026-07-02 06:25:01,482 - Train - INFO - 当前学习率: 0.00000891
# 2026-07-02 06:25:01,482 - Train - INFO -
# Epoch [26/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-07-02 06:26:25,728 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6713
# 2026-07-02 06:26:25,737 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6713
# 2026-07-02 06:26:25,738 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:26:25,739 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 75.00% | SEN: 50.00% | SPE: 90.38% | F1: 60.00% | AUC: 70.19%
# 2026-07-02 06:26:25,741 - Train - INFO - 训练损失: 0.6234 | 训练准确率: 51.68%
# 2026-07-02 06:26:25,741 - Train - INFO - 验证损失: 0.7174 | 验证准确率: 75.61% | AUC: 70.19%
# 2026-07-02 06:26:25,742 - Train - INFO - 当前学习率: 0.00000877
# 2026-07-02 06:26:25,743 - Train - INFO -
# Epoch [27/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-07-02 06:27:50,545 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6409
# 2026-07-02 06:27:50,553 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6409
# 2026-07-02 06:27:50,554 - Train - INFO - 👉 混淆矩阵: [类0: 46, 误判1: 6] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:27:50,555 - Train - INFO - 🏆 真实指标: ACC: 74.39% | Precision: 71.43% | SEN: 50.00% | SPE: 88.46% | F1: 58.82% | AUC: 69.36%
# 2026-07-02 06:27:50,556 - Train - INFO - 训练损失: 0.6572 | 训练准确率: 47.87%
# 2026-07-02 06:27:50,557 - Train - INFO - 验证损失: 0.7011 | 验证准确率: 74.39% | AUC: 69.36%
# 2026-07-02 06:27:50,558 - Train - INFO - 当前学习率: 0.00000861
# 2026-07-02 06:27:50,558 - Train - INFO -
# Epoch [28/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-07-02 06:29:14,983 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6805
# 2026-07-02 06:29:14,994 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6805
# 2026-07-02 06:29:14,995 - Train - INFO - 👉 混淆矩阵: [类0: 48, 误判1: 4] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:29:14,996 - Train - INFO - 🏆 真实指标: ACC: 76.83% | Precision: 78.95% | SEN: 50.00% | SPE: 92.31% | F1: 61.22% | AUC: 70.26%
# 2026-07-02 06:29:14,998 - Train - INFO - 训练损失: 0.6447 | 训练准确率: 48.93%
# 2026-07-02 06:29:14,998 - Train - INFO - 验证损失: 0.7099 | 验证准确率: 76.83% | AUC: 70.26%
# 2026-07-02 06:29:14,999 - Train - INFO - 当前学习率: 0.00000846
# 2026-07-02 06:29:15,000 - Train - INFO -
# Epoch [29/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.37it/s]
# 2026-07-02 06:30:39,834 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6380
# 2026-07-02 06:30:39,844 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6380
# 2026-07-02 06:30:39,846 - Train - INFO - 👉 混淆矩阵: [类0: 37, 误判1: 15] | [漏判1: 9, 类1: 21]
# 2026-07-02 06:30:39,846 - Train - INFO - 🏆 真实指标: ACC: 70.73% | Precision: 58.33% | SEN: 70.00% | SPE: 71.15% | F1: 63.64% | AUC: 70.77%
# 2026-07-02 06:30:39,848 - Train - INFO - 训练损失: 0.6501 | 训练准确率: 48.02%
# 2026-07-02 06:30:39,848 - Train - INFO - 验证损失: 0.6862 | 验证准确率: 70.73% | AUC: 70.77%
# 2026-07-02 06:30:39,849 - Train - INFO - 当前学习率: 0.00000829
# 2026-07-02 06:30:39,850 - Train - INFO -
# Epoch [30/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-07-02 06:32:03,637 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7445
# 2026-07-02 06:32:03,645 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7445
# 2026-07-02 06:32:03,646 - Train - INFO - 👉 混淆矩阵: [类0: 46, 误判1: 6] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:32:03,646 - Train - INFO - 🏆 真实指标: ACC: 74.39% | Precision: 71.43% | SEN: 50.00% | SPE: 88.46% | F1: 58.82% | AUC: 66.03%
# 2026-07-02 06:32:03,648 - Train - INFO - 训练损失: 0.6197 | 训练准确率: 51.98%
# 2026-07-02 06:32:03,648 - Train - INFO - 验证损失: 0.7817 | 验证准确率: 74.39% | AUC: 66.03%
# 2026-07-02 06:32:03,649 - Train - INFO - 当前学习率: 0.00000812
# 2026-07-02 06:32:03,650 - Train - INFO -
# Epoch [31/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.42it/s]
# 2026-07-02 06:33:27,891 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7661
# 2026-07-02 06:33:27,900 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7661
# 2026-07-02 06:33:27,901 - Train - INFO - 👉 混淆矩阵: [类0: 45, 误判1: 7] | [漏判1: 13, 类1: 17]
# 2026-07-02 06:33:27,902 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 70.83% | SEN: 56.67% | SPE: 86.54% | F1: 62.96% | AUC: 68.59%
# 2026-07-02 06:33:27,903 - Train - INFO - 训练损失: 0.6158 | 训练准确率: 51.52%
# 2026-07-02 06:33:27,904 - Train - INFO - 验证损失: 0.7810 | 验证准确率: 75.61% | AUC: 68.59%
# 2026-07-02 06:33:27,905 - Train - INFO - 当前学习率: 0.00000794
# 2026-07-02 06:33:27,905 - Train - INFO -
# Epoch [32/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-07-02 06:34:52,175 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7044
# 2026-07-02 06:34:52,186 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7044
# 2026-07-02 06:34:52,187 - Train - INFO - 👉 混淆矩阵: [类0: 48, 误判1: 4] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:34:52,188 - Train - INFO - 🏆 真实指标: ACC: 76.83% | Precision: 78.95% | SEN: 50.00% | SPE: 92.31% | F1: 61.22% | AUC: 70.58%
# 2026-07-02 06:34:52,190 - Train - INFO - 训练损失: 0.6386 | 训练准确率: 46.80%
# 2026-07-02 06:34:52,191 - Train - INFO - 验证损失: 0.6839 | 验证准确率: 76.83% | AUC: 70.58%
# 2026-07-02 06:34:52,192 - Train - INFO - 当前学习率: 0.00000775
# 2026-07-02 06:34:52,194 - Train - INFO -
# Epoch [33/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.34it/s]
# 2026-07-02 06:36:17,638 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6818
# 2026-07-02 06:36:17,651 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6818
# 2026-07-02 06:36:17,652 - Train - INFO - 👉 混淆矩阵: [类0: 50, 误判1: 2] | [漏判1: 16, 类1: 14]
# 2026-07-02 06:36:17,653 - Train - INFO - 🏆 真实指标: ACC: 78.05% | Precision: 87.50% | SEN: 46.67% | SPE: 96.15% | F1: 60.87% | AUC: 71.15%
# 2026-07-02 06:36:17,654 - Train - INFO - 训练损失: 0.6230 | 训练准确率: 49.54%
# 2026-07-02 06:36:17,655 - Train - INFO - 验证损失: 0.6577 | 验证准确率: 78.05% | AUC: 71.15%
# 2026-07-02 06:36:17,656 - Train - INFO - 当前学习率: 0.00000756
# 2026-07-02 06:36:18,624 - Train - INFO - ✅ 最佳模型已保存至 checkpoints/best_model3_APM_Former.pth！当前最高准确率: 78.05%
# 2026-07-02 06:36:18,625 - Train - INFO -
# Epoch [34/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.43it/s]
# 2026-07-02 06:37:44,231 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.6575
# 2026-07-02 06:37:44,242 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.6575
# 2026-07-02 06:37:44,243 - Train - INFO - 👉 混淆矩阵: [类0: 45, 误判1: 7] | [漏判1: 13, 类1: 17]
# 2026-07-02 06:37:44,244 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 70.83% | SEN: 56.67% | SPE: 86.54% | F1: 62.96% | AUC: 70.06%
# 2026-07-02 06:37:44,246 - Train - INFO - 训练损失: 0.6221 | 训练准确率: 50.15%
# 2026-07-02 06:37:44,246 - Train - INFO - 验证损失: 0.6630 | 验证准确率: 75.61% | AUC: 70.06%
# 2026-07-02 06:37:44,247 - Train - INFO - 当前学习率: 0.00000737
# 2026-07-02 06:37:44,248 - Train - INFO -
# Epoch [35/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.43it/s]
# 2026-07-02 06:39:08,596 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7459
# 2026-07-02 06:39:08,610 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7459
# 2026-07-02 06:39:08,611 - Train - INFO - 👉 混淆矩阵: [类0: 45, 误判1: 7] | [漏判1: 13, 类1: 17]
# 2026-07-02 06:39:08,612 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 70.83% | SEN: 56.67% | SPE: 86.54% | F1: 62.96% | AUC: 69.74%
# 2026-07-02 06:39:08,613 - Train - INFO - 训练损失: 0.6200 | 训练准确率: 53.66%
# 2026-07-02 06:39:08,614 - Train - INFO - 验证损失: 0.7196 | 验证准确率: 75.61% | AUC: 69.74%
# 2026-07-02 06:39:08,615 - Train - INFO - 当前学习率: 0.00000717
# 2026-07-02 06:39:08,616 - Train - INFO -
# Epoch [36/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-07-02 06:40:32,846 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8301
# 2026-07-02 06:40:32,856 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8301
# 2026-07-02 06:40:32,857 - Train - INFO - 👉 混淆矩阵: [类0: 46, 误判1: 6] | [漏判1: 14, 类1: 16]
# 2026-07-02 06:40:32,858 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 72.73% | SEN: 53.33% | SPE: 88.46% | F1: 61.54% | AUC: 69.55%
# 2026-07-02 06:40:32,859 - Train - INFO - 训练损失: 0.6254 | 训练准确率: 52.90%
# 2026-07-02 06:40:32,860 - Train - INFO - 验证损失: 0.8529 | 验证准确率: 75.61% | AUC: 69.55%
# 2026-07-02 06:40:32,860 - Train - INFO - 当前学习率: 0.00000697
# 2026-07-02 06:40:32,861 - Train - INFO -
# Epoch [37/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.44it/s]
# 2026-07-02 06:41:57,834 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7458
# 2026-07-02 06:41:57,845 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7458
# 2026-07-02 06:41:57,845 - Train - INFO - 👉 混淆矩阵: [类0: 46, 误判1: 6] | [漏判1: 13, 类1: 17]
# 2026-07-02 06:41:57,846 - Train - INFO - 🏆 真实指标: ACC: 76.83% | Precision: 73.91% | SEN: 56.67% | SPE: 88.46% | F1: 64.15% | AUC: 68.59%
# 2026-07-02 06:41:57,847 - Train - INFO - 训练损失: 0.6310 | 训练准确率: 50.91%
# 2026-07-02 06:41:57,847 - Train - INFO - 验证损失: 0.7248 | 验证准确率: 76.83% | AUC: 68.59%
# 2026-07-02 06:41:57,847 - Train - INFO - 当前学习率: 0.00000676
# 2026-07-02 06:41:57,848 - Train - INFO -
# Epoch [38/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.44it/s]
# 2026-07-02 06:43:22,570 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8034
# 2026-07-02 06:43:22,581 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8034
# 2026-07-02 06:43:22,582 - Train - INFO - 👉 混淆矩阵: [类0: 40, 误判1: 12] | [漏判1: 11, 类1: 19]
# 2026-07-02 06:43:22,584 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 61.29% | SEN: 63.33% | SPE: 76.92% | F1: 62.30% | AUC: 67.95%
# 2026-07-02 06:43:22,585 - Train - INFO - 训练损失: 0.6184 | 训练准确率: 51.52%
# 2026-07-02 06:43:22,586 - Train - INFO - 验证损失: 0.8357 | 验证准确率: 71.95% | AUC: 67.95%
# 2026-07-02 06:43:22,587 - Train - INFO - 当前学习率: 0.00000655
# 2026-07-02 06:43:22,588 - Train - INFO -
# Epoch [39/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.44it/s]
# 2026-07-02 06:44:47,038 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7187
# 2026-07-02 06:44:47,054 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7187
# 2026-07-02 06:44:47,056 - Train - INFO - 👉 混淆矩阵: [类0: 46, 误判1: 6] | [漏判1: 13, 类1: 17]
# 2026-07-02 06:44:47,058 - Train - INFO - 🏆 真实指标: ACC: 76.83% | Precision: 73.91% | SEN: 56.67% | SPE: 88.46% | F1: 64.15% | AUC: 70.19%
# 2026-07-02 06:44:47,060 - Train - INFO - 训练损失: 0.6096 | 训练准确率: 51.83%
# 2026-07-02 06:44:47,061 - Train - INFO - 验证损失: 0.6808 | 验证准确率: 76.83% | AUC: 70.19%
# 2026-07-02 06:44:47,062 - Train - INFO - 当前学习率: 0.00000633
# 2026-07-02 06:44:47,063 - Train - INFO -
# Epoch [40/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.31it/s]
# 2026-07-02 06:46:14,415 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7248
# 2026-07-02 06:46:14,427 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7248
# 2026-07-02 06:46:14,428 - Train - INFO - 👉 混淆矩阵: [类0: 42, 误判1: 10] | [漏判1: 12, 类1: 18]
# 2026-07-02 06:46:14,429 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 64.29% | SEN: 60.00% | SPE: 80.77% | F1: 62.07% | AUC: 70.58%
# 2026-07-02 06:46:14,430 - Train - INFO - 训练损失: 0.6351 | 训练准确率: 51.07%
# 2026-07-02 06:46:14,431 - Train - INFO - 验证损失: 0.6905 | 验证准确率: 73.17% | AUC: 70.58%
# 2026-07-02 06:46:14,432 - Train - INFO - 当前学习率: 0.00000611
# 2026-07-02 06:46:14,433 - Train - INFO -
# Epoch [41/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.42it/s]
# 2026-07-02 06:47:39,541 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8510
# 2026-07-02 06:47:39,552 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8510
# 2026-07-02 06:47:39,553 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:47:39,554 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 75.00% | SEN: 50.00% | SPE: 90.38% | F1: 60.00% | AUC: 69.42%
# 2026-07-02 06:47:39,555 - Train - INFO - 训练损失: 0.6255 | 训练准确率: 52.74%
# 2026-07-02 06:47:39,556 - Train - INFO - 验证损失: 0.8454 | 验证准确率: 75.61% | AUC: 69.42%
# 2026-07-02 06:47:39,557 - Train - INFO - 当前学习率: 0.00000589
# 2026-07-02 06:47:39,558 - Train - INFO -
# Epoch [42/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-07-02 06:49:04,522 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7351
# 2026-07-02 06:49:04,535 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7351
# 2026-07-02 06:49:04,536 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 11, 类1: 19]
# 2026-07-02 06:49:04,537 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 63.33% | SEN: 63.33% | SPE: 78.85% | F1: 63.33% | AUC: 70.58%
# 2026-07-02 06:49:04,539 - Train - INFO - 训练损失: 0.6058 | 训练准确率: 54.57%
# 2026-07-02 06:49:04,540 - Train - INFO - 验证损失: 0.6787 | 验证准确率: 73.17% | AUC: 70.58%
# 2026-07-02 06:49:04,541 - Train - INFO - 当前学习率: 0.00000567
# 2026-07-02 06:49:04,542 - Train - INFO -
# Epoch [43/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.27it/s]
# 2026-07-02 06:50:32,013 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8675
# 2026-07-02 06:50:32,025 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8675
# 2026-07-02 06:50:32,026 - Train - INFO - 👉 混淆矩阵: [类0: 47, 误判1: 5] | [漏判1: 15, 类1: 15]
# 2026-07-02 06:50:32,027 - Train - INFO - 🏆 真实指标: ACC: 75.61% | Precision: 75.00% | SEN: 50.00% | SPE: 90.38% | F1: 60.00% | AUC: 69.62%
# 2026-07-02 06:50:32,029 - Train - INFO - 训练损失: 0.6046 | 训练准确率: 52.13%
# 2026-07-02 06:50:32,030 - Train - INFO - 验证损失: 0.8737 | 验证准确率: 75.61% | AUC: 69.62%
# 2026-07-02 06:50:32,031 - Train - INFO - 当前学习率: 0.00000545
# 2026-07-02 06:50:32,032 - Train - INFO -
# Epoch [44/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-07-02 06:51:57,281 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7587
# 2026-07-02 06:51:57,292 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7587
# 2026-07-02 06:51:57,292 - Train - INFO - 👉 混淆矩阵: [类0: 40, 误判1: 12] | [漏判1: 11, 类1: 19]
# 2026-07-02 06:51:57,294 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 61.29% | SEN: 63.33% | SPE: 76.92% | F1: 62.30% | AUC: 70.26%
# 2026-07-02 06:51:57,295 - Train - INFO - 训练损失: 0.5893 | 训练准确率: 52.74%
# 2026-07-02 06:51:57,296 - Train - INFO - 验证损失: 0.7102 | 验证准确率: 71.95% | AUC: 70.26%
# 2026-07-02 06:51:57,297 - Train - INFO - 当前学习率: 0.00000522
# 2026-07-02 06:51:57,298 - Train - INFO -
# Epoch [45/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-07-02 06:53:23,146 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8990
# 2026-07-02 06:53:23,156 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8990
# 2026-07-02 06:53:23,157 - Train - INFO - 👉 混淆矩阵: [类0: 49, 误判1: 3] | [漏判1: 16, 类1: 14]
# 2026-07-02 06:53:23,158 - Train - INFO - 🏆 真实指标: ACC: 76.83% | Precision: 82.35% | SEN: 46.67% | SPE: 94.23% | F1: 59.57% | AUC: 69.04%
# 2026-07-02 06:53:23,159 - Train - INFO - 训练损失: 0.6131 | 训练准确率: 52.13%
# 2026-07-02 06:53:23,160 - Train - INFO - 验证损失: 0.9449 | 验证准确率: 76.83% | AUC: 69.04%
# 2026-07-02 06:53:23,161 - Train - INFO - 当前学习率: 0.00000500
# 2026-07-02 06:53:23,161 - Train - INFO -
# Epoch [46/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-07-02 06:54:48,582 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8419
# 2026-07-02 06:54:48,599 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8419
# 2026-07-02 06:54:48,601 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 12, 类1: 18]
# 2026-07-02 06:54:48,602 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.07% | SEN: 60.00% | SPE: 78.85% | F1: 61.02% | AUC: 69.87%
# 2026-07-02 06:54:48,604 - Train - INFO - 训练损失: 0.6130 | 训练准确率: 52.74%
# 2026-07-02 06:54:48,604 - Train - INFO - 验证损失: 0.8169 | 验证准确率: 71.95% | AUC: 69.87%
# 2026-07-02 06:54:48,606 - Train - INFO - 当前学习率: 0.00000478
# 2026-07-02 06:54:48,607 - Train - INFO -
# Epoch [47/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.38it/s]
# 2026-07-02 06:56:13,361 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8890
# 2026-07-02 06:56:13,374 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8890
# 2026-07-02 06:56:13,375 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 12, 类1: 18]
# 2026-07-02 06:56:13,376 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.07% | SEN: 60.00% | SPE: 78.85% | F1: 61.02% | AUC: 69.87%
# 2026-07-02 06:56:13,378 - Train - INFO - 训练损失: 0.6256 | 训练准确率: 52.13%
# 2026-07-02 06:56:13,378 - Train - INFO - 验证损失: 0.9660 | 验证准确率: 71.95% | AUC: 69.87%
# 2026-07-02 06:56:13,379 - Train - INFO - 当前学习率: 0.00000455
# 2026-07-02 06:56:13,380 - Train - INFO -
# Epoch [48/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.27it/s]
# 2026-07-02 06:57:40,674 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8380
# 2026-07-02 06:57:40,688 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8380
# 2026-07-02 06:57:40,690 - Train - INFO - 👉 混淆矩阵: [类0: 43, 误判1: 9] | [漏判1: 13, 类1: 17]
# 2026-07-02 06:57:40,691 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 65.38% | SEN: 56.67% | SPE: 82.69% | F1: 60.71% | AUC: 69.17%
# 2026-07-02 06:57:40,693 - Train - INFO - 训练损失: 0.6444 | 训练准确率: 51.22%
# 2026-07-02 06:57:40,694 - Train - INFO - 验证损失: 0.8167 | 验证准确率: 73.17% | AUC: 69.17%
# 2026-07-02 06:57:40,695 - Train - INFO - 当前学习率: 0.00000433
# 2026-07-02 06:57:40,696 - Train - INFO -
# Epoch [49/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.27it/s]
# 2026-07-02 06:59:07,577 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8655
# 2026-07-02 06:59:07,590 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8655
# 2026-07-02 06:59:07,592 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 12, 类1: 18]
# 2026-07-02 06:59:07,593 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.07% | SEN: 60.00% | SPE: 78.85% | F1: 61.02% | AUC: 70.32%
# 2026-07-02 06:59:07,595 - Train - INFO - 训练损失: 0.6332 | 训练准确率: 54.12%
# 2026-07-02 06:59:07,596 - Train - INFO - 验证损失: 0.8638 | 验证准确率: 71.95% | AUC: 70.32%
# 2026-07-02 06:59:07,597 - Train - INFO - 当前学习率: 0.00000411
# 2026-07-02 06:59:07,599 - Train - INFO -
# Epoch [50/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.32it/s]
# 2026-07-02 07:00:32,782 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8461
# 2026-07-02 07:00:32,793 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8461
# 2026-07-02 07:00:32,794 - Train - INFO - 👉 混淆矩阵: [类0: 42, 误判1: 10] | [漏判1: 12, 类1: 18]
# 2026-07-02 07:00:32,795 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 64.29% | SEN: 60.00% | SPE: 80.77% | F1: 62.07% | AUC: 70.06%
# 2026-07-02 07:00:32,797 - Train - INFO - 训练损失: 0.6520 | 训练准确率: 51.83%
# 2026-07-02 07:00:32,798 - Train - INFO - 验证损失: 0.8144 | 验证准确率: 73.17% | AUC: 70.06%
# 2026-07-02 07:00:32,800 - Train - INFO - 当前学习率: 0.00000389
# 2026-07-02 07:00:32,801 - Train - INFO -
# Epoch [51/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.30it/s]
# 2026-07-02 07:01:59,520 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8243
# 2026-07-02 07:01:59,530 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8243
# 2026-07-02 07:01:59,530 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 11, 类1: 19]
# 2026-07-02 07:01:59,531 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 63.33% | SEN: 63.33% | SPE: 78.85% | F1: 63.33% | AUC: 70.32%
# 2026-07-02 07:01:59,533 - Train - INFO - 训练损失: 0.6041 | 训练准确率: 56.55%
# 2026-07-02 07:01:59,533 - Train - INFO - 验证损失: 0.7705 | 验证准确率: 73.17% | AUC: 70.32%
# 2026-07-02 07:01:59,534 - Train - INFO - 当前学习率: 0.00000367
# 2026-07-02 07:01:59,535 - Train - INFO -
# Epoch [52/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.43it/s]
# 2026-07-02 07:03:24,100 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7885
# 2026-07-02 07:03:24,109 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7885
# 2026-07-02 07:03:24,110 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 11, 类1: 19]
# 2026-07-02 07:03:24,111 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 63.33% | SEN: 63.33% | SPE: 78.85% | F1: 63.33% | AUC: 70.45%
# 2026-07-02 07:03:24,112 - Train - INFO - 训练损失: 0.6296 | 训练准确率: 51.52%
# 2026-07-02 07:03:24,113 - Train - INFO - 验证损失: 0.7213 | 验证准确率: 73.17% | AUC: 70.45%
# 2026-07-02 07:03:24,114 - Train - INFO - 当前学习率: 0.00000345
# 2026-07-02 07:03:24,114 - Train - INFO -
# Epoch [53/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.45it/s]
# 2026-07-02 07:04:48,620 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8386
# 2026-07-02 07:04:48,632 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8386
# 2026-07-02 07:04:48,633 - Train - INFO - 👉 混淆矩阵: [类0: 42, 误判1: 10] | [漏判1: 12, 类1: 18]
# 2026-07-02 07:04:48,634 - Train - INFO - 🏆 真实指标: ACC: 73.17% | Precision: 64.29% | SEN: 60.00% | SPE: 80.77% | F1: 62.07% | AUC: 70.06%
# 2026-07-02 07:04:48,636 - Train - INFO - 训练损失: 0.6003 | 训练准确率: 55.03%
# 2026-07-02 07:04:48,637 - Train - INFO - 验证损失: 0.7941 | 验证准确率: 73.17% | AUC: 70.06%
# 2026-07-02 07:04:48,638 - Train - INFO - 当前学习率: 0.00000324
# 2026-07-02 07:04:48,638 - Train - INFO -
# Epoch [54/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.21it/s]
# 2026-07-02 07:06:16,415 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7892
# 2026-07-02 07:06:16,424 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7892
# 2026-07-02 07:06:16,425 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 12, 类1: 18]
# 2026-07-02 07:06:16,425 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.07% | SEN: 60.00% | SPE: 78.85% | F1: 61.02% | AUC: 70.19%
# 2026-07-02 07:06:16,427 - Train - INFO - 训练损失: 0.6470 | 训练准确率: 51.98%
# 2026-07-02 07:06:16,428 - Train - INFO - 验证损失: 0.7112 | 验证准确率: 71.95% | AUC: 70.19%
# 2026-07-02 07:06:16,428 - Train - INFO - 当前学习率: 0.00000303
# 2026-07-02 07:06:16,429 - Train - INFO -
# Epoch [55/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-07-02 07:07:42,044 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8631
# 2026-07-02 07:07:42,063 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8631
# 2026-07-02 07:07:42,065 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 12, 类1: 18]
# 2026-07-02 07:07:42,067 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.07% | SEN: 60.00% | SPE: 78.85% | F1: 61.02% | AUC: 70.00%
# 2026-07-02 07:07:42,070 - Train - INFO - 训练损失: 0.6137 | 训练准确率: 55.18%
# 2026-07-02 07:07:42,071 - Train - INFO - 验证损失: 0.8370 | 验证准确率: 71.95% | AUC: 70.00%
# 2026-07-02 07:07:42,072 - Train - INFO - 当前学习率: 0.00000283
# 2026-07-02 07:07:42,074 - Train - INFO -
# Epoch [56/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.29it/s]
# 2026-07-02 07:09:08,278 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8160
# 2026-07-02 07:09:08,288 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8160
# 2026-07-02 07:09:08,288 - Train - INFO - 👉 混淆矩阵: [类0: 40, 误判1: 12] | [漏判1: 12, 类1: 18]
# 2026-07-02 07:09:08,289 - Train - INFO - 🏆 真实指标: ACC: 70.73% | Precision: 60.00% | SEN: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 69.29%
# 2026-07-02 07:09:08,291 - Train - INFO - 训练损失: 0.6250 | 训练准确率: 56.86%
# 2026-07-02 07:09:08,291 - Train - INFO - 验证损失: 0.7599 | 验证准确率: 70.73% | AUC: 69.29%
# 2026-07-02 07:09:08,292 - Train - INFO - 当前学习率: 0.00000263
# 2026-07-02 07:09:08,292 - Train - INFO -
# Epoch [57/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-07-02 07:10:33,822 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8761
# 2026-07-02 07:10:33,833 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8761
# 2026-07-02 07:10:33,834 - Train - INFO - 👉 混淆矩阵: [类0: 42, 误判1: 10] | [漏判1: 13, 类1: 17]
# 2026-07-02 07:10:33,835 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.96% | SEN: 56.67% | SPE: 80.77% | F1: 59.65% | AUC: 69.10%
# 2026-07-02 07:10:33,837 - Train - INFO - 训练损失: 0.6194 | 训练准确率: 53.20%
# 2026-07-02 07:10:33,837 - Train - INFO - 验证损失: 0.8932 | 验证准确率: 71.95% | AUC: 69.10%
# 2026-07-02 07:10:33,838 - Train - INFO - 当前学习率: 0.00000244
# 2026-07-02 07:10:33,839 - Train - INFO -
# Epoch [58/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.23it/s]
# 2026-07-02 07:12:02,542 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7333
# 2026-07-02 07:12:02,552 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7333
# 2026-07-02 07:12:02,554 - Train - INFO - 👉 混淆矩阵: [类0: 45, 误判1: 7] | [漏判1: 16, 类1: 14]
# 2026-07-02 07:12:02,555 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 66.67% | SEN: 46.67% | SPE: 86.54% | F1: 54.90% | AUC: 68.72%
# 2026-07-02 07:12:02,557 - Train - INFO - 训练损失: 0.6598 | 训练准确率: 53.05%
# 2026-07-02 07:12:02,558 - Train - INFO - 验证损失: 0.6482 | 验证准确率: 71.95% | AUC: 68.72%
# 2026-07-02 07:12:02,559 - Train - INFO - 当前学习率: 0.00000225
# 2026-07-02 07:12:02,560 - Train - INFO -
# Epoch [59/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-07-02 07:13:27,386 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8080
# 2026-07-02 07:13:27,397 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8080
# 2026-07-02 07:13:27,398 - Train - INFO - 👉 混淆矩阵: [类0: 42, 误判1: 10] | [漏判1: 13, 类1: 17]
# 2026-07-02 07:13:27,399 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.96% | SEN: 56.67% | SPE: 80.77% | F1: 59.65% | AUC: 69.23%
# 2026-07-02 07:13:27,401 - Train - INFO - 训练损失: 0.6500 | 训练准确率: 54.57%
# 2026-07-02 07:13:27,402 - Train - INFO - 验证损失: 0.7281 | 验证准确率: 71.95% | AUC: 69.23%
# 2026-07-02 07:13:27,403 - Train - INFO - 当前学习率: 0.00000206
# 2026-07-02 07:13:27,404 - Train - INFO -
# Epoch [60/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.24it/s]
# 2026-07-02 07:14:55,392 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8530
# 2026-07-02 07:14:55,404 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8530
# 2026-07-02 07:14:55,404 - Train - INFO - 👉 混淆矩阵: [类0: 40, 误判1: 12] | [漏判1: 12, 类1: 18]
# 2026-07-02 07:14:55,405 - Train - INFO - 🏆 真实指标: ACC: 70.73% | Precision: 60.00% | SEN: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 69.87%
# 2026-07-02 07:14:55,407 - Train - INFO - 训练损失: 0.6177 | 训练准确率: 54.57%
# 2026-07-02 07:14:55,407 - Train - INFO - 验证损失: 0.8404 | 验证准确率: 70.73% | AUC: 69.87%
# 2026-07-02 07:14:55,408 - Train - INFO - 当前学习率: 0.00000188
# 2026-07-02 07:14:55,409 - Train - INFO -
# Epoch [61/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.30it/s]
# 2026-07-02 07:16:22,803 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8439
# 2026-07-02 07:16:22,828 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8439
# 2026-07-02 07:16:22,829 - Train - INFO - 👉 混淆矩阵: [类0: 38, 误判1: 14] | [漏判1: 11, 类1: 19]
# 2026-07-02 07:16:22,831 - Train - INFO - 🏆 真实指标: ACC: 69.51% | Precision: 57.58% | SEN: 63.33% | SPE: 73.08% | F1: 60.32% | AUC: 69.94%
# 2026-07-02 07:16:22,833 - Train - INFO - 训练损失: 0.6016 | 训练准确率: 53.20%
# 2026-07-02 07:16:22,835 - Train - INFO - 验证损失: 0.8204 | 验证准确率: 69.51% | AUC: 69.94%
# 2026-07-02 07:16:22,836 - Train - INFO - 当前学习率: 0.00000171
# 2026-07-02 07:16:22,836 - Train - INFO -
# Epoch [62/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.46it/s]
# 2026-07-02 07:17:47,038 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.7983
# 2026-07-02 07:17:47,049 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.7983
# 2026-07-02 07:17:47,050 - Train - INFO - 👉 混淆矩阵: [类0: 41, 误判1: 11] | [漏判1: 12, 类1: 18]
# 2026-07-02 07:17:47,052 - Train - INFO - 🏆 真实指标: ACC: 71.95% | Precision: 62.07% | SEN: 60.00% | SPE: 78.85% | F1: 61.02% | AUC: 69.68%
# 2026-07-02 07:17:47,054 - Train - INFO - 训练损失: 0.6198 | 训练准确率: 54.27%
# 2026-07-02 07:17:47,055 - Train - INFO - 验证损失: 0.7165 | 验证准确率: 71.95% | AUC: 69.68%
# 2026-07-02 07:17:47,056 - Train - INFO - 当前学习率: 0.00000154
# 2026-07-02 07:17:47,056 - Train - INFO -
# Epoch [63/80] - Model: APM_Former
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.24it/s]
# 2026-07-02 07:19:14,333 - Train - INFO - ⚠️ [未达F1约束，退化为传统平衡] 最佳动态阈值: 0.8404
# 2026-07-02 07:19:14,345 - Train - INFO - 💡 [APM_Former] 动态最佳判定阈值: 0.8404
# 2026-07-02 07:19:14,347 - Train - INFO - 👉 混淆矩阵: [类0: 38, 误判1: 14] | [漏判1: 11, 类1: 19]
# 2026-07-02 07:19:14,348 - Train - INFO - 🏆 真实指标: ACC: 69.51% | Precision: 57.58% | SEN: 63.33% | SPE: 73.08% | F1: 60.32% | AUC: 69.94%
# 2026-07-02 07:19:14,349 - Train - INFO - 训练损失: 0.5564 | 训练准确率: 56.71%
# 2026-07-02 07:19:14,351 - Train - INFO - 验证损失: 0.8167 | 验证准确率: 69.51% | AUC: 69.94%
# 2026-07-02 07:19:14,352 - Train - INFO - 当前学习率: 0.00000139
# 2026-07-02 07:19:14,353 - Train - INFO -
# 🛑 已经连续 30 轮没有刷新最高纪录，触发早停机制！
# 2026-07-02 07:19:14,354 - Train - INFO - 🛑 APM_Former 的训练提前结束，防止过拟合。
# 2026-07-02 07:19:14,355 - Train - INFO -
# 🎉 所有训练流程彻底完成！
# 2026-07-02 07:19:14,356 - Train - INFO - 🏆 APM_Former 最终锁定的最佳真实验证准确率: 78.05%
