# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 71.95% 74.39%
# seed 3407 71.95% 75.61%
# seed 1234 73.17% 69.51%
# seed 98 71.95% 73.17%
# seed 20  69.51%
# seed 1024

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
UNFREEZE_EPOCH = 5  # 设定前 5 个 epoch 为阶段一
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 50
GRADIENT_ACCUMULATION_STEPS = 1
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SAVE_PATH = "checkpoints/best_mci_3407model.pth"
PRETRAINED_SWIN_PATH = "checkpoints/model_swinvit.pt"
SEED = 3407

set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-05-26 03:48:52,357 - Train - INFO - ==================================================
# 2026-05-26 03:48:52,359 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-05-26 03:48:52,360 - Train - INFO - ==================================================
# 2026-05-26 03:48:52,362 - Train - INFO - ▶ 随机种子 (SEED): 3407
# 2026-05-26 03:48:52,363 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-05-26 03:48:52,364 - Train - INFO - ▶ 预热轮数 (Warmup Epochs): 5
# 2026-05-26 03:48:52,366 - Train - INFO - ▶ 批次大小 (Batch Size): 2
# 2026-05-26 03:48:52,367 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-05-26 03:48:52,369 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-05-26 03:48:52,370 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-05-26 03:48:52,371 - Train - INFO - ==================================================
# 2026-05-26 03:48:52,373 - Train - INFO - 训练设备: cuda
# 2026-05-26 03:48:52,374 - Train - INFO - 批次大小: 2
# 2026-05-26 03:48:52,376 - Train - INFO - 总轮数: 50

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS,
    use_sampler=False
)
# Out:
# 2026-05-26 03:48:52,427 - Train - INFO - 正在加载数据集...
# 2026-05-26 03:48:52,439 - utils.dataset - INFO - ✅ 成功加载 82 个样本
# 2026-05-26 03:48:52,441 - utils.dataset - INFO - 🧪 启用【原生数据分布 (Shuffle) + 基础增强】策略
# 2026-05-26 03:48:52,481 - utils.dataset - INFO - ✅ 成功加载 656 个样本
# 2026-05-26 03:48:52,482 - utils.dataset - INFO - 训练集批次: 328，验证集批次: 41

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model = APM_Former_ImageOnly(
    img_size=TRAIN_IMG_SIZE,
    in_channels=1,
    num_classes=NUM_CLASSES,
    feature_size=FEATURE_SIZE,
    guide_channels=GUIDE_CHANNELS,
    pretrained_swin_path=PRETRAINED_SWIN_PATH # 传入刚刚下载的权重
).to(DEVICE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-05-26 03:48:52,528 - Train - INFO - 初始化 APM-Former 模型...
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-05-26 03:48:53,929 - Train - INFO - 模型总参数量: 16.32 M

# %%
# 5. 损失函数 + 两阶段优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR

# ==========================================
# 损失函数 (保持你原来的完美配置不变)
# ==========================================
# weights = torch.tensor([1.0, 1.755]).to(DEVICE) 
weights = torch.tensor([1.0, 2.5]).to(DEVICE)
criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)

# ==========================================
# 两阶段训练：阶段一 (冻结主干)
# ==========================================

# 1. 冻结 Swin 主干网络
logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
for name, param in model.named_parameters():
    if "swin_backbone" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

# 2. 定义优化器：极其重要！这里加了 filter，只把没冻结的参数交给优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# 3. 阶段一的调度器：不需要预热，直接用 5 个 epoch 的余弦退火
scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
# Out:
# 2026-05-26 03:48:53,980 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 对比实验：增加TV Loss
def total_variation_loss_3d(displacement_field):
    """
    计算 3D 形变场的 TV Loss，促使相邻像素的偏移方向和幅度保持平滑
    displacement_field shape: (Batch_size, 3, Depth, Height, Width)
    """
    # 计算三个空间维度的梯度（相邻体素的差值绝对值）
    d_diff = torch.abs(displacement_field[:, :, 1:, :, :] - displacement_field[:, :, :-1, :, :])
    h_diff = torch.abs(displacement_field[:, :, :, 1:, :] - displacement_field[:, :, :, :-1, :])
    w_diff = torch.abs(displacement_field[:, :, :, :, 1:] - displacement_field[:, :, :, :, :-1])
    
    # 将三个方向的平滑度误差求平均并相加
    tv_loss = torch.mean(d_diff) + torch.mean(h_diff) + torch.mean(w_diff)
    return tv_loss

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0
    tv_weight = 1e-3  # 初始建议给一个较小的值，比如 0.001

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _, displacement_field = model(images)
        cls_loss = criterion(logits, labels.unsqueeze(1))
        # 增加tv_loss
        tv_loss = total_variation_loss_3d(displacement_field)

        loss = cls_loss + tv_loss *tv_weight

        loss = loss / accum_steps

        loss.backward()
        # 👇 就在 optimizer.step() 之前，加入这行“梯度裁剪”代码！
        # max_norm=1.0 或 2.0 是最常用的安全值
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc

from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    # correct = 0
    # total = 0
    all_preds = []
    all_labels = []
    all_probs = []  # 🌟 新增：专门用于收集预测为 pMCI 的概率，计算 AUC 必须用

    for images, labels in loader: 
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1)) # 如果用的是交叉熵，这里不用 unsqueeze

        total_loss += loss.item()
        
        # 获取预测类别 (0 或 1)
        preds = torch.argmax(logits, dim=1)
        
        # 🌟 获取预测为类别 1 (pMCI) 的概率
        probs = F.softmax(logits, dim=1)[:, 1] 
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    # ==========================
    # 🌟 计算所有医学黄金指标
    # ==========================
    acc = accuracy_score(all_labels, all_preds) * 100
    precision = precision_score(all_labels, all_preds, pos_label=1, zero_division=0) * 100
    sen = recall_score(all_labels, all_preds, pos_label=1) * 100  # Sensitivity / Recall
    spe = recall_score(all_labels, all_preds, pos_label=0) * 100  # Specificity (反向召回)
    f1 = f1_score(all_labels, all_preds, pos_label=1,zero_division=0) * 100
    
    # 计算 AUC (注意：有些 batch 如果只有一个类别会报错，这里做了容错)
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    
    # 打印超级豪华版日志
    logger.info(f"👉 混淆矩阵: [类0正确: {cm[0][0]}, 误判为类1: {cm[0][1]}] | [类1漏判: {cm[1][0]}, 类1正确: {cm[1][1]}]")
    logger.info(f"🏆 评估指标: ACC: {acc:.2f}% | Precision: {precision:.2f}% | SEN/Recall: {sen:.2f}% | SPE: {spe:.2f}% | F1: {f1:.2f}% | AUC: {auc:.2f}%")
    return avg_loss, acc, auc

# %%
# 7. 主训练循环
best_val_acc = 0.0
logger.info("=" * 50)
logger.info("开始训练！")
logger.info("=" * 50)

for epoch in range(NUM_EPOCHS):
    # 👇 ================= 新增：解冻机关 ================= 👇
    if epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 重新定义优化器（包含主干网络），并大幅降低学习率来保护老专家！
        # 这里用 1e-4 或 5e-5 进行微调最合适
        optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    val_loss, val_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    scheduler.step()

    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {val_acc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), SAVE_PATH)
        logger.info(f"✅ 最佳模型已保存！最佳验证准确率: {best_val_acc:.2f}%")

logger.info("\n🎉 训练完成！")
logger.info(f"最终最佳验证准确率: {best_val_acc:.2f}%")
# Out:
# 2026-05-26 03:48:54,119 - Train - INFO - ==================================================
# 2026-05-26 03:48:54,120 - Train - INFO - 开始训练！
# 2026-05-26 03:48:54,122 - Train - INFO - ==================================================
# 2026-05-26 03:48:54,125 - Train - INFO -
# Epoch [1/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-05-26 03:50:19,807 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 03:50:19,810 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 50.77%
# 2026-05-26 03:50:19,811 - Train - INFO - 训练损失: 0.2992 | 训练准确率: 61.43%
# 2026-05-26 03:50:19,813 - Train - INFO - 验证损失: 0.2899 | 验证准确率: 63.41%
# 2026-05-26 03:50:19,814 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-26 03:50:21,690 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 63.41%
# 2026-05-26 03:50:21,693 - Train - INFO -
# Epoch [2/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.30it/s]
# 2026-05-26 03:51:47,519 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 03:51:47,520 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 54.74%
# 2026-05-26 03:51:47,522 - Train - INFO - 训练损失: 0.2956 | 训练准确率: 63.72%
# 2026-05-26 03:51:47,523 - Train - INFO - 验证损失: 0.2904 | 验证准确率: 63.41%
# 2026-05-26 03:51:47,524 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-26 03:51:47,525 - Train - INFO -
# Epoch [3/50]
# 训练中: 100%|██████████| 328/328 [01:12<00:00,  4.51it/s]
# 2026-05-26 03:53:09,936 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 03:53:09,939 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 57.05%
# 2026-05-26 03:53:09,940 - Train - INFO - 训练损失: 0.2910 | 训练准确率: 63.72%
# 2026-05-26 03:53:09,941 - Train - INFO - 验证损失: 0.2892 | 验证准确率: 63.41%
# 2026-05-26 03:53:09,942 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-26 03:53:09,943 - Train - INFO -
# Epoch [4/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-05-26 03:54:35,784 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 03:54:35,788 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 59.01%
# 2026-05-26 03:54:35,789 - Train - INFO - 训练损失: 0.2930 | 训练准确率: 63.72%
# 2026-05-26 03:54:35,790 - Train - INFO - 验证损失: 0.2894 | 验证准确率: 63.41%
# 2026-05-26 03:54:35,791 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-26 03:54:35,792 - Train - INFO -
# Epoch [5/50]
# 训练中: 100%|██████████| 328/328 [01:12<00:00,  4.50it/s]
# 2026-05-26 03:55:59,022 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 03:55:59,024 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 59.23%
# 2026-05-26 03:55:59,026 - Train - INFO - 训练损失: 0.2905 | 训练准确率: 63.72%
# 2026-05-26 03:55:59,027 - Train - INFO - 验证损失: 0.2893 | 验证准确率: 63.41%
# 2026-05-26 03:55:59,027 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-26 03:55:59,028 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-26 03:55:59,029 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！
# 2026-05-26 03:55:59,030 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-26 03:55:59,033 - Train - INFO -
# Epoch [6/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.28it/s]
# 2026-05-26 03:57:25,309 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 03:57:25,311 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 51.99%
# 2026-05-26 03:57:25,313 - Train - INFO - 训练损失: 0.3044 | 训练准确率: 63.41%
# 2026-05-26 03:57:25,314 - Train - INFO - 验证损失: 0.2919 | 验证准确率: 63.41%
# 2026-05-26 03:57:25,315 - Train - INFO - 当前学习率: 0.00029963
# 2026-05-26 03:57:25,315 - Train - INFO -
# Epoch [7/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.30it/s]
# 2026-05-26 03:58:51,633 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 03:58:51,635 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 53.08%
# 2026-05-26 03:58:51,637 - Train - INFO - 训练损失: 0.2942 | 训练准确率: 63.72%
# 2026-05-26 03:58:51,637 - Train - INFO - 验证损失: 0.2908 | 验证准确率: 63.41%
# 2026-05-26 03:58:51,638 - Train - INFO - 当前学习率: 0.00029854
# 2026-05-26 03:58:51,639 - Train - INFO -
# Epoch [8/50]
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.44it/s]
# 2026-05-26 04:00:14,904 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:00:14,906 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 54.87%
# 2026-05-26 04:00:14,907 - Train - INFO - 训练损失: 0.2932 | 训练准确率: 63.72%
# 2026-05-26 04:00:14,908 - Train - INFO - 验证损失: 0.2889 | 验证准确率: 63.41%
# 2026-05-26 04:00:14,909 - Train - INFO - 当前学习率: 0.00029672
# 2026-05-26 04:00:14,910 - Train - INFO -
# Epoch [9/50]
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.46it/s]
# 2026-05-26 04:01:38,322 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:01:38,324 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 54.49%
# 2026-05-26 04:01:38,327 - Train - INFO - 训练损失: 0.2918 | 训练准确率: 63.72%
# 2026-05-26 04:01:38,328 - Train - INFO - 验证损失: 0.2907 | 验证准确率: 63.41%
# 2026-05-26 04:01:38,329 - Train - INFO - 当前学习率: 0.00029419
# 2026-05-26 04:01:38,330 - Train - INFO -
# Epoch [10/50]
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.46it/s]
# 2026-05-26 04:03:03,107 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:03:03,109 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 52.69%
# 2026-05-26 04:03:03,111 - Train - INFO - 训练损失: 0.2913 | 训练准确率: 63.72%
# 2026-05-26 04:03:03,112 - Train - INFO - 验证损失: 0.2917 | 验证准确率: 63.41%
# 2026-05-26 04:03:03,113 - Train - INFO - 当前学习率: 0.00029095
# 2026-05-26 04:03:03,114 - Train - INFO -
# Epoch [11/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.43it/s]
# 2026-05-26 04:04:27,374 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:04:27,376 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 53.27%
# 2026-05-26 04:04:27,378 - Train - INFO - 训练损失: 0.2910 | 训练准确率: 63.41%
# 2026-05-26 04:04:27,378 - Train - INFO - 验证损失: 0.2892 | 验证准确率: 63.41%
# 2026-05-26 04:04:27,379 - Train - INFO - 当前学习率: 0.00028703
# 2026-05-26 04:04:27,380 - Train - INFO -
# Epoch [12/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-05-26 04:05:51,782 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:05:51,784 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 56.35%
# 2026-05-26 04:05:51,786 - Train - INFO - 训练损失: 0.2881 | 训练准确率: 63.72%
# 2026-05-26 04:05:51,787 - Train - INFO - 验证损失: 0.2884 | 验证准确率: 63.41%
# 2026-05-26 04:05:51,788 - Train - INFO - 当前学习率: 0.00028244
# 2026-05-26 04:05:51,789 - Train - INFO -
# Epoch [13/50]
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.45it/s]
# 2026-05-26 04:07:15,836 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:07:15,839 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 60.19%
# 2026-05-26 04:07:15,840 - Train - INFO - 训练损失: 0.2896 | 训练准确率: 63.72%
# 2026-05-26 04:07:15,841 - Train - INFO - 验证损失: 0.2882 | 验证准确率: 63.41%
# 2026-05-26 04:07:15,842 - Train - INFO - 当前学习率: 0.00027721
# 2026-05-26 04:07:15,842 - Train - INFO -
# Epoch [14/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.36it/s]
# 2026-05-26 04:08:40,772 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:08:40,774 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.05%
# 2026-05-26 04:08:40,776 - Train - INFO - 训练损失: 0.2891 | 训练准确率: 63.72%
# 2026-05-26 04:08:40,777 - Train - INFO - 验证损失: 0.2883 | 验证准确率: 63.41%
# 2026-05-26 04:08:40,778 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-26 04:08:40,779 - Train - INFO -
# Epoch [15/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.31it/s]
# 2026-05-26 04:10:06,840 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:10:06,842 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.82%
# 2026-05-26 04:10:06,843 - Train - INFO - 训练损失: 0.2887 | 训练准确率: 62.96%
# 2026-05-26 04:10:06,844 - Train - INFO - 验证损失: 0.2877 | 验证准确率: 63.41%
# 2026-05-26 04:10:06,845 - Train - INFO - 当前学习率: 0.00026491
# 2026-05-26 04:10:06,845 - Train - INFO -
# Epoch [16/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.31it/s]
# 2026-05-26 04:11:33,442 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:11:33,444 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 68.53%
# 2026-05-26 04:11:33,446 - Train - INFO - 训练损失: 0.2869 | 训练准确率: 63.72%
# 2026-05-26 04:11:33,447 - Train - INFO - 验证损失: 0.2847 | 验证准确率: 63.41%
# 2026-05-26 04:11:33,448 - Train - INFO - 当前学习率: 0.00025790
# 2026-05-26 04:11:33,449 - Train - INFO -
# Epoch [17/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.34it/s]
# 2026-05-26 04:12:59,439 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:12:59,441 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 68.72%
# 2026-05-26 04:12:59,442 - Train - INFO - 训练损失: 0.2877 | 训练准确率: 63.72%
# 2026-05-26 04:12:59,443 - Train - INFO - 验证损失: 0.2846 | 验证准确率: 63.41%
# 2026-05-26 04:12:59,444 - Train - INFO - 当前学习率: 0.00025037
# 2026-05-26 04:12:59,444 - Train - INFO -
# Epoch [18/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-05-26 04:14:24,777 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:14:24,779 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.15%
# 2026-05-26 04:14:24,780 - Train - INFO - 训练损失: 0.2844 | 训练准确率: 63.72%
# 2026-05-26 04:14:24,781 - Train - INFO - 验证损失: 0.2871 | 验证准确率: 63.41%
# 2026-05-26 04:14:24,782 - Train - INFO - 当前学习率: 0.00024235
# 2026-05-26 04:14:24,783 - Train - INFO -
# Epoch [19/50]
# 训练中: 100%|██████████| 328/328 [01:13<00:00,  4.46it/s]
# 2026-05-26 04:15:48,236 - Train - INFO - 👉 混淆矩阵: [类0正确: 52, 误判为类1: 0] | [类1漏判: 30, 类1正确: 0]
# 2026-05-26 04:15:48,238 - Train - INFO - 🏆 评估指标: ACC: 63.41% | Precision: 0.00% | SEN/Recall: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 71.79%
# 2026-05-26 04:15:48,239 - Train - INFO - 训练损失: 0.2930 | 训练准确率: 64.18%
# 2026-05-26 04:15:48,240 - Train - INFO - 验证损失: 0.3262 | 验证准确率: 63.41%
# 2026-05-26 04:15:48,241 - Train - INFO - 当前学习率: 0.00023388
# 2026-05-26 04:15:48,242 - Train - INFO -
# Epoch [20/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.43it/s]
# 2026-05-26 04:17:12,253 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:17:12,256 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 56.25% | SEN/Recall: 60.00% | SPE: 73.08% | F1: 58.06% | AUC: 73.59%
# 2026-05-26 04:17:12,258 - Train - INFO - 训练损失: 0.2836 | 训练准确率: 64.48%
# 2026-05-26 04:17:12,259 - Train - INFO - 验证损失: 0.2611 | 验证准确率: 68.29%
# 2026-05-26 04:17:12,260 - Train - INFO - 当前学习率: 0.00022500
# 2026-05-26 04:17:13,396 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 68.29%
# 2026-05-26 04:17:13,398 - Train - INFO -
# Epoch [21/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.36it/s]
# 2026-05-26 04:18:38,351 - Train - INFO - 👉 混淆矩阵: [类0正确: 51, 误判为类1: 1] | [类1漏判: 27, 类1正确: 3]
# 2026-05-26 04:18:38,354 - Train - INFO - 🏆 评估指标: ACC: 65.85% | Precision: 75.00% | SEN/Recall: 10.00% | SPE: 98.08% | F1: 17.65% | AUC: 73.97%
# 2026-05-26 04:18:38,355 - Train - INFO - 训练损失: 0.2811 | 训练准确率: 67.07%
# 2026-05-26 04:18:38,357 - Train - INFO - 验证损失: 0.3231 | 验证准确率: 65.85%
# 2026-05-26 04:18:38,357 - Train - INFO - 当前学习率: 0.00021576
# 2026-05-26 04:18:38,358 - Train - INFO -
# Epoch [22/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.42it/s]
# 2026-05-26 04:20:03,122 - Train - INFO - 👉 混淆矩阵: [类0正确: 28, 误判为类1: 24] | [类1漏判: 7, 类1正确: 23]
# 2026-05-26 04:20:03,125 - Train - INFO - 🏆 评估指标: ACC: 62.20% | Precision: 48.94% | SEN/Recall: 76.67% | SPE: 53.85% | F1: 59.74% | AUC: 73.78%
# 2026-05-26 04:20:03,127 - Train - INFO - 训练损失: 0.3085 | 训练准确率: 68.29%
# 2026-05-26 04:20:03,128 - Train - INFO - 验证损失: 0.2884 | 验证准确率: 62.20%
# 2026-05-26 04:20:03,129 - Train - INFO - 当前学习率: 0.00020619
# 2026-05-26 04:20:03,130 - Train - INFO -
# Epoch [23/50]
# 训练中: 100%|██████████| 328/328 [01:12<00:00,  4.49it/s]
# 2026-05-26 04:21:26,718 - Train - INFO - 👉 混淆矩阵: [类0正确: 47, 误判为类1: 5] | [类1漏判: 16, 类1正确: 14]
# 2026-05-26 04:21:26,720 - Train - INFO - 🏆 评估指标: ACC: 74.39% | Precision: 73.68% | SEN/Recall: 46.67% | SPE: 90.38% | F1: 57.14% | AUC: 75.32%
# 2026-05-26 04:21:26,722 - Train - INFO - 训练损失: 0.3083 | 训练准确率: 68.75%
# 2026-05-26 04:21:26,723 - Train - INFO - 验证损失: 0.2620 | 验证准确率: 74.39%
# 2026-05-26 04:21:26,724 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-26 04:21:28,123 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 74.39%
# 2026-05-26 04:21:28,124 - Train - INFO -
# Epoch [24/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.36it/s]
# 2026-05-26 04:22:53,070 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:22:53,072 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.45%
# 2026-05-26 04:22:53,073 - Train - INFO - 训练损失: 0.3106 | 训练准确率: 68.45%
# 2026-05-26 04:22:53,075 - Train - INFO - 验证损失: 0.2541 | 验证准确率: 70.73%
# 2026-05-26 04:22:53,077 - Train - INFO - 当前学习率: 0.00018629
# 2026-05-26 04:22:53,078 - Train - INFO -
# Epoch [25/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.42it/s]
# 2026-05-26 04:24:16,794 - Train - INFO - 👉 混淆矩阵: [类0正确: 22, 误判为类1: 30] | [类1漏判: 4, 类1正确: 26]
# 2026-05-26 04:24:16,797 - Train - INFO - 🏆 评估指标: ACC: 58.54% | Precision: 46.43% | SEN/Recall: 86.67% | SPE: 42.31% | F1: 60.47% | AUC: 74.42%
# 2026-05-26 04:24:16,799 - Train - INFO - 训练损失: 0.2762 | 训练准确率: 70.73%
# 2026-05-26 04:24:16,800 - Train - INFO - 验证损失: 0.3533 | 验证准确率: 58.54%
# 2026-05-26 04:24:16,801 - Train - INFO - 当前学习率: 0.00017605
# 2026-05-26 04:24:16,801 - Train - INFO -
# Epoch [26/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-05-26 04:25:42,205 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 04:25:42,208 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.62% | SEN/Recall: 56.67% | SPE: 76.92% | F1: 57.63% | AUC: 75.13%
# 2026-05-26 04:25:42,210 - Train - INFO - 训练损失: 0.2988 | 训练准确率: 70.27%
# 2026-05-26 04:25:42,211 - Train - INFO - 验证损失: 0.2624 | 验证准确率: 69.51%
# 2026-05-26 04:25:42,212 - Train - INFO - 当前学习率: 0.00016568
# 2026-05-26 04:25:42,214 - Train - INFO -
# Epoch [27/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.21it/s]
# 2026-05-26 04:27:10,310 - Train - INFO - 👉 混淆矩阵: [类0正确: 41, 误判为类1: 11] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 04:27:10,312 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.71% | SEN/Recall: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 75.06%
# 2026-05-26 04:27:10,313 - Train - INFO - 训练损失: 0.3084 | 训练准确率: 69.05%
# 2026-05-26 04:27:10,314 - Train - INFO - 验证损失: 0.2805 | 验证准确率: 70.73%
# 2026-05-26 04:27:10,315 - Train - INFO - 当前学习率: 0.00015523
# 2026-05-26 04:27:10,316 - Train - INFO -
# Epoch [28/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.22it/s]
# 2026-05-26 04:28:38,081 - Train - INFO - 👉 混淆矩阵: [类0正确: 50, 误判为类1: 2] | [类1漏判: 24, 类1正确: 6]
# 2026-05-26 04:28:38,083 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 75.00% | SEN/Recall: 20.00% | SPE: 96.15% | F1: 31.58% | AUC: 75.45%
# 2026-05-26 04:28:38,084 - Train - INFO - 训练损失: 0.3189 | 训练准确率: 70.27%
# 2026-05-26 04:28:38,085 - Train - INFO - 验证损失: 0.3666 | 验证准确率: 68.29%
# 2026-05-26 04:28:38,086 - Train - INFO - 当前学习率: 0.00014477
# 2026-05-26 04:28:38,087 - Train - INFO -
# Epoch [29/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.33it/s]
# 2026-05-26 04:30:03,549 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 04:30:03,552 - Train - INFO - 🏆 评估指标: ACC: 67.07% | Precision: 54.84% | SEN/Recall: 56.67% | SPE: 73.08% | F1: 55.74% | AUC: 75.38%
# 2026-05-26 04:30:03,553 - Train - INFO - 训练损失: 0.3180 | 训练准确率: 67.53%
# 2026-05-26 04:30:03,554 - Train - INFO - 验证损失: 0.2806 | 验证准确率: 67.07%
# 2026-05-26 04:30:03,555 - Train - INFO - 当前学习率: 0.00013432
# 2026-05-26 04:30:03,556 - Train - INFO -
# Epoch [30/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.37it/s]
# 2026-05-26 04:31:28,631 - Train - INFO - 👉 混淆矩阵: [类0正确: 44, 误判为类1: 8] | [类1漏判: 14, 类1正确: 16]
# 2026-05-26 04:31:28,632 - Train - INFO - 🏆 评估指标: ACC: 73.17% | Precision: 66.67% | SEN/Recall: 53.33% | SPE: 84.62% | F1: 59.26% | AUC: 75.19%
# 2026-05-26 04:31:28,633 - Train - INFO - 训练损失: 0.3002 | 训练准确率: 69.36%
# 2026-05-26 04:31:28,634 - Train - INFO - 验证损失: 0.2774 | 验证准确率: 73.17%
# 2026-05-26 04:31:28,635 - Train - INFO - 当前学习率: 0.00012395
# 2026-05-26 04:31:28,636 - Train - INFO -
# Epoch [31/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.37it/s]
# 2026-05-26 04:32:52,955 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 04:32:52,958 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.62% | SEN/Recall: 56.67% | SPE: 76.92% | F1: 57.63% | AUC: 74.68%
# 2026-05-26 04:32:52,960 - Train - INFO - 训练损失: 0.3116 | 训练准确率: 69.82%
# 2026-05-26 04:32:52,961 - Train - INFO - 验证损失: 0.2794 | 验证准确率: 69.51%
# 2026-05-26 04:32:52,961 - Train - INFO - 当前学习率: 0.00011371
# 2026-05-26 04:32:52,963 - Train - INFO -
# Epoch [32/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.29it/s]
# 2026-05-26 04:34:19,372 - Train - INFO - 👉 混淆矩阵: [类0正确: 35, 误判为类1: 17] | [类1漏判: 8, 类1正确: 22]
# 2026-05-26 04:34:19,374 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 56.41% | SEN/Recall: 73.33% | SPE: 67.31% | F1: 63.77% | AUC: 75.26%
# 2026-05-26 04:34:19,376 - Train - INFO - 训练损失: 0.3179 | 训练准确率: 69.66%
# 2026-05-26 04:34:19,377 - Train - INFO - 验证损失: 0.3041 | 验证准确率: 69.51%
# 2026-05-26 04:34:19,377 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-26 04:34:19,378 - Train - INFO -
# Epoch [33/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-05-26 04:35:44,648 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:35:44,650 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.00%
# 2026-05-26 04:35:44,652 - Train - INFO - 训练损失: 0.3063 | 训练准确率: 71.04%
# 2026-05-26 04:35:44,653 - Train - INFO - 验证损失: 0.3123 | 验证准确率: 70.73%
# 2026-05-26 04:35:44,655 - Train - INFO - 当前学习率: 0.00009381
# 2026-05-26 04:35:44,655 - Train - INFO -
# Epoch [34/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.35it/s]
# 2026-05-26 04:37:10,362 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:37:10,365 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.06%
# 2026-05-26 04:37:10,366 - Train - INFO - 训练损失: 0.3349 | 训练准确率: 69.82%
# 2026-05-26 04:37:10,367 - Train - INFO - 验证损失: 0.3041 | 验证准确率: 70.73%
# 2026-05-26 04:37:10,368 - Train - INFO - 当前学习率: 0.00008424
# 2026-05-26 04:37:10,368 - Train - INFO -
# Epoch [35/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-05-26 04:38:34,528 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:38:34,530 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 56.25% | SEN/Recall: 60.00% | SPE: 73.08% | F1: 58.06% | AUC: 74.87%
# 2026-05-26 04:38:34,532 - Train - INFO - 训练损失: 0.3111 | 训练准确率: 72.71%
# 2026-05-26 04:38:34,533 - Train - INFO - 验证损失: 0.3116 | 验证准确率: 68.29%
# 2026-05-26 04:38:34,534 - Train - INFO - 当前学习率: 0.00007500
# 2026-05-26 04:38:34,535 - Train - INFO -
# Epoch [36/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.40it/s]
# 2026-05-26 04:39:58,718 - Train - INFO - 👉 混淆矩阵: [类0正确: 47, 误判为类1: 5] | [类1漏判: 15, 类1正确: 15]
# 2026-05-26 04:39:58,721 - Train - INFO - 🏆 评估指标: ACC: 75.61% | Precision: 75.00% | SEN/Recall: 50.00% | SPE: 90.38% | F1: 60.00% | AUC: 74.62%
# 2026-05-26 04:39:58,722 - Train - INFO - 训练损失: 0.3127 | 训练准确率: 68.60%
# 2026-05-26 04:39:58,724 - Train - INFO - 验证损失: 0.3096 | 验证准确率: 75.61%
# 2026-05-26 04:39:58,724 - Train - INFO - 当前学习率: 0.00006612
# 2026-05-26 04:39:59,968 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 75.61%
# 2026-05-26 04:39:59,969 - Train - INFO -
# Epoch [37/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.22it/s]
# 2026-05-26 04:41:27,310 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:41:27,313 - Train - INFO - 🏆 评估指标: ACC: 69.51% | Precision: 58.06% | SEN/Recall: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 75.32%
# 2026-05-26 04:41:27,314 - Train - INFO - 训练损失: 0.3094 | 训练准确率: 70.12%
# 2026-05-26 04:41:27,315 - Train - INFO - 验证损失: 0.2921 | 验证准确率: 69.51%
# 2026-05-26 04:41:27,316 - Train - INFO - 当前学习率: 0.00005765
# 2026-05-26 04:41:27,317 - Train - INFO -
# Epoch [38/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.29it/s]
# 2026-05-26 04:42:53,765 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:42:53,767 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 56.25% | SEN/Recall: 60.00% | SPE: 73.08% | F1: 58.06% | AUC: 75.51%
# 2026-05-26 04:42:53,769 - Train - INFO - 训练损失: 0.3240 | 训练准确率: 70.43%
# 2026-05-26 04:42:53,770 - Train - INFO - 验证损失: 0.2949 | 验证准确率: 68.29%
# 2026-05-26 04:42:53,771 - Train - INFO - 当前学习率: 0.00004963
# 2026-05-26 04:42:53,771 - Train - INFO -
# Epoch [39/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.34it/s]
# 2026-05-26 04:44:19,280 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:44:19,283 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 56.25% | SEN/Recall: 60.00% | SPE: 73.08% | F1: 58.06% | AUC: 75.83%
# 2026-05-26 04:44:19,284 - Train - INFO - 训练损失: 0.3190 | 训练准确率: 71.34%
# 2026-05-26 04:44:19,286 - Train - INFO - 验证损失: 0.3016 | 验证准确率: 68.29%
# 2026-05-26 04:44:19,287 - Train - INFO - 当前学习率: 0.00004210
# 2026-05-26 04:44:19,289 - Train - INFO -
# Epoch [40/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.38it/s]
# 2026-05-26 04:45:44,939 - Train - INFO - 👉 混淆矩阵: [类0正确: 39, 误判为类1: 13] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 04:45:44,942 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 56.67% | SEN/Recall: 56.67% | SPE: 75.00% | F1: 56.67% | AUC: 75.58%
# 2026-05-26 04:45:44,944 - Train - INFO - 训练损失: 0.3104 | 训练准确率: 70.27%
# 2026-05-26 04:45:44,946 - Train - INFO - 验证损失: 0.3064 | 验证准确率: 68.29%
# 2026-05-26 04:45:44,947 - Train - INFO - 当前学习率: 0.00003509
# 2026-05-26 04:45:44,948 - Train - INFO -
# Epoch [41/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.30it/s]
# 2026-05-26 04:47:11,722 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:47:11,724 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.38%
# 2026-05-26 04:47:11,726 - Train - INFO - 训练损失: 0.3243 | 训练准确率: 71.49%
# 2026-05-26 04:47:11,726 - Train - INFO - 验证损失: 0.3071 | 验证准确率: 70.73%
# 2026-05-26 04:47:11,727 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-26 04:47:11,728 - Train - INFO -
# Epoch [42/50]
# 训练中: 100%|██████████| 328/328 [01:12<00:00,  4.49it/s]
# 2026-05-26 04:48:34,761 - Train - INFO - 👉 混淆矩阵: [类0正确: 44, 误判为类1: 8] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 04:48:34,763 - Train - INFO - 🏆 评估指标: ACC: 74.39% | Precision: 68.00% | SEN/Recall: 56.67% | SPE: 84.62% | F1: 61.82% | AUC: 75.45%
# 2026-05-26 04:48:34,765 - Train - INFO - 训练损失: 0.3012 | 训练准确率: 72.26%
# 2026-05-26 04:48:34,766 - Train - INFO - 验证损失: 0.3126 | 验证准确率: 74.39%
# 2026-05-26 04:48:34,767 - Train - INFO - 当前学习率: 0.00002279
# 2026-05-26 04:48:34,768 - Train - INFO -
# Epoch [43/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.29it/s]
# 2026-05-26 04:50:01,658 - Train - INFO - 👉 混淆矩阵: [类0正确: 42, 误判为类1: 10] | [类1漏判: 13, 类1正确: 17]
# 2026-05-26 04:50:01,660 - Train - INFO - 🏆 评估指标: ACC: 71.95% | Precision: 62.96% | SEN/Recall: 56.67% | SPE: 80.77% | F1: 59.65% | AUC: 75.51%
# 2026-05-26 04:50:01,662 - Train - INFO - 训练损失: 0.3061 | 训练准确率: 71.80%
# 2026-05-26 04:50:01,663 - Train - INFO - 验证损失: 0.3120 | 验证准确率: 71.95%
# 2026-05-26 04:50:01,663 - Train - INFO - 当前学习率: 0.00001756
# 2026-05-26 04:50:01,664 - Train - INFO -
# Epoch [44/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.36it/s]
# 2026-05-26 04:51:28,057 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:51:28,059 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.38%
# 2026-05-26 04:51:28,061 - Train - INFO - 训练损失: 0.3119 | 训练准确率: 71.65%
# 2026-05-26 04:51:28,062 - Train - INFO - 验证损失: 0.3122 | 验证准确率: 70.73%
# 2026-05-26 04:51:28,062 - Train - INFO - 当前学习率: 0.00001297
# 2026-05-26 04:51:28,063 - Train - INFO -
# Epoch [45/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.22it/s]
# 2026-05-26 04:52:56,276 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:52:56,278 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.38%
# 2026-05-26 04:52:56,280 - Train - INFO - 训练损失: 0.3082 | 训练准确率: 71.95%
# 2026-05-26 04:52:56,281 - Train - INFO - 验证损失: 0.3126 | 验证准确率: 70.73%
# 2026-05-26 04:52:56,281 - Train - INFO - 当前学习率: 0.00000905
# 2026-05-26 04:52:56,282 - Train - INFO -
# Epoch [46/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.29it/s]
# 2026-05-26 04:54:22,826 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:54:22,828 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.32%
# 2026-05-26 04:54:22,830 - Train - INFO - 训练损失: 0.3152 | 训练准确率: 71.49%
# 2026-05-26 04:54:22,831 - Train - INFO - 验证损失: 0.3152 | 验证准确率: 70.73%
# 2026-05-26 04:54:22,832 - Train - INFO - 当前学习率: 0.00000581
# 2026-05-26 04:54:22,833 - Train - INFO -
# Epoch [47/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.36it/s]
# 2026-05-26 04:55:48,035 - Train - INFO - 👉 混淆矩阵: [类0正确: 37, 误判为类1: 15] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:55:48,037 - Train - INFO - 🏆 评估指标: ACC: 67.07% | Precision: 54.55% | SEN/Recall: 60.00% | SPE: 71.15% | F1: 57.14% | AUC: 75.38%
# 2026-05-26 04:55:48,039 - Train - INFO - 训练损失: 0.3176 | 训练准确率: 72.41%
# 2026-05-26 04:55:48,039 - Train - INFO - 验证损失: 0.3178 | 验证准确率: 67.07%
# 2026-05-26 04:55:48,040 - Train - INFO - 当前学习率: 0.00000328
# 2026-05-26 04:55:48,041 - Train - INFO -
# Epoch [48/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-05-26 04:57:12,662 - Train - INFO - 👉 混淆矩阵: [类0正确: 38, 误判为类1: 14] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:57:12,666 - Train - INFO - 🏆 评估指标: ACC: 68.29% | Precision: 56.25% | SEN/Recall: 60.00% | SPE: 73.08% | F1: 58.06% | AUC: 75.38%
# 2026-05-26 04:57:12,667 - Train - INFO - 训练损失: 0.3080 | 训练准确率: 72.26%
# 2026-05-26 04:57:12,669 - Train - INFO - 验证损失: 0.3161 | 验证准确率: 68.29%
# 2026-05-26 04:57:12,670 - Train - INFO - 当前学习率: 0.00000146
# 2026-05-26 04:57:12,671 - Train - INFO -
# Epoch [49/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.43it/s]
# 2026-05-26 04:58:37,555 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 04:58:37,557 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.38%
# 2026-05-26 04:58:37,558 - Train - INFO - 训练损失: 0.2990 | 训练准确率: 73.02%
# 2026-05-26 04:58:37,559 - Train - INFO - 验证损失: 0.3152 | 验证准确率: 70.73%
# 2026-05-26 04:58:37,560 - Train - INFO - 当前学习率: 0.00000037
# 2026-05-26 04:58:37,561 - Train - INFO -
# Epoch [50/50]
# 训练中: 100%|██████████| 328/328 [01:15<00:00,  4.32it/s]
# 2026-05-26 05:00:03,083 - Train - INFO - 👉 混淆矩阵: [类0正确: 40, 误判为类1: 12] | [类1漏判: 12, 类1正确: 18]
# 2026-05-26 05:00:03,085 - Train - INFO - 🏆 评估指标: ACC: 70.73% | Precision: 60.00% | SEN/Recall: 60.00% | SPE: 76.92% | F1: 60.00% | AUC: 75.38%
# 2026-05-26 05:00:03,086 - Train - INFO - 训练损失: 0.3051 | 训练准确率: 71.95%
# 2026-05-26 05:00:03,087 - Train - INFO - 验证损失: 0.3151 | 验证准确率: 70.73%
# 2026-05-26 05:00:03,088 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-26 05:00:03,089 - Train - INFO -
# 🎉 训练完成！
# 2026-05-26 05:00:03,089 - Train - INFO - 最终最佳验证准确率: 75.61%

# %%
# import torch
# import torch.nn.functional as F
# import numpy as np
# import matplotlib.pyplot as plt

# # ==========================================
# # 第一步：加载你跑出 74.39% 的最佳模型权重
# # ==========================================
# print("🔄 正在加载最佳模型权重...")

# # 实例化模型 (确保这里的参数和你跑出最好成绩的那次完全一致)
# # 之前确认过 FEATURE_SIZE 是 24
# vis_model = APM_Former_ImageOnly(
#     feature_size=24,  
#     num_classes=2
# ).to(DEVICE)

# # ⚠️ 注意：把这里的 'best_model.pth' 换成你实际保存的权重文件名！
# # 比如可能是 'checkpoint_epoch_xx.pth'
# checkpoint_path = 'checkpoints/best_3407model2.pth'  
# state_dict = torch.load(checkpoint_path, map_location=DEVICE)
# vis_model.load_state_dict(state_dict)

# vis_model.eval() # 切换到评估模式
# print(f"✅ 成功加载权重: {checkpoint_path}")
# print("-" * 50)


# # ==========================================
# # 第二步：定义并运行可视化探针
# # ==========================================
# @torch.no_grad()
# def visualize_pMCI_attention(model, val_loader, device, num_cases_to_show=3):
#     model.eval()
#     found_cases = 0
    
#     # 解决 matplotlib 中文显示问题
#     # plt.rcParams['font.sans-serif'] = ['SimHei'] 
#     # plt.rcParams['axes.unicode_minus'] = False
    
#     print("🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...\n")
    
#     for images, labels in val_loader:
#         images = images.to(device)
#         labels = labels.to(device)
        
#         logits, _, spatial_attention = model(images)
#         preds = torch.argmax(logits, dim=1)
        
#         # 寻找 True Positives (真实为pMCI，预测也为pMCI)
#         for i in range(len(labels)):
#             if labels[i].item() == 1 and preds[i].item() == 1:
#                 found_cases += 1
                
#                 # 1. 提取原始 3D MRI 图像
#                 img_3d = images[i, 0].cpu().numpy()  
                
#                 # 2. 提取注意力掩码，并插值放大到原始图像大小 (96, 96, 96)
#                 attn_tensor = spatial_attention[i:i+1] 
#                 attn_resized = F.interpolate(attn_tensor, size=img_3d.shape, mode='trilinear', align_corners=False)
#                 attn_3d = attn_resized[0, 0].cpu().numpy()
                
#                 # 3. 智能寻找网络最关注的切片位置
#                 slice_x = np.argmax(np.sum(attn_3d, axis=(1, 2))) 
#                 slice_y = np.argmax(np.sum(attn_3d, axis=(0, 2))) 
#                 slice_z = np.argmax(np.sum(attn_3d, axis=(0, 1))) 
                
#                 # 4. 绘图
#                 fig, axes = plt.subplots(1, 3, figsize=(18, 6))
#                 # 成功识别的pMCI阳性病例  高亮区域为网络空间对齐中点关注区域
#                 fig.suptitle(f"True Positive pMCI Case #{found_cases}\n(Spatial Attention Guided Alignment)", fontsize=18, fontweight='bold', y=1.05)
                
#                 # 矢状面 矢状面切片
#                 axes[0].imshow(img_3d[slice_x, :, :], cmap='gray') 
#                 im = axes[0].imshow(attn_3d[slice_x, :, :], cmap='jet', alpha=0.45) 
#                 axes[0].set_title(f"Sagittal View (Slice {slice_x})", fontsize=14)
#                 axes[0].axis('off')
                
#                 # 冠状面 冠状面切片
#                 axes[1].imshow(img_3d[:, slice_y, :], cmap='gray')
#                 axes[1].imshow(attn_3d[:, slice_y, :], cmap='jet', alpha=0.45)
#                 axes[1].set_title(f"Coronal View (Slice {slice_y})", fontsize=14)
#                 axes[1].axis('off')
                
#                 # 轴状面 轴状面切片
#                 axes[2].imshow(img_3d[:, :, slice_z], cmap='gray')
#                 axes[2].imshow(attn_3d[:, :, slice_z], cmap='jet', alpha=0.45)
#                 axes[2].set_title(f"Axial View (Slice {slice_z})", fontsize=14)
#                 axes[2].axis('off')
                
#                 # 颜色条的标签 解剖引导强度
#                 cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
#                 cbar.set_label('Attention Weight', fontsize=12)
                
#                 plt.show()
                
#                 if found_cases >= num_cases_to_show:
#                     print(f"\n✅ 成功提取 {num_cases_to_show} 组 pMCI 空间注意力图！")
#                     return

#     print(f"\n搜索结束，共找到 {found_cases} 个符合条件的病例。")

# # 执行探针！展示前 5 个最典型的病例
# visualize_pMCI_attention(vis_model, val_loader, DEVICE, num_cases_to_show=5)
