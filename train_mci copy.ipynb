# %%
# %load_ext autoreload
# %autoreload 2
# 1. 导入所有依赖库
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
import numpy as np
import random

# 导入我们的核心模块
from models.apm_former import APM_Former_ImageOnly
from utils.dataset import get_adni_dataloaders
# 修正导入：只导入config里存在的变量
from utils.config import TRAIN_CSV, VAL_CSV, BATCH_SIZE, NUM_WORKERS, TRAIN_IMG_SIZE
from utils.logging_utils import get_logger
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR

import torch.nn.functional as F
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score


# 日志
logger = get_logger("Train")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    # torch.cuda.manual_seed_all(seed)  # 如果用多卡
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False



# seed 42 71.95% 74.39%
# seed 3407 71.95% 75.61%
# seed 1234 73.17% 69.51%
# seed 98 71.95% 73.17%
# seed 20  69.51%
# seed 1024

# %%
# 2. 超参数配置
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
LEARNING_RATE = 3e-4
UNFREEZE_EPOCH = 5  # 设定前 5 个 epoch 为阶段一
WEIGHT_DECAY = 1e-3
NUM_EPOCHS = 50
GRADIENT_ACCUMULATION_STEPS = 1
NUM_CLASSES = 2
FEATURE_SIZE = 24
GUIDE_CHANNELS = 18
SAVE_PATH = "checkpoints/best_3407model2.pth"
PRETRAINED_SWIN_PATH = "checkpoints/model_swinvit.pt"
SEED = 3407

set_seed(SEED)

logger.info("=" * 50)
logger.info("🌟 本次实验配置档案 (Experiment Config) 🌟")
logger.info("=" * 50)
logger.info(f"▶ 随机种子 (SEED): {SEED}")
logger.info(f"▶ 峰值学习率 (LR): {LEARNING_RATE}")
logger.info(f"▶ 预热轮数 (Warmup Epochs): {UNFREEZE_EPOCH}")
logger.info(f"▶ 批次大小 (Batch Size): {BATCH_SIZE}")
logger.info(f"▶ 优化器: AdamW (Weight Decay: {WEIGHT_DECAY})")
logger.info(f"▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)")
logger.info(f"▶ 架构说明: 启用 m_k 调制掩码")
logger.info("=" * 50)

logger.info(f"训练设备: {DEVICE}")
logger.info(f"批次大小: {BATCH_SIZE}")
logger.info(f"总轮数: {NUM_EPOCHS}")
# Out:
# 2026-05-25 14:25:49,170 - Train - INFO - ==================================================
# 2026-05-25 14:25:49,172 - Train - INFO - 🌟 本次实验配置档案 (Experiment Config) 🌟
# 2026-05-25 14:25:49,173 - Train - INFO - ==================================================
# 2026-05-25 14:25:49,174 - Train - INFO - ▶ 随机种子 (SEED): 3407
# 2026-05-25 14:25:49,175 - Train - INFO - ▶ 峰值学习率 (LR): 0.0003
# 2026-05-25 14:25:49,176 - Train - INFO - ▶ 预热轮数 (Warmup Epochs): 5
# 2026-05-25 14:25:49,177 - Train - INFO - ▶ 批次大小 (Batch Size): 2
# 2026-05-25 14:25:49,178 - Train - INFO - ▶ 优化器: AdamW (Weight Decay: 0.001)
# 2026-05-25 14:25:49,179 - Train - INFO - ▶ 架构说明: 启用浅层特征多尺度融合 (shallow_downsample)
# 2026-05-25 14:25:49,180 - Train - INFO - ▶ 架构说明: 启用 m_k 调制掩码
# 2026-05-25 14:25:49,181 - Train - INFO - ==================================================
# 2026-05-25 14:25:49,182 - Train - INFO - 训练设备: cuda
# 2026-05-25 14:25:49,183 - Train - INFO - 批次大小: 2
# 2026-05-25 14:25:49,184 - Train - INFO - 总轮数: 50

# %%
# 3. 加载训练集 + 验证集 DataLoader
logger.info("正在加载数据集...")
train_loader, val_loader = get_adni_dataloaders(
    train_csv=TRAIN_CSV,
    val_csv=VAL_CSV,
    batch_size=BATCH_SIZE,
    target_size=TRAIN_IMG_SIZE,
    num_workers=NUM_WORKERS,
    use_sampler=False
)
# Out:
# 2026-05-25 14:25:49,230 - Train - INFO - 正在加载数据集...
# 2026-05-25 14:25:49,240 - utils.dataset - INFO - ✅ 成功加载 82 个样本
# 2026-05-25 14:25:49,241 - utils.dataset - INFO - 🧪 启用【原生数据分布 (Shuffle) + 基础增强】策略
# 2026-05-25 14:25:49,277 - utils.dataset - INFO - ✅ 成功加载 656 个样本
# 2026-05-25 14:25:49,278 - utils.dataset - INFO - 训练集批次: 328，验证集批次: 41

# %%
# 4. 初始化模型（完整版！）
logger.info("初始化 APM-Former 模型...")
model = APM_Former_ImageOnly(
    img_size=TRAIN_IMG_SIZE,
    in_channels=1,
    num_classes=NUM_CLASSES,
    feature_size=FEATURE_SIZE,
    guide_channels=GUIDE_CHANNELS,
    pretrained_swin_path=PRETRAINED_SWIN_PATH # 传入刚刚下载的权重
).to(DEVICE)

# 打印模型参数量
total_params = sum(p.numel() for p in model.parameters())
logger.info(f"模型总参数量: {total_params / 1e6:.2f} M")
# Out:
# 2026-05-25 14:25:49,325 - Train - INFO - 初始化 APM-Former 模型...
# /home/ubuntu/Code/APM_Former_Project/models/apm_former.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(pretrained_swin_path, map_location='cpu')
# 加载SwinUNETR预训练权重：checkpoints/model_swinvit.pt
# 2026-05-25 14:25:50,456 - Train - INFO - 模型总参数量: 16.32 M

# %%
# 5. 损失函数 + 两阶段优化器设置
from monai.losses import FocalLoss
from torch.optim.lr_scheduler import CosineAnnealingLR

# ==========================================
# 损失函数 (保持你原来的完美配置不变)
# ==========================================
weights = torch.tensor([1.0, 1.755]).to(DEVICE) 
criterion = FocalLoss(weight=weights, gamma=2.0, to_onehot_y=True).to(DEVICE)

# ==========================================
# 两阶段训练：阶段一 (冻结主干)
# ==========================================

# 1. 冻结 Swin 主干网络
logger.info("🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...")
for name, param in model.named_parameters():
    if "swin_backbone" in name:
        param.requires_grad = False
    else:
        param.requires_grad = True

# 2. 定义优化器：极其重要！这里加了 filter，只把没冻结的参数交给优化器
optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()), 
    lr=3e-4, 
    weight_decay=WEIGHT_DECAY
)

# 3. 阶段一的调度器：不需要预热，直接用 5 个 epoch 的余弦退火
scheduler = CosineAnnealingLR(optimizer, T_max=UNFREEZE_EPOCH)
# Out:
# 2026-05-25 14:25:50,498 - Train - INFO - 🔒 阶段一：冻结 Swin 主干网络，仅训练新增模块...

# %%
# 6. 训练/验证函数
def train_epoch(model, loader, criterion, optimizer, device, accum_steps):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0

    optimizer.zero_grad()
    for idx, (images, labels) in enumerate(tqdm(loader, desc="训练中")):
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1))
        # loss = criterion(logits, labels)
        loss = loss / accum_steps

        loss.backward()
        # 👇 就在 optimizer.step() 之前，加入这行“梯度裁剪”代码！
        # max_norm=1.0 或 2.0 是最常用的安全值
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        if (idx + 1) % accum_steps == 0:
            optimizer.step()
            optimizer.zero_grad()

        total_loss += loss.item() * accum_steps
        preds = torch.argmax(logits, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    avg_loss = total_loss / len(loader)
    acc = 100 * correct / total
    return avg_loss, acc

from sklearn.metrics import confusion_matrix

@torch.no_grad()
def val_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    # correct = 0
    # total = 0
    all_preds = []
    all_labels = []
    all_probs = []  # 🌟 新增：专门用于收集预测为 pMCI 的概率，计算 AUC 必须用

    for images, labels in loader: 
        images = images.to(device)
        labels = labels.to(device)

        logits, _, _ = model(images)
        loss = criterion(logits, labels.unsqueeze(1)) # 如果用的是交叉熵，这里不用 unsqueeze

        total_loss += loss.item()
        
        # 获取预测类别 (0 或 1)
        preds = torch.argmax(logits, dim=1)
        
        # 🌟 获取预测为类别 1 (pMCI) 的概率
        probs = F.softmax(logits, dim=1)[:, 1] 
        
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    
    # ==========================
    # 🌟 计算所有医学黄金指标
    # ==========================
    acc = accuracy_score(all_labels, all_preds) * 100
    sen = recall_score(all_labels, all_preds, pos_label=1) * 100  # Sensitivity / Recall
    spe = recall_score(all_labels, all_preds, pos_label=0) * 100  # Specificity (反向召回)
    f1 = f1_score(all_labels, all_preds, pos_label=1) * 100
    
    # 计算 AUC (注意：有些 batch 如果只有一个类别会报错，这里做了容错)
    try:
        auc = roc_auc_score(all_labels, all_probs) * 100
    except ValueError:
        auc = 0.0

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    
    # 打印超级豪华版日志
    logger.info(f"👉 混淆矩阵: [sMCI正确: {cm[0][0]}, 误判为pMCI: {cm[0][1]}] | [pMCI漏判: {cm[1][0]}, pMCI正确: {cm[1][1]}]")
    logger.info(f"🏆 评估指标: ACC: {acc:.2f}% | SEN: {sen:.2f}% | SPE: {spe:.2f}% | F1: {f1:.2f}% | AUC: {auc:.2f}%")
    
    return avg_loss, acc, auc

# %%
# # %% 训练1个batch，打印梯度！！！
# model.train()
# images, labels = next(iter(train_loader))
# images = images.to(DEVICE)
# labels = labels.to(DEVICE)

# optimizer.zero_grad()
# logits, _, _ = model(images)
# loss = criterion(logits, labels)
# loss.backward()

# # 打印Swin主干的梯度（如果是None/0，就是主干冻结！）
# print("Loss:", loss.item())
# print("Swin主干参数梯度：")
# for name, param in model.swin_backbone.named_parameters():
#     if param.grad is not None:
#         print(f"{name}: 梯度均值 = {param.grad.mean().item()}")
#         break
#     else:
#         print(f"{name}: 梯度为 None ❌（冻结了！）")
#         break

# %%
# 7. 主训练循环
best_val_acc = 0.0
logger.info("=" * 50)
logger.info("开始训练！")
logger.info("=" * 50)

for epoch in range(NUM_EPOCHS):
    # 👇 ================= 新增：解冻机关 ================= 👇
    if epoch == UNFREEZE_EPOCH:
        logger.info("\n" + "🚀" * 20)
        logger.info("🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！")
        logger.info("🚀" * 20)
        
        # 将所有参数解冻
        for param in model.parameters():
            param.requires_grad = True
            
        # 重新定义优化器（包含主干网络），并大幅降低学习率来保护老专家！
        # 这里用 1e-4 或 5e-5 进行微调最合适
        optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=WEIGHT_DECAY)
        
        # 重新定义剩下 epoch 的调度器
        scheduler = CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS - UNFREEZE_EPOCH)
    # 👆 =================================================== 👆
    logger.info(f"\nEpoch [{epoch+1}/{NUM_EPOCHS}]")
    
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, DEVICE, GRADIENT_ACCUMULATION_STEPS)
    val_loss, val_acc, val_auc = val_epoch(model, val_loader, criterion, DEVICE)
    scheduler.step()

    logger.info(f"训练损失: {train_loss:.4f} | 训练准确率: {train_acc:.2f}%")
    logger.info(f"验证损失: {val_loss:.4f} | 验证准确率: {val_acc:.2f}%")
    logger.info(f"当前学习率: {optimizer.param_groups[0]['lr']:.8f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), SAVE_PATH)
        logger.info(f"✅ 最佳模型已保存！最佳验证准确率: {best_val_acc:.2f}%")

logger.info("\n🎉 训练完成！")
logger.info(f"最终最佳验证准确率: {best_val_acc:.2f}%")
# Out:
# 2026-05-25 14:25:50,602 - Train - INFO - ==================================================
# 2026-05-25 14:25:50,604 - Train - INFO - 开始训练！
# 2026-05-25 14:25:50,605 - Train - INFO - ==================================================
# 2026-05-25 14:25:50,606 - Train - INFO -
# Epoch [1/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.41it/s]
# 2026-05-25 14:27:14,424 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:27:14,427 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 56.22%
# 2026-05-25 14:27:14,429 - Train - INFO - 训练损失: 0.2329 | 训练准确率: 61.89%
# 2026-05-25 14:27:14,430 - Train - INFO - 验证损失: 0.2275 | 验证准确率: 63.41%
# 2026-05-25 14:27:14,431 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-25 14:27:15,860 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 63.41%
# 2026-05-25 14:27:15,864 - Train - INFO -
# Epoch [2/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.21it/s]
# 2026-05-25 14:28:43,779 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:28:43,782 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 64.23%
# 2026-05-25 14:28:43,783 - Train - INFO - 训练损失: 0.2297 | 训练准确率: 63.72%
# 2026-05-25 14:28:43,784 - Train - INFO - 验证损失: 0.2277 | 验证准确率: 63.41%
# 2026-05-25 14:28:43,785 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-25 14:28:43,786 - Train - INFO -
# Epoch [3/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.16it/s]
# 2026-05-25 14:30:13,408 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:30:13,410 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 58.27%
# 2026-05-25 14:30:13,412 - Train - INFO - 训练损失: 0.2279 | 训练准确率: 63.72%
# 2026-05-25 14:30:13,413 - Train - INFO - 验证损失: 0.2274 | 验证准确率: 63.41%
# 2026-05-25 14:30:13,414 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-25 14:30:13,415 - Train - INFO -
# Epoch [4/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.24it/s]
# 2026-05-25 14:31:41,301 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:31:41,303 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.44%
# 2026-05-25 14:31:41,305 - Train - INFO - 训练损失: 0.2297 | 训练准确率: 63.72%
# 2026-05-25 14:31:41,306 - Train - INFO - 验证损失: 0.2273 | 验证准确率: 63.41%
# 2026-05-25 14:31:41,306 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-25 14:31:41,308 - Train - INFO -
# Epoch [5/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.10it/s]
# 2026-05-25 14:33:11,900 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:33:11,905 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 64.94%
# 2026-05-25 14:33:11,906 - Train - INFO - 训练损失: 0.2279 | 训练准确率: 63.72%
# 2026-05-25 14:33:11,907 - Train - INFO - 验证损失: 0.2272 | 验证准确率: 63.41%
# 2026-05-25 14:33:11,908 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-25 14:33:11,909 - Train - INFO -
# 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-25 14:33:11,910 - Train - INFO - 🔓 阶段二触发：解冻 Swin 主干网络，开始全员微调！
# 2026-05-25 14:33:11,911 - Train - INFO - 🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀🚀
# 2026-05-25 14:33:11,917 - Train - INFO -
# Epoch [6/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.15it/s]
# 2026-05-25 14:34:41,435 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:34:41,437 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 60.32%
# 2026-05-25 14:34:41,439 - Train - INFO - 训练损失: 0.2337 | 训练准确率: 63.26%
# 2026-05-25 14:34:41,440 - Train - INFO - 验证损失: 0.2275 | 验证准确率: 63.41%
# 2026-05-25 14:34:41,440 - Train - INFO - 当前学习率: 0.00029963
# 2026-05-25 14:34:41,441 - Train - INFO -
# Epoch [7/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.11it/s]
# 2026-05-25 14:36:12,352 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:36:12,354 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 61.86%
# 2026-05-25 14:36:12,357 - Train - INFO - 训练损失: 0.2284 | 训练准确率: 63.72%
# 2026-05-25 14:36:12,358 - Train - INFO - 验证损失: 0.2290 | 验证准确率: 63.41%
# 2026-05-25 14:36:12,359 - Train - INFO - 当前学习率: 0.00029854
# 2026-05-25 14:36:12,359 - Train - INFO -
# Epoch [8/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.11it/s]
# 2026-05-25 14:37:42,185 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:37:42,188 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 63.59%
# 2026-05-25 14:37:42,189 - Train - INFO - 训练损失: 0.2295 | 训练准确率: 63.72%
# 2026-05-25 14:37:42,190 - Train - INFO - 验证损失: 0.2280 | 验证准确率: 63.41%
# 2026-05-25 14:37:42,191 - Train - INFO - 当前学习率: 0.00029672
# 2026-05-25 14:37:42,192 - Train - INFO -
# Epoch [9/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-25 14:39:13,202 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:39:13,204 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 63.85%
# 2026-05-25 14:39:13,206 - Train - INFO - 训练损失: 0.2297 | 训练准确率: 63.72%
# 2026-05-25 14:39:13,207 - Train - INFO - 验证损失: 0.2274 | 验证准确率: 63.41%
# 2026-05-25 14:39:13,207 - Train - INFO - 当前学习率: 0.00029419
# 2026-05-25 14:39:13,208 - Train - INFO -
# Epoch [10/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.14it/s]
# 2026-05-25 14:40:42,716 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:40:42,719 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 60.19%
# 2026-05-25 14:40:42,720 - Train - INFO - 训练损失: 0.2281 | 训练准确率: 63.72%
# 2026-05-25 14:40:42,721 - Train - INFO - 验证损失: 0.2278 | 验证准确率: 63.41%
# 2026-05-25 14:40:42,722 - Train - INFO - 当前学习率: 0.00029095
# 2026-05-25 14:40:42,723 - Train - INFO -
# Epoch [11/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.20it/s]
# 2026-05-25 14:42:11,218 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:42:11,221 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 57.44%
# 2026-05-25 14:42:11,222 - Train - INFO - 训练损失: 0.2290 | 训练准确率: 63.72%
# 2026-05-25 14:42:11,223 - Train - INFO - 验证损失: 0.2278 | 验证准确率: 63.41%
# 2026-05-25 14:42:11,224 - Train - INFO - 当前学习率: 0.00028703
# 2026-05-25 14:42:11,225 - Train - INFO -
# Epoch [12/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.19it/s]
# 2026-05-25 14:43:40,386 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:43:40,392 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.69%
# 2026-05-25 14:43:40,394 - Train - INFO - 训练损失: 0.2279 | 训练准确率: 63.72%
# 2026-05-25 14:43:40,395 - Train - INFO - 验证损失: 0.2272 | 验证准确率: 63.41%
# 2026-05-25 14:43:40,396 - Train - INFO - 当前学习率: 0.00028244
# 2026-05-25 14:43:40,397 - Train - INFO -
# Epoch [13/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.20it/s]
# 2026-05-25 14:45:08,843 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:45:08,845 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 60.64%
# 2026-05-25 14:45:08,847 - Train - INFO - 训练损失: 0.2281 | 训练准确率: 63.72%
# 2026-05-25 14:45:08,848 - Train - INFO - 验证损失: 0.2274 | 验证准确率: 63.41%
# 2026-05-25 14:45:08,849 - Train - INFO - 当前学习率: 0.00027721
# 2026-05-25 14:45:08,849 - Train - INFO -
# Epoch [14/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.18it/s]
# 2026-05-25 14:46:37,248 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:46:37,250 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 62.24%
# 2026-05-25 14:46:37,252 - Train - INFO - 训练损失: 0.2282 | 训练准确率: 63.72%
# 2026-05-25 14:46:37,253 - Train - INFO - 验证损失: 0.2271 | 验证准确率: 63.41%
# 2026-05-25 14:46:37,254 - Train - INFO - 当前学习率: 0.00027135
# 2026-05-25 14:46:37,254 - Train - INFO -
# Epoch [15/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.22it/s]
# 2026-05-25 14:48:05,435 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:48:05,437 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 65.45%
# 2026-05-25 14:48:05,438 - Train - INFO - 训练损失: 0.2263 | 训练准确率: 63.72%
# 2026-05-25 14:48:05,439 - Train - INFO - 验证损失: 0.2277 | 验证准确率: 63.41%
# 2026-05-25 14:48:05,439 - Train - INFO - 当前学习率: 0.00026491
# 2026-05-25 14:48:05,440 - Train - INFO -
# Epoch [16/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.13it/s]
# 2026-05-25 14:49:35,764 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:49:35,768 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 67.76%
# 2026-05-25 14:49:35,770 - Train - INFO - 训练损失: 0.2267 | 训练准确率: 63.72%
# 2026-05-25 14:49:35,771 - Train - INFO - 验证损失: 0.2255 | 验证准确率: 63.41%
# 2026-05-25 14:49:35,772 - Train - INFO - 当前学习率: 0.00025790
# 2026-05-25 14:49:35,774 - Train - INFO -
# Epoch [17/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.19it/s]
# 2026-05-25 14:51:03,896 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:51:03,897 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 68.97%
# 2026-05-25 14:51:03,898 - Train - INFO - 训练损失: 0.2266 | 训练准确率: 63.72%
# 2026-05-25 14:51:03,898 - Train - INFO - 验证损失: 0.2256 | 验证准确率: 63.41%
# 2026-05-25 14:51:03,899 - Train - INFO - 当前学习率: 0.00025037
# 2026-05-25 14:51:03,899 - Train - INFO -
# Epoch [18/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.20it/s]
# 2026-05-25 14:52:32,992 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:52:32,995 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 69.94%
# 2026-05-25 14:52:32,996 - Train - INFO - 训练损失: 0.2254 | 训练准确率: 63.72%
# 2026-05-25 14:52:32,997 - Train - INFO - 验证损失: 0.2252 | 验证准确率: 63.41%
# 2026-05-25 14:52:32,997 - Train - INFO - 当前学习率: 0.00024235
# 2026-05-25 14:52:32,998 - Train - INFO -
# Epoch [19/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.12it/s]
# 2026-05-25 14:54:02,454 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:54:02,456 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 70.32%
# 2026-05-25 14:54:02,458 - Train - INFO - 训练损失: 0.2247 | 训练准确率: 63.26%
# 2026-05-25 14:54:02,459 - Train - INFO - 验证损失: 0.2289 | 验证准确率: 63.41%
# 2026-05-25 14:54:02,459 - Train - INFO - 当前学习率: 0.00023388
# 2026-05-25 14:54:02,460 - Train - INFO -
# Epoch [20/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.11it/s]
# 2026-05-25 14:55:31,982 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 51, 误判为pMCI: 1] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:55:31,984 - Train - INFO - 🏆 评估指标: ACC: 62.20% | SEN: 0.00% | SPE: 98.08% | F1: 0.00% | AUC: 72.76%
# 2026-05-25 14:55:31,986 - Train - INFO - 训练损失: 0.2207 | 训练准确率: 64.02%
# 2026-05-25 14:55:31,986 - Train - INFO - 验证损失: 0.2131 | 验证准确率: 62.20%
# 2026-05-25 14:55:31,987 - Train - INFO - 当前学习率: 0.00022500
# 2026-05-25 14:55:31,988 - Train - INFO -
# Epoch [21/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.15it/s]
# 2026-05-25 14:57:01,315 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 52, 误判为pMCI: 0] | [pMCI漏判: 30, pMCI正确: 0]
# 2026-05-25 14:57:01,317 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 0.00% | SPE: 100.00% | F1: 0.00% | AUC: 72.76%
# 2026-05-25 14:57:01,319 - Train - INFO - 训练损失: 0.2146 | 训练准确率: 65.85%
# 2026-05-25 14:57:01,320 - Train - INFO - 验证损失: 0.2577 | 验证准确率: 63.41%
# 2026-05-25 14:57:01,321 - Train - INFO - 当前学习率: 0.00021576
# 2026-05-25 14:57:01,322 - Train - INFO -
# Epoch [22/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.15it/s]
# 2026-05-25 14:58:31,628 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 35, 误判为pMCI: 17] | [pMCI漏判: 9, pMCI正确: 21]
# 2026-05-25 14:58:31,630 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 70.00% | SPE: 67.31% | F1: 61.76% | AUC: 74.04%
# 2026-05-25 14:58:31,632 - Train - INFO - 训练损失: 0.2339 | 训练准确率: 66.16%
# 2026-05-25 14:58:31,632 - Train - INFO - 验证损失: 0.2081 | 验证准确率: 68.29%
# 2026-05-25 14:58:31,633 - Train - INFO - 当前学习率: 0.00020619
# 2026-05-25 14:58:32,947 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 68.29%
# 2026-05-25 14:58:32,948 - Train - INFO -
# Epoch [23/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.20it/s]
# 2026-05-25 15:00:01,225 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 50, 误判为pMCI: 2] | [pMCI漏判: 25, pMCI正确: 5]
# 2026-05-25 15:00:01,227 - Train - INFO - 🏆 评估指标: ACC: 67.07% | SEN: 16.67% | SPE: 96.15% | F1: 27.03% | AUC: 73.53%
# 2026-05-25 15:00:01,229 - Train - INFO - 训练损失: 0.2286 | 训练准确率: 68.60%
# 2026-05-25 15:00:01,229 - Train - INFO - 验证损失: 0.2229 | 验证准确率: 67.07%
# 2026-05-25 15:00:01,231 - Train - INFO - 当前学习率: 0.00019635
# 2026-05-25 15:00:01,231 - Train - INFO -
# Epoch [24/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.14it/s]
# 2026-05-25 15:01:30,897 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 43, 误判为pMCI: 9] | [pMCI漏判: 14, pMCI正确: 16]
# 2026-05-25 15:01:30,899 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 53.33% | SPE: 82.69% | F1: 58.18% | AUC: 74.55%
# 2026-05-25 15:01:30,901 - Train - INFO - 训练损失: 0.2253 | 训练准确率: 67.84%
# 2026-05-25 15:01:30,901 - Train - INFO - 验证损失: 0.2006 | 验证准确率: 71.95%
# 2026-05-25 15:01:30,902 - Train - INFO - 当前学习率: 0.00018629
# 2026-05-25 15:01:32,115 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 71.95%
# 2026-05-25 15:01:32,115 - Train - INFO -
# Epoch [25/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.23it/s]
# 2026-05-25 15:02:59,869 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 35, 误判为pMCI: 17] | [pMCI漏判: 8, pMCI正确: 22]
# 2026-05-25 15:02:59,871 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 73.33% | SPE: 67.31% | F1: 63.77% | AUC: 73.08%
# 2026-05-25 15:02:59,873 - Train - INFO - 训练损失: 0.2174 | 训练准确率: 71.19%
# 2026-05-25 15:02:59,874 - Train - INFO - 验证损失: 0.2432 | 验证准确率: 69.51%
# 2026-05-25 15:02:59,874 - Train - INFO - 当前学习率: 0.00017605
# 2026-05-25 15:02:59,875 - Train - INFO -
# Epoch [26/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.14it/s]
# 2026-05-25 15:04:29,281 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 41, 误判为pMCI: 11] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:04:29,283 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 74.74%
# 2026-05-25 15:04:29,284 - Train - INFO - 训练损失: 0.2284 | 训练准确率: 69.82%
# 2026-05-25 15:04:29,285 - Train - INFO - 验证损失: 0.2086 | 验证准确率: 70.73%
# 2026-05-25 15:04:29,286 - Train - INFO - 当前学习率: 0.00016568
# 2026-05-25 15:04:29,287 - Train - INFO -
# Epoch [27/50]
# 训练中: 100%|██████████| 328/328 [01:14<00:00,  4.39it/s]
# 2026-05-25 15:05:54,353 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 48, 误判为pMCI: 4] | [pMCI漏判: 22, pMCI正确: 8]
# 2026-05-25 15:05:54,356 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 26.67% | SPE: 92.31% | F1: 38.10% | AUC: 72.63%
# 2026-05-25 15:05:54,357 - Train - INFO - 训练损失: 0.2366 | 训练准确率: 67.99%
# 2026-05-25 15:05:54,358 - Train - INFO - 验证损失: 0.2183 | 验证准确率: 68.29%
# 2026-05-25 15:05:54,359 - Train - INFO - 当前学习率: 0.00015523
# 2026-05-25 15:05:54,360 - Train - INFO -
# Epoch [28/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.13it/s]
# 2026-05-25 15:07:23,456 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 50, 误判为pMCI: 2] | [pMCI漏判: 28, pMCI正确: 2]
# 2026-05-25 15:07:23,458 - Train - INFO - 🏆 评估指标: ACC: 63.41% | SEN: 6.67% | SPE: 96.15% | F1: 11.76% | AUC: 74.55%
# 2026-05-25 15:07:23,459 - Train - INFO - 训练损失: 0.2277 | 训练准确率: 69.05%
# 2026-05-25 15:07:23,460 - Train - INFO - 验证损失: 0.2826 | 验证准确率: 63.41%
# 2026-05-25 15:07:23,461 - Train - INFO - 当前学习率: 0.00014477
# 2026-05-25 15:07:23,462 - Train - INFO -
# Epoch [29/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.22it/s]
# 2026-05-25 15:08:52,899 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 45, 误判为pMCI: 7] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-25 15:08:52,901 - Train - INFO - 🏆 评估指标: ACC: 73.17% | SEN: 50.00% | SPE: 86.54% | F1: 57.69% | AUC: 75.00%
# 2026-05-25 15:08:52,902 - Train - INFO - 训练损失: 0.2381 | 训练准确率: 70.27%
# 2026-05-25 15:08:52,903 - Train - INFO - 验证损失: 0.2172 | 验证准确率: 73.17%
# 2026-05-25 15:08:52,904 - Train - INFO - 当前学习率: 0.00013432
# 2026-05-25 15:08:54,205 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 73.17%
# 2026-05-25 15:08:54,206 - Train - INFO -
# Epoch [30/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.18it/s]
# 2026-05-25 15:10:22,754 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 39, 误判为pMCI: 13] | [pMCI漏判: 11, pMCI正确: 19]
# 2026-05-25 15:10:22,756 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 63.33% | SPE: 75.00% | F1: 61.29% | AUC: 75.26%
# 2026-05-25 15:10:22,757 - Train - INFO - 训练损失: 0.2318 | 训练准确率: 70.58%
# 2026-05-25 15:10:22,758 - Train - INFO - 验证损失: 0.2254 | 验证准确率: 70.73%
# 2026-05-25 15:10:22,759 - Train - INFO - 当前学习率: 0.00012395
# 2026-05-25 15:10:22,760 - Train - INFO -
# Epoch [31/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.06it/s]
# 2026-05-25 15:11:53,630 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 45, 误判为pMCI: 7] | [pMCI漏判: 14, pMCI正确: 16]
# 2026-05-25 15:11:53,632 - Train - INFO - 🏆 评估指标: ACC: 74.39% | SEN: 53.33% | SPE: 86.54% | F1: 60.38% | AUC: 74.49%
# 2026-05-25 15:11:53,633 - Train - INFO - 训练损失: 0.2339 | 训练准确率: 70.43%
# 2026-05-25 15:11:53,634 - Train - INFO - 验证损失: 0.2157 | 验证准确率: 74.39%
# 2026-05-25 15:11:53,635 - Train - INFO - 当前学习率: 0.00011371
# 2026-05-25 15:11:54,678 - Train - INFO - ✅ 最佳模型已保存！最佳验证准确率: 74.39%
# 2026-05-25 15:11:54,679 - Train - INFO -
# Epoch [32/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.12it/s]
# 2026-05-25 15:13:24,630 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 35, 误判为pMCI: 17] | [pMCI漏判: 8, pMCI正确: 22]
# 2026-05-25 15:13:24,632 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 73.33% | SPE: 67.31% | F1: 63.77% | AUC: 73.85%
# 2026-05-25 15:13:24,633 - Train - INFO - 训练损失: 0.2338 | 训练准确率: 71.65%
# 2026-05-25 15:13:24,634 - Train - INFO - 验证损失: 0.2537 | 验证准确率: 69.51%
# 2026-05-25 15:13:24,635 - Train - INFO - 当前学习率: 0.00010365
# 2026-05-25 15:13:24,636 - Train - INFO -
# Epoch [33/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.15it/s]
# 2026-05-25 15:14:54,569 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 45, 误判为pMCI: 7] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-25 15:14:54,571 - Train - INFO - 🏆 评估指标: ACC: 73.17% | SEN: 50.00% | SPE: 86.54% | F1: 57.69% | AUC: 74.87%
# 2026-05-25 15:14:54,573 - Train - INFO - 训练损失: 0.2349 | 训练准确率: 72.41%
# 2026-05-25 15:14:54,574 - Train - INFO - 验证损失: 0.2570 | 验证准确率: 73.17%
# 2026-05-25 15:14:54,575 - Train - INFO - 当前学习率: 0.00009381
# 2026-05-25 15:14:54,576 - Train - INFO -
# Epoch [34/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.11it/s]
# 2026-05-25 15:16:24,501 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 39, 误判为pMCI: 13] | [pMCI漏判: 12, pMCI正确: 18]
# 2026-05-25 15:16:24,503 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 74.17%
# 2026-05-25 15:16:24,504 - Train - INFO - 训练损失: 0.2611 | 训练准确率: 69.97%
# 2026-05-25 15:16:24,505 - Train - INFO - 验证损失: 0.2405 | 验证准确率: 69.51%
# 2026-05-25 15:16:24,506 - Train - INFO - 当前学习率: 0.00008424
# 2026-05-25 15:16:24,506 - Train - INFO -
# Epoch [35/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.11it/s]
# 2026-05-25 15:17:54,242 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 35, 误判为pMCI: 17] | [pMCI漏判: 9, pMCI正确: 21]
# 2026-05-25 15:17:54,245 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 70.00% | SPE: 67.31% | F1: 61.76% | AUC: 74.04%
# 2026-05-25 15:17:54,246 - Train - INFO - 训练损失: 0.2388 | 训练准确率: 70.12%
# 2026-05-25 15:17:54,247 - Train - INFO - 验证损失: 0.2607 | 验证准确率: 68.29%
# 2026-05-25 15:17:54,248 - Train - INFO - 当前学习率: 0.00007500
# 2026-05-25 15:17:54,248 - Train - INFO -
# Epoch [36/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.06it/s]
# 2026-05-25 15:19:24,803 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 45, 误判为pMCI: 7] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-25 15:19:24,805 - Train - INFO - 🏆 评估指标: ACC: 73.17% | SEN: 50.00% | SPE: 86.54% | F1: 57.69% | AUC: 74.49%
# 2026-05-25 15:19:24,805 - Train - INFO - 训练损失: 0.2221 | 训练准确率: 71.80%
# 2026-05-25 15:19:24,806 - Train - INFO - 验证损失: 0.2342 | 验证准确率: 73.17%
# 2026-05-25 15:19:24,806 - Train - INFO - 当前学习率: 0.00006612
# 2026-05-25 15:19:24,806 - Train - INFO -
# Epoch [37/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-25 15:20:54,749 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:20:54,751 - Train - INFO - 🏆 评估指标: ACC: 74.39% | SEN: 56.67% | SPE: 84.62% | F1: 61.82% | AUC: 74.87%
# 2026-05-25 15:20:54,752 - Train - INFO - 训练损失: 0.2365 | 训练准确率: 71.34%
# 2026-05-25 15:20:54,753 - Train - INFO - 验证损失: 0.2438 | 验证准确率: 74.39%
# 2026-05-25 15:20:54,754 - Train - INFO - 当前学习率: 0.00005765
# 2026-05-25 15:20:54,755 - Train - INFO -
# Epoch [38/50]
# 训练中: 100%|██████████| 328/328 [01:21<00:00,  4.04it/s]
# 2026-05-25 15:22:26,251 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 38, 误判为pMCI: 14] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:22:26,253 - Train - INFO - 🏆 评估指标: ACC: 67.07% | SEN: 56.67% | SPE: 73.08% | F1: 55.74% | AUC: 74.42%
# 2026-05-25 15:22:26,255 - Train - INFO - 训练损失: 0.2485 | 训练准确率: 71.04%
# 2026-05-25 15:22:26,255 - Train - INFO - 验证损失: 0.2536 | 验证准确率: 67.07%
# 2026-05-25 15:22:26,256 - Train - INFO - 当前学习率: 0.00004963
# 2026-05-25 15:22:26,257 - Train - INFO -
# Epoch [39/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-25 15:23:56,893 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 39, 误判为pMCI: 13] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:23:56,895 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 56.67% | SPE: 75.00% | F1: 56.67% | AUC: 74.55%
# 2026-05-25 15:23:56,896 - Train - INFO - 训练损失: 0.2483 | 训练准确率: 70.88%
# 2026-05-25 15:23:56,897 - Train - INFO - 验证损失: 0.2529 | 验证准确率: 68.29%
# 2026-05-25 15:23:56,898 - Train - INFO - 当前学习率: 0.00004210
# 2026-05-25 15:23:56,899 - Train - INFO -
# Epoch [40/50]
# 训练中: 100%|██████████| 328/328 [01:16<00:00,  4.26it/s]
# 2026-05-25 15:25:23,958 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 42, 误判为pMCI: 10] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:25:23,959 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 56.67% | SPE: 80.77% | F1: 59.65% | AUC: 74.94%
# 2026-05-25 15:25:23,960 - Train - INFO - 训练损失: 0.2442 | 训练准确率: 70.88%
# 2026-05-25 15:25:23,961 - Train - INFO - 验证损失: 0.2511 | 验证准确率: 71.95%
# 2026-05-25 15:25:23,962 - Train - INFO - 当前学习率: 0.00003509
# 2026-05-25 15:25:23,962 - Train - INFO -
# Epoch [41/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.17it/s]
# 2026-05-25 15:26:52,753 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 39, 误判为pMCI: 13] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:26:52,755 - Train - INFO - 🏆 评估指标: ACC: 68.29% | SEN: 56.67% | SPE: 75.00% | F1: 56.67% | AUC: 74.55%
# 2026-05-25 15:26:52,757 - Train - INFO - 训练损失: 0.2499 | 训练准确率: 71.04%
# 2026-05-25 15:26:52,758 - Train - INFO - 验证损失: 0.2562 | 验证准确率: 68.29%
# 2026-05-25 15:26:52,759 - Train - INFO - 当前学习率: 0.00002865
# 2026-05-25 15:26:52,760 - Train - INFO -
# Epoch [42/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.07it/s]
# 2026-05-25 15:28:23,919 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 15, pMCI正确: 15]
# 2026-05-25 15:28:23,922 - Train - INFO - 🏆 评估指标: ACC: 71.95% | SEN: 50.00% | SPE: 84.62% | F1: 56.60% | AUC: 75.13%
# 2026-05-25 15:28:23,923 - Train - INFO - 训练损失: 0.2399 | 训练准确率: 71.49%
# 2026-05-25 15:28:23,924 - Train - INFO - 验证损失: 0.2534 | 验证准确率: 71.95%
# 2026-05-25 15:28:23,925 - Train - INFO - 当前学习率: 0.00002279
# 2026-05-25 15:28:23,925 - Train - INFO -
# Epoch [43/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.15it/s]
# 2026-05-25 15:29:53,386 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 44, 误判为pMCI: 8] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:29:53,388 - Train - INFO - 🏆 评估指标: ACC: 74.39% | SEN: 56.67% | SPE: 84.62% | F1: 61.82% | AUC: 74.94%
# 2026-05-25 15:29:53,390 - Train - INFO - 训练损失: 0.2444 | 训练准确率: 70.58%
# 2026-05-25 15:29:53,391 - Train - INFO - 验证损失: 0.2471 | 验证准确率: 74.39%
# 2026-05-25 15:29:53,391 - Train - INFO - 当前学习率: 0.00001756
# 2026-05-25 15:29:53,393 - Train - INFO -
# Epoch [44/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.15it/s]
# 2026-05-25 15:31:22,709 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 39, 误判为pMCI: 13] | [pMCI漏判: 12, pMCI正确: 18]
# 2026-05-25 15:31:22,711 - Train - INFO - 🏆 评估指标: ACC: 69.51% | SEN: 60.00% | SPE: 75.00% | F1: 59.02% | AUC: 75.06%
# 2026-05-25 15:31:22,712 - Train - INFO - 训练损失: 0.2376 | 训练准确率: 70.12%
# 2026-05-25 15:31:22,713 - Train - INFO - 验证损失: 0.2545 | 验证准确率: 69.51%
# 2026-05-25 15:31:22,714 - Train - INFO - 当前学习率: 0.00001297
# 2026-05-25 15:31:22,714 - Train - INFO -
# Epoch [45/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-25 15:32:52,809 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 41, 误判为pMCI: 11] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:32:52,811 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 75.00%
# 2026-05-25 15:32:52,813 - Train - INFO - 训练损失: 0.2300 | 训练准确率: 72.26%
# 2026-05-25 15:32:52,813 - Train - INFO - 验证损失: 0.2511 | 验证准确率: 70.73%
# 2026-05-25 15:32:52,814 - Train - INFO - 当前学习率: 0.00000905
# 2026-05-25 15:32:52,815 - Train - INFO -
# Epoch [46/50]
# 训练中: 100%|██████████| 328/328 [01:20<00:00,  4.09it/s]
# 2026-05-25 15:34:23,396 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 41, 误判为pMCI: 11] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:34:23,399 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 75.00%
# 2026-05-25 15:34:23,402 - Train - INFO - 训练损失: 0.2393 | 训练准确率: 72.26%
# 2026-05-25 15:34:23,404 - Train - INFO - 验证损失: 0.2563 | 验证准确率: 70.73%
# 2026-05-25 15:34:23,405 - Train - INFO - 当前学习率: 0.00000581
# 2026-05-25 15:34:23,406 - Train - INFO -
# Epoch [47/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.13it/s]
# 2026-05-25 15:35:53,401 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 41, 误判为pMCI: 11] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:35:53,404 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 75.06%
# 2026-05-25 15:35:53,405 - Train - INFO - 训练损失: 0.2427 | 训练准确率: 72.56%
# 2026-05-25 15:35:53,406 - Train - INFO - 验证损失: 0.2564 | 验证准确率: 70.73%
# 2026-05-25 15:35:53,406 - Train - INFO - 当前学习率: 0.00000328
# 2026-05-25 15:35:53,408 - Train - INFO -
# Epoch [48/50]
# 训练中: 100%|██████████| 328/328 [01:19<00:00,  4.14it/s]
# 2026-05-25 15:37:22,848 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 41, 误判为pMCI: 11] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:37:22,850 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 74.94%
# 2026-05-25 15:37:22,851 - Train - INFO - 训练损失: 0.2327 | 训练准确率: 72.56%
# 2026-05-25 15:37:22,852 - Train - INFO - 验证损失: 0.2548 | 验证准确率: 70.73%
# 2026-05-25 15:37:22,853 - Train - INFO - 当前学习率: 0.00000146
# 2026-05-25 15:37:22,853 - Train - INFO -
# Epoch [49/50]
# 训练中: 100%|██████████| 328/328 [01:18<00:00,  4.16it/s]
# 2026-05-25 15:38:51,235 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 41, 误判为pMCI: 11] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:38:51,237 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 74.94%
# 2026-05-25 15:38:51,238 - Train - INFO - 训练损失: 0.2346 | 训练准确率: 71.34%
# 2026-05-25 15:38:51,239 - Train - INFO - 验证损失: 0.2545 | 验证准确率: 70.73%
# 2026-05-25 15:38:51,241 - Train - INFO - 当前学习率: 0.00000037
# 2026-05-25 15:38:51,242 - Train - INFO -
# Epoch [50/50]
# 训练中: 100%|██████████| 328/328 [01:17<00:00,  4.23it/s]
# 2026-05-25 15:40:18,965 - Train - INFO - 👉 混淆矩阵: [sMCI正确: 41, 误判为pMCI: 11] | [pMCI漏判: 13, pMCI正确: 17]
# 2026-05-25 15:40:18,966 - Train - INFO - 🏆 评估指标: ACC: 70.73% | SEN: 56.67% | SPE: 78.85% | F1: 58.62% | AUC: 74.94%
# 2026-05-25 15:40:18,968 - Train - INFO - 训练损失: 0.2364 | 训练准确率: 72.26%
# 2026-05-25 15:40:18,969 - Train - INFO - 验证损失: 0.2547 | 验证准确率: 70.73%
# 2026-05-25 15:40:18,969 - Train - INFO - 当前学习率: 0.00000000
# 2026-05-25 15:40:18,970 - Train - INFO -
# 🎉 训练完成！
# 2026-05-25 15:40:18,971 - Train - INFO - 最终最佳验证准确率: 74.39%

# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

# ==========================================
# 第一步：加载你跑出 74.39% 的最佳模型权重
# ==========================================
print("🔄 正在加载最佳模型权重...")

# 实例化模型 (确保这里的参数和你跑出最好成绩的那次完全一致)
# 之前确认过 FEATURE_SIZE 是 24
vis_model = APM_Former_ImageOnly(
    feature_size=24,  
    num_classes=2
).to(DEVICE)

# ⚠️ 注意：把这里的 'best_model.pth' 换成你实际保存的权重文件名！
# 比如可能是 'checkpoint_epoch_xx.pth'
checkpoint_path = 'checkpoints/best_3407model2.pth'  
state_dict = torch.load(checkpoint_path, map_location=DEVICE)
vis_model.load_state_dict(state_dict)

vis_model.eval() # 切换到评估模式
print(f"✅ 成功加载权重: {checkpoint_path}")
print("-" * 50)


# ==========================================
# 第二步：定义并运行可视化探针
# ==========================================
@torch.no_grad()
def visualize_pMCI_attention(model, val_loader, device, num_cases_to_show=3):
    model.eval()
    found_cases = 0
    
    # 解决 matplotlib 中文显示问题
    # plt.rcParams['font.sans-serif'] = ['SimHei'] 
    # plt.rcParams['axes.unicode_minus'] = False
    
    print("🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...\n")
    
    for images, labels in val_loader:
        images = images.to(device)
        labels = labels.to(device)
        
        logits, _, spatial_attention = model(images)
        preds = torch.argmax(logits, dim=1)
        
        # 寻找 True Positives (真实为pMCI，预测也为pMCI)
        for i in range(len(labels)):
            if labels[i].item() == 1 and preds[i].item() == 1:
                found_cases += 1
                
                # 1. 提取原始 3D MRI 图像
                img_3d = images[i, 0].cpu().numpy()  
                
                # 2. 提取注意力掩码，并插值放大到原始图像大小 (96, 96, 96)
                attn_tensor = spatial_attention[i:i+1] 
                attn_resized = F.interpolate(attn_tensor, size=img_3d.shape, mode='trilinear', align_corners=False)
                attn_3d = attn_resized[0, 0].cpu().numpy()
                
                # 3. 智能寻找网络最关注的切片位置
                slice_x = np.argmax(np.sum(attn_3d, axis=(1, 2))) 
                slice_y = np.argmax(np.sum(attn_3d, axis=(0, 2))) 
                slice_z = np.argmax(np.sum(attn_3d, axis=(0, 1))) 
                
                # 4. 绘图
                fig, axes = plt.subplots(1, 3, figsize=(18, 6))
                # 成功识别的pMCI阳性病例  高亮区域为网络空间对齐中点关注区域
                fig.suptitle(f"True Positive pMCI Case #{found_cases}\n(Spatial Attention Guided Alignment)", fontsize=18, fontweight='bold', y=1.05)
                
                # 矢状面 矢状面切片
                axes[0].imshow(img_3d[slice_x, :, :], cmap='gray') 
                im = axes[0].imshow(attn_3d[slice_x, :, :], cmap='jet', alpha=0.45) 
                axes[0].set_title(f"Sagittal View (Slice {slice_x})", fontsize=14)
                axes[0].axis('off')
                
                # 冠状面 冠状面切片
                axes[1].imshow(img_3d[:, slice_y, :], cmap='gray')
                axes[1].imshow(attn_3d[:, slice_y, :], cmap='jet', alpha=0.45)
                axes[1].set_title(f"Coronal View (Slice {slice_y})", fontsize=14)
                axes[1].axis('off')
                
                # 轴状面 轴状面切片
                axes[2].imshow(img_3d[:, :, slice_z], cmap='gray')
                axes[2].imshow(attn_3d[:, :, slice_z], cmap='jet', alpha=0.45)
                axes[2].set_title(f"Axial View (Slice {slice_z})", fontsize=14)
                axes[2].axis('off')
                
                # 颜色条的标签 解剖引导强度
                cbar = fig.colorbar(im, ax=axes.ravel().tolist(), shrink=0.7)
                cbar.set_label('Attention Weight', fontsize=12)
                
                plt.show()
                
                if found_cases >= num_cases_to_show:
                    print(f"\n✅ 成功提取 {num_cases_to_show} 组 pMCI 空间注意力图！")
                    return

    print(f"\n搜索结束，共找到 {found_cases} 个符合条件的病例。")

# 执行探针！展示前 5 个最典型的病例
visualize_pMCI_attention(vis_model, val_loader, DEVICE, num_cases_to_show=5)
# Out:
# 🔄 正在加载最佳模型权重...
# /tmp/ipykernel_294464/3096245218.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(checkpoint_path, map_location=DEVICE)
# ✅ 成功加载权重: checkpoints/best_3407model2.pth
# --------------------------------------------------
# 🕵️‍♂️ 探针已启动，正在验证集中搜寻成功预测的 pMCI 病例...
# ✅ 成功提取 5 组 pMCI 空间注意力图！
